# %%
import utils
import torch
import math
import numpy as np 
from PIL import Image
import cv2
import os
from pathlib import *
import shutil
import pandas as PD
import matplotlib.pyplot as plt
# %matplotlib inline
PD.options.display.expand_frame_repr = False

# %%
display = utils.notebook_init() 
print('cuda доступна', torch.cuda.is_available())
print('под каким номером куда:',torch.cuda.current_device())
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE" #без этого ошибка будет
# Out:
# YOLOv5  v6.1-258-g1156a32 Python-3.8.13 torch-1.11.0 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Setup complete  (16 CPUs, 39.3 GB RAM, 233.2/953.9 GB disk)
# cuda доступна True
# под каким номером куда: 0

# %%
#функция крутит картинку в зависимости от того, что нашла в характеристиках файла. 
def exif_transpose(img):
    if not img:
        return img

    exif_orientation_tag = 274

    # Check for EXIF data (only present on some files)
    if hasattr(img, "_getexif") and isinstance(img._getexif(), dict) and exif_orientation_tag in img._getexif():
        exif_data = img._getexif()
        orientation = exif_data[exif_orientation_tag]

        # Handle EXIF Orientation
        if orientation == 1:
            # Normal image - nothing to do!
            pass
        elif orientation == 2:
            # Mirrored left to right
            img = img.transpose(PIL.Image.FLIP_LEFT_RIGHT)
        elif orientation == 3:
            # Rotated 180 degrees
            img = img.rotate(180)
        elif orientation == 4:
            # Mirrored top to bottom
            img = img.rotate(180).transpose(PIL.Image.FLIP_LEFT_RIGHT)
        elif orientation == 5:
            # Mirrored along top-left diagonal
            img = img.rotate(-90, expand=True).transpose(PIL.Image.FLIP_LEFT_RIGHT)
        elif orientation == 6:
            # Rotated 90 degrees
            #print('повернули')
            img = img.rotate(-90, expand=True)
        elif orientation == 7:
            # Mirrored along top-right diagonal
            img = img.rotate(90, expand=True).transpose(PIL.Image.FLIP_LEFT_RIGHT)
        elif orientation == 8:
            # Rotated 270 degrees
            img = img.rotate(90, expand=True)

    return img

def conv_heic_to_jpg(file, new_name):

    heif_file = pillow_heif.read_heif(file)
    image = Image.frombytes(
        heif_file.mode,
        heif_file.size,
        heif_file.data,
        "raw",
    )
    
    #new_name = 'Y:\\temp.jpg' #так просто мы меняем расширение
    ex = heif_file.info['exif']
    image.save(new_name, format("jpeg"), exif=ex)
    image.close()
    return new_name

# %%
#model = torch.hub.load('ultralytics/yolov5', 'custom',  path='runs\\train\\exp002\\weights\\best.pt') #работает, но загружает каждый раз
model = torch.hub.load('ultralytics/yolov5', 'custom',  path='runs\\train\\color\\exp003\\weights\\best.pt') #работает, но загружает каждый раз
# Out:
# Using cache found in C:\Users\Алексей/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  v6.1-258-g1156a32 Python-3.8.13 torch-1.11.0 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
#
# Fusing layers...
# Model summary: 290 layers, 20852934 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# # получаем из картинки знак и все его параметры

# %%
def get_distance(p):
    if len(p) != 2: 
        return 0
    d = (p[0][0]-p[1][0])**2 + (p[0][1]-p[1][1])**2
    d = d**0.5
    return d
def res(file, show_pandas = 0):
    #Здесь и далее - show_pandas - параметр отпределяет вывод отладочной информации. 1 - выводить, 0 - не выводить
    if '.heic' in file:
        #temp_file = 'Y:\\tmp.jpg'
        temp_file = 'tmp.jpg'
        file = conv_heic_to_jpg(work_file,temp_file)
    
    im = Image.open(file)
    (width, height) = im.size
    
    results = model(file)
    pd = results.pandas().xyxy[0]
    
    pd = pd.loc[pd['name'] == 'znak']                   #таблица со знаками
    
    #все номера нам не надо. Нам надо только тот, что ближе к центру

    #ОБРАБАТЫВАЕМ ЗНАКИ
    if show_pandas == 1:
        print('Знаки\n',pd)
    
    pd = pd.assign(to_centre_x = abs(width/2 - (pd.xmin + (pd.xmax-pd.xmin)/2)))     #считаем расстояние до центра
    pd = pd.assign(centre_x = pd.xmin + (pd.xmax-pd.xmin)/2)                         #считаем координаты центра 
    
    pd = pd.assign(width = pd.xmax - pd.xmin)                                        #ширина
    pd = pd.assign(height = pd.ymax - pd.ymin)                                       #высота
    pd = pd.assign(s2 = pd.width * pd.height)                                        #площадь
    
    pd = pd.sort_values(['to_centre_x'] )                                            #сортируем по близости к центру. Нам надо самый близкий номер
    
    
    d = dict()   #в этом словаре будут все результаты
    for index, row in pd.iterrows():
        d ['width']  = row['width']
        d ['height']  = row['height']
        d ['s2']  = row['s2']
        d ['xmin']  = row['xmin']
        d ['ymin']  = row['ymin']
        d ['xmax']  = row['xmax']
        d ['ymax']  = row['ymax']
        break
    #Сейчас в d - все характеристики знака. 
    
    
    d['im_width'] = width
    d['im_height'] = height
    
    
    return d

# %%
#проверка. работаем с одним файлом
znak = res('..\\avto\\start_dataset\\train\\img_2857.jpg',1)
print(znak)
# Out:
# Знаки
#            xmin         ymin         xmax         ymax  confidence  class  name
# 0  1531.125244  1871.091064  2322.714600  2076.274414    0.949516      0  znak
# 1  3192.312744  1373.636108  3309.839355  1434.549561    0.728924      0  znak
# {'width': 791.58935546875, 'height': 205.183349609375, 's2': 162420.95547020435, 'xmin': 1531.125244140625, 'ymin': 1871.091064453125, 'xmax': 2322.714599609375, 'ymax': 2076.2744140625, 'im_width': 4032, 'im_height': 3024}

# %% [markdown]
# # Перебираем изображения и записываем информацию  о них в файл

# %%
keys = ['width', 'height', 's2', 'xmin', 'ymin', 'xmax', 'ymax','im_width', 'im_height']
pic_data = '..\\avto\\start_dataset\\train'
train_csv = '..\\avto\\start_dataset\\train.csv'  #данные датасета
new_train_csv = '..\\avto\\start_dataset\\my_train_new.csv'  #сюда придет результат

#сначала прочитаем все данные нам растояния
dist = dict()  #здесь будем храть все расстояния добытые из файла
with open(train_csv, 'r', encoding='utf-8') as file:
    for line in file:
        line = line.replace('\n','')
        key, d = line.split(';')
        dist[key] = d

new_f = 'file;dist;'+';'.join(keys)
#print(new_f)
not_recognize = []
n = 0
for f in os.listdir(pic_data):
    n +=1
        
    work_file = os.path.join(pic_data, f)
    print(n,'работаем  с файлом: ',work_file)
    znak = res(work_file)
    
    if len(znak) == 3:
        print('ФАЙЛ НЕ РАСПОЗНАН')
        not_recognize.append(f)
        continue
    #формируем строку с параметрами знака для записи в csv
   
    st = f'{f};{dist[f]}'
    for k in keys:
        if k in znak:
            st += ';' + str(znak[k])
        else:
            st += ';' + str(0)
    #добавляем распознаное
    #d = file_recognition(work_file)
    #st += ';' + str(d)
    
    
    new_f = new_f +'\n'+st
    
#print(new_f)
with open(new_train_csv, 'w', encoding = 'utf-8') as file:
    file.write(new_f)
print('не распознано файлов', len(not_recognize))
print('не распознанные', *not_recognize)
print('сохранено в ',new_train_csv)
# Out:
# 1 работаем  с файлом:  ..\avto\start_dataset\train\img_1596.jpg
# 2 работаем  с файлом:  ..\avto\start_dataset\train\img_1600.jpg
# 3 работаем  с файлом:  ..\avto\start_dataset\train\img_1601.jpg
# 4 работаем  с файлом:  ..\avto\start_dataset\train\img_1603.jpg
# 5 работаем  с файлом:  ..\avto\start_dataset\train\img_1605.jpg
# 6 работаем  с файлом:  ..\avto\start_dataset\train\img_1606.jpg
# 7 работаем  с файлом:  ..\avto\start_dataset\train\img_1607.jpg
# 8 работаем  с файлом:  ..\avto\start_dataset\train\img_1608.jpg
# 9 работаем  с файлом:  ..\avto\start_dataset\train\img_1612.jpg
# 10 работаем  с файлом:  ..\avto\start_dataset\train\img_1613.jpg
# 11 работаем  с файлом:  ..\avto\start_dataset\train\img_1615.jpg
# 12 работаем  с файлом:  ..\avto\start_dataset\train\img_1616.jpg
# 13 работаем  с файлом:  ..\avto\start_dataset\train\img_1618.jpg
# 14 работаем  с файлом:  ..\avto\start_dataset\train\img_1619.jpg
# 15 работаем  с файлом:  ..\avto\start_dataset\train\img_1620.jpg
# 16 работаем  с файлом:  ..\avto\start_dataset\train\img_1621.jpg
# 17 работаем  с файлом:  ..\avto\start_dataset\train\img_1623.jpg
# 18 работаем  с файлом:  ..\avto\start_dataset\train\img_1626.jpg
# 19 работаем  с файлом:  ..\avto\start_dataset\train\img_1627.jpg
# 20 работаем  с файлом:  ..\avto\start_dataset\train\img_1628.jpg
# 21 работаем  с файлом:  ..\avto\start_dataset\train\img_1631.jpg
# 22 работаем  с файлом:  ..\avto\start_dataset\train\img_1634.jpg
# 23 работаем  с файлом:  ..\avto\start_dataset\train\img_1635.jpg
# 24 работаем  с файлом:  ..\avto\start_dataset\train\img_1637.jpg
# 25 работаем  с файлом:  ..\avto\start_dataset\train\img_1640.jpg
# 26 работаем  с файлом:  ..\avto\start_dataset\train\img_1641.jpg
# 27 работаем  с файлом:  ..\avto\start_dataset\train\img_1643.jpg
# 28 работаем  с файлом:  ..\avto\start_dataset\train\img_1645.jpg
# 29 работаем  с файлом:  ..\avto\start_dataset\train\img_1647.jpg
# 30 работаем  с файлом:  ..\avto\start_dataset\train\img_1649.jpg
# 31 работаем  с файлом:  ..\avto\start_dataset\train\img_1650.jpg
# 32 работаем  с файлом:  ..\avto\start_dataset\train\img_1653.jpg
# 33 работаем  с файлом:  ..\avto\start_dataset\train\img_1656.jpg
# 34 работаем  с файлом:  ..\avto\start_dataset\train\img_1658.jpg
# 35 работаем  с файлом:  ..\avto\start_dataset\train\img_1662.jpg
# 36 работаем  с файлом:  ..\avto\start_dataset\train\img_1665.jpg
# 37 работаем  с файлом:  ..\avto\start_dataset\train\img_1666.jpg
# 38 работаем  с файлом:  ..\avto\start_dataset\train\img_1667.jpg
# 39 работаем  с файлом:  ..\avto\start_dataset\train\img_1672.jpg
# 40 работаем  с файлом:  ..\avto\start_dataset\train\img_1673.jpg
# 41 работаем  с файлом:  ..\avto\start_dataset\train\img_1674.jpg
# 42 работаем  с файлом:  ..\avto\start_dataset\train\img_1675.jpg
# 43 работаем  с файлом:  ..\avto\start_dataset\train\img_1676.jpg
# 44 работаем  с файлом:  ..\avto\start_dataset\train\img_1677.jpg
# 45 работаем  с файлом:  ..\avto\start_dataset\train\img_1680.jpg
# 46 работаем  с файлом:  ..\avto\start_dataset\train\img_1681.jpg
# 47 работаем  с файлом:  ..\avto\start_dataset\train\img_1684.jpg
# 48 работаем  с файлом:  ..\avto\start_dataset\train\img_1685.jpg
# 49 работаем  с файлом:  ..\avto\start_dataset\train\img_1686.jpg
# 50 работаем  с файлом:  ..\avto\start_dataset\train\img_1687.jpg
# 51 работаем  с файлом:  ..\avto\start_dataset\train\img_1688.jpg
# 52 работаем  с файлом:  ..\avto\start_dataset\train\img_1690.jpg
# 53 работаем  с файлом:  ..\avto\start_dataset\train\img_1691.jpg
# 54 работаем  с файлом:  ..\avto\start_dataset\train\img_1692.jpg
# 55 работаем  с файлом:  ..\avto\start_dataset\train\img_1696.jpg
# 56 работаем  с файлом:  ..\avto\start_dataset\train\img_1700.jpg
# 57 работаем  с файлом:  ..\avto\start_dataset\train\img_1707.jpg
# 58 работаем  с файлом:  ..\avto\start_dataset\train\img_1708.jpg
# 59 работаем  с файлом:  ..\avto\start_dataset\train\img_1709.jpg
# 60 работаем  с файлом:  ..\avto\start_dataset\train\img_1711.jpg
# 61 работаем  с файлом:  ..\avto\start_dataset\train\img_1712.jpg
# 62 работаем  с файлом:  ..\avto\start_dataset\train\img_1713.jpg
# 63 работаем  с файлом:  ..\avto\start_dataset\train\img_1714.jpg
# 64 работаем  с файлом:  ..\avto\start_dataset\train\img_1715.jpg
# 65 работаем  с файлом:  ..\avto\start_dataset\train\img_1818.jpg
# 66 работаем  с файлом:  ..\avto\start_dataset\train\img_1820.jpg
# 67 работаем  с файлом:  ..\avto\start_dataset\train\img_1822.jpg
# 68 работаем  с файлом:  ..\avto\start_dataset\train\img_1824.jpg
# 69 работаем  с файлом:  ..\avto\start_dataset\train\img_1827.jpg
# 70 работаем  с файлом:  ..\avto\start_dataset\train\img_1829.jpg
# 71 работаем  с файлом:  ..\avto\start_dataset\train\img_1831.jpg
# 72 работаем  с файлом:  ..\avto\start_dataset\train\img_1832.jpg
# 73 работаем  с файлом:  ..\avto\start_dataset\train\img_1834.jpg
# 74 работаем  с файлом:  ..\avto\start_dataset\train\img_1835.jpg
# 75 работаем  с файлом:  ..\avto\start_dataset\train\img_1837.jpg
# 76 работаем  с файлом:  ..\avto\start_dataset\train\img_1838.jpg
# 77 работаем  с файлом:  ..\avto\start_dataset\train\img_1841.jpg
# 78 работаем  с файлом:  ..\avto\start_dataset\train\img_1845.jpg
# 79 работаем  с файлом:  ..\avto\start_dataset\train\img_1847.jpg
# 80 работаем  с файлом:  ..\avto\start_dataset\train\img_1848.jpg
# 81 работаем  с файлом:  ..\avto\start_dataset\train\img_1850.jpg
# 82 работаем  с файлом:  ..\avto\start_dataset\train\img_1853.jpg
# 83 работаем  с файлом:  ..\avto\start_dataset\train\img_1854.jpg
# 84 работаем  с файлом:  ..\avto\start_dataset\train\img_1856.jpg
# 85 работаем  с файлом:  ..\avto\start_dataset\train\img_1857.jpg
# 86 работаем  с файлом:  ..\avto\start_dataset\train\img_1860.jpg
# 87 работаем  с файлом:  ..\avto\start_dataset\train\img_1861.jpg
# 88 работаем  с файлом:  ..\avto\start_dataset\train\img_1862.jpg
# 89 работаем  с файлом:  ..\avto\start_dataset\train\img_1863.jpg
# 90 работаем  с файлом:  ..\avto\start_dataset\train\img_1864.jpg
# 91 работаем  с файлом:  ..\avto\start_dataset\train\img_1865.jpg
# 92 работаем  с файлом:  ..\avto\start_dataset\train\img_1874.jpg
# 93 работаем  с файлом:  ..\avto\start_dataset\train\img_1878.jpg
# 94 работаем  с файлом:  ..\avto\start_dataset\train\img_1881.jpg
# 95 работаем  с файлом:  ..\avto\start_dataset\train\img_1882.jpg
# 96 работаем  с файлом:  ..\avto\start_dataset\train\img_1883.jpg
# 97 работаем  с файлом:  ..\avto\start_dataset\train\img_1885.jpg
# 98 работаем  с файлом:  ..\avto\start_dataset\train\img_1886.jpg
# 99 работаем  с файлом:  ..\avto\start_dataset\train\img_1887.jpg
# 100 работаем  с файлом:  ..\avto\start_dataset\train\img_1890.jpg
# 101 работаем  с файлом:  ..\avto\start_dataset\train\img_1893.jpg
# 102 работаем  с файлом:  ..\avto\start_dataset\train\img_1896.jpg
# 103 работаем  с файлом:  ..\avto\start_dataset\train\img_1899.jpg
# 104 работаем  с файлом:  ..\avto\start_dataset\train\img_1901.jpg
# 105 работаем  с файлом:  ..\avto\start_dataset\train\img_1902.jpg
# 106 работаем  с файлом:  ..\avto\start_dataset\train\img_1903.jpg
# 107 работаем  с файлом:  ..\avto\start_dataset\train\img_1907.jpg
# 108 работаем  с файлом:  ..\avto\start_dataset\train\img_1909.jpg
# 109 работаем  с файлом:  ..\avto\start_dataset\train\img_1910.jpg
# 110 работаем  с файлом:  ..\avto\start_dataset\train\img_1912.jpg
# 111 работаем  с файлом:  ..\avto\start_dataset\train\img_1916.jpg
# 112 работаем  с файлом:  ..\avto\start_dataset\train\img_1918.jpg
# 113 работаем  с файлом:  ..\avto\start_dataset\train\img_1921.jpg
# 114 работаем  с файлом:  ..\avto\start_dataset\train\img_1922.jpg
# 115 работаем  с файлом:  ..\avto\start_dataset\train\img_1924.jpg
# 116 работаем  с файлом:  ..\avto\start_dataset\train\img_1925.jpg
# 117 работаем  с файлом:  ..\avto\start_dataset\train\img_1926.jpg
# 118 работаем  с файлом:  ..\avto\start_dataset\train\img_1927.jpg
# 119 работаем  с файлом:  ..\avto\start_dataset\train\img_1929.jpg
# 120 работаем  с файлом:  ..\avto\start_dataset\train\img_1930.jpg
# 121 работаем  с файлом:  ..\avto\start_dataset\train\img_1932.jpg
# 122 работаем  с файлом:  ..\avto\start_dataset\train\img_1933.jpg
# 123 работаем  с файлом:  ..\avto\start_dataset\train\img_1937.jpg
# 124 работаем  с файлом:  ..\avto\start_dataset\train\img_1938.jpg
# 125 работаем  с файлом:  ..\avto\start_dataset\train\img_1939.jpg
# 126 работаем  с файлом:  ..\avto\start_dataset\train\img_1945.jpg
# 127 работаем  с файлом:  ..\avto\start_dataset\train\img_1948.jpg
# 128 работаем  с файлом:  ..\avto\start_dataset\train\img_1950.jpg
# 129 работаем  с файлом:  ..\avto\start_dataset\train\img_1951.jpg
# 130 работаем  с файлом:  ..\avto\start_dataset\train\img_1958.jpg
# 131 работаем  с файлом:  ..\avto\start_dataset\train\img_1959.jpg
# 132 работаем  с файлом:  ..\avto\start_dataset\train\img_1963.jpg
# 133 работаем  с файлом:  ..\avto\start_dataset\train\img_1964.jpg
# 134 работаем  с файлом:  ..\avto\start_dataset\train\img_1965.jpg
# 135 работаем  с файлом:  ..\avto\start_dataset\train\img_1966.jpg
# 136 работаем  с файлом:  ..\avto\start_dataset\train\img_1967.jpg
# 137 работаем  с файлом:  ..\avto\start_dataset\train\img_1968.jpg
# 138 работаем  с файлом:  ..\avto\start_dataset\train\img_1970.jpg
# 139 работаем  с файлом:  ..\avto\start_dataset\train\img_1971.jpg
# 140 работаем  с файлом:  ..\avto\start_dataset\train\img_1973.jpg
# 141 работаем  с файлом:  ..\avto\start_dataset\train\img_1976.jpg
# 142 работаем  с файлом:  ..\avto\start_dataset\train\img_1977.jpg
# 143 работаем  с файлом:  ..\avto\start_dataset\train\img_1979.jpg
# 144 работаем  с файлом:  ..\avto\start_dataset\train\img_1980.jpg
# 145 работаем  с файлом:  ..\avto\start_dataset\train\img_1983.jpg
# 146 работаем  с файлом:  ..\avto\start_dataset\train\img_1984.jpg
# 147 работаем  с файлом:  ..\avto\start_dataset\train\img_1985.jpg
# 148 работаем  с файлом:  ..\avto\start_dataset\train\img_1991.jpg
# 149 работаем  с файлом:  ..\avto\start_dataset\train\img_1992.jpg
# 150 работаем  с файлом:  ..\avto\start_dataset\train\img_1994.jpg
# 151 работаем  с файлом:  ..\avto\start_dataset\train\img_1996.jpg
# 152 работаем  с файлом:  ..\avto\start_dataset\train\img_2001.jpg
# 153 работаем  с файлом:  ..\avto\start_dataset\train\img_2002.jpg
# 154 работаем  с файлом:  ..\avto\start_dataset\train\img_2003.jpg
# 155 работаем  с файлом:  ..\avto\start_dataset\train\img_2005.jpg
# 156 работаем  с файлом:  ..\avto\start_dataset\train\img_2007.jpg
# 157 работаем  с файлом:  ..\avto\start_dataset\train\img_2008.jpg
# 158 работаем  с файлом:  ..\avto\start_dataset\train\img_2010.jpg
# 159 работаем  с файлом:  ..\avto\start_dataset\train\img_2012.jpg
# 160 работаем  с файлом:  ..\avto\start_dataset\train\img_2014.jpg
# 161 работаем  с файлом:  ..\avto\start_dataset\train\img_2016.jpg
# 162 работаем  с файлом:  ..\avto\start_dataset\train\img_2018.jpg
# 163 работаем  с файлом:  ..\avto\start_dataset\train\img_2021.jpg
# 164 работаем  с файлом:  ..\avto\start_dataset\train\img_2025.jpg
# 165 работаем  с файлом:  ..\avto\start_dataset\train\img_2026.jpg
# 166 работаем  с файлом:  ..\avto\start_dataset\train\img_2027.jpg
# 167 работаем  с файлом:  ..\avto\start_dataset\train\img_2030.jpg
# 168 работаем  с файлом:  ..\avto\start_dataset\train\img_2254.jpg
# 169 работаем  с файлом:  ..\avto\start_dataset\train\img_2255.jpg
# 170 работаем  с файлом:  ..\avto\start_dataset\train\img_2256.jpg
# 171 работаем  с файлом:  ..\avto\start_dataset\train\img_2260.jpg
# 172 работаем  с файлом:  ..\avto\start_dataset\train\img_2261.jpg
# 173 работаем  с файлом:  ..\avto\start_dataset\train\img_2264.jpg
# 174 работаем  с файлом:  ..\avto\start_dataset\train\img_2266.jpg
# 175 работаем  с файлом:  ..\avto\start_dataset\train\img_2268.jpg
# 176 работаем  с файлом:  ..\avto\start_dataset\train\img_2269.jpg
# 177 работаем  с файлом:  ..\avto\start_dataset\train\img_2270.jpg
# 178 работаем  с файлом:  ..\avto\start_dataset\train\img_2271.jpg
# 179 работаем  с файлом:  ..\avto\start_dataset\train\img_2272.jpg
# 180 работаем  с файлом:  ..\avto\start_dataset\train\img_2275.jpg
# 181 работаем  с файлом:  ..\avto\start_dataset\train\img_2277.jpg
# 182 работаем  с файлом:  ..\avto\start_dataset\train\img_2278.jpg
# 183 работаем  с файлом:  ..\avto\start_dataset\train\img_2280.jpg
# 184 работаем  с файлом:  ..\avto\start_dataset\train\img_2282.jpg
# 185 работаем  с файлом:  ..\avto\start_dataset\train\img_2285.jpg
# 186 работаем  с файлом:  ..\avto\start_dataset\train\img_2287.jpg
# 187 работаем  с файлом:  ..\avto\start_dataset\train\img_2289.jpg
# 188 работаем  с файлом:  ..\avto\start_dataset\train\img_2290.jpg
# 189 работаем  с файлом:  ..\avto\start_dataset\train\img_2291.jpg
# 190 работаем  с файлом:  ..\avto\start_dataset\train\img_2294.jpg
# 191 работаем  с файлом:  ..\avto\start_dataset\train\img_2295.jpg
# 192 работаем  с файлом:  ..\avto\start_dataset\train\img_2296.jpg
# 193 работаем  с файлом:  ..\avto\start_dataset\train\img_2297.jpg
# 194 работаем  с файлом:  ..\avto\start_dataset\train\img_2300.jpg
# 195 работаем  с файлом:  ..\avto\start_dataset\train\img_2301.jpg
# 196 работаем  с файлом:  ..\avto\start_dataset\train\img_2302.jpg
# 197 работаем  с файлом:  ..\avto\start_dataset\train\img_2304.jpg
# 198 работаем  с файлом:  ..\avto\start_dataset\train\img_2305.jpg
# 199 работаем  с файлом:  ..\avto\start_dataset\train\img_2306.jpg
# 200 работаем  с файлом:  ..\avto\start_dataset\train\img_2308.jpg
# 201 работаем  с файлом:  ..\avto\start_dataset\train\img_2309.jpg
# 202 работаем  с файлом:  ..\avto\start_dataset\train\img_2310.jpg
# 203 работаем  с файлом:  ..\avto\start_dataset\train\img_2313.jpg
# 204 работаем  с файлом:  ..\avto\start_dataset\train\img_2316.jpg
# 205 работаем  с файлом:  ..\avto\start_dataset\train\img_2319.jpg
# 206 работаем  с файлом:  ..\avto\start_dataset\train\img_2320.jpg
# 207 работаем  с файлом:  ..\avto\start_dataset\train\img_2321.jpg
# 208 работаем  с файлом:  ..\avto\start_dataset\train\img_2322.jpg
# 209 работаем  с файлом:  ..\avto\start_dataset\train\img_2327.jpg
# 210 работаем  с файлом:  ..\avto\start_dataset\train\img_2330.jpg
# 211 работаем  с файлом:  ..\avto\start_dataset\train\img_2331.jpg
# 212 работаем  с файлом:  ..\avto\start_dataset\train\img_2332.jpg
# 213 работаем  с файлом:  ..\avto\start_dataset\train\img_2333.jpg
# 214 работаем  с файлом:  ..\avto\start_dataset\train\img_2336.jpg
# 215 работаем  с файлом:  ..\avto\start_dataset\train\img_2341.jpg
# 216 работаем  с файлом:  ..\avto\start_dataset\train\img_2342.jpg
# 217 работаем  с файлом:  ..\avto\start_dataset\train\img_2344.jpg
# 218 работаем  с файлом:  ..\avto\start_dataset\train\img_2345.jpg
# 219 работаем  с файлом:  ..\avto\start_dataset\train\img_2347.jpg
# 220 работаем  с файлом:  ..\avto\start_dataset\train\img_2350.jpg
# 221 работаем  с файлом:  ..\avto\start_dataset\train\img_2352.jpg
# 222 работаем  с файлом:  ..\avto\start_dataset\train\img_2359.jpg
# 223 работаем  с файлом:  ..\avto\start_dataset\train\img_2361.jpg
# 224 работаем  с файлом:  ..\avto\start_dataset\train\img_2369.jpg
# 225 работаем  с файлом:  ..\avto\start_dataset\train\img_2372.jpg
# 226 работаем  с файлом:  ..\avto\start_dataset\train\img_2373.jpg
# 227 работаем  с файлом:  ..\avto\start_dataset\train\img_2374.jpg
# 228 работаем  с файлом:  ..\avto\start_dataset\train\img_2376.jpg
# 229 работаем  с файлом:  ..\avto\start_dataset\train\img_2378.jpg
# 230 работаем  с файлом:  ..\avto\start_dataset\train\img_2383.jpg
# 231 работаем  с файлом:  ..\avto\start_dataset\train\img_2384.jpg
# 232 работаем  с файлом:  ..\avto\start_dataset\train\img_2385.jpg
# 233 работаем  с файлом:  ..\avto\start_dataset\train\img_2390.jpg
# 234 работаем  с файлом:  ..\avto\start_dataset\train\img_2397.jpg
# 235 работаем  с файлом:  ..\avto\start_dataset\train\img_2398.jpg
# 236 работаем  с файлом:  ..\avto\start_dataset\train\img_2404.jpg
# 237 работаем  с файлом:  ..\avto\start_dataset\train\img_2405.jpg
# 238 работаем  с файлом:  ..\avto\start_dataset\train\img_2406.jpg
# 239 работаем  с файлом:  ..\avto\start_dataset\train\img_2408.jpg
# 240 работаем  с файлом:  ..\avto\start_dataset\train\img_2409.jpg
# 241 работаем  с файлом:  ..\avto\start_dataset\train\img_2410.jpg
# 242 работаем  с файлом:  ..\avto\start_dataset\train\img_2411.jpg
# 243 работаем  с файлом:  ..\avto\start_dataset\train\img_2418.jpg
# 244 работаем  с файлом:  ..\avto\start_dataset\train\img_2420.jpg
# 245 работаем  с файлом:  ..\avto\start_dataset\train\img_2422.jpg
# 246 работаем  с файлом:  ..\avto\start_dataset\train\img_2423.jpg
# 247 работаем  с файлом:  ..\avto\start_dataset\train\img_2426.jpg
# 248 работаем  с файлом:  ..\avto\start_dataset\train\img_2427.jpg
# 249 работаем  с файлом:  ..\avto\start_dataset\train\img_2429.jpg
# 250 работаем  с файлом:  ..\avto\start_dataset\train\img_2430.jpg
# 251 работаем  с файлом:  ..\avto\start_dataset\train\img_2432.jpg
# 252 работаем  с файлом:  ..\avto\start_dataset\train\img_2434.jpg
# 253 работаем  с файлом:  ..\avto\start_dataset\train\img_2436.jpg
# 254 работаем  с файлом:  ..\avto\start_dataset\train\img_2437.jpg
# 255 работаем  с файлом:  ..\avto\start_dataset\train\img_2440.jpg
# 256 работаем  с файлом:  ..\avto\start_dataset\train\img_2442.jpg
# 257 работаем  с файлом:  ..\avto\start_dataset\train\img_2443.jpg
# 258 работаем  с файлом:  ..\avto\start_dataset\train\img_2445.jpg
# 259 работаем  с файлом:  ..\avto\start_dataset\train\img_2449.jpg
# 260 работаем  с файлом:  ..\avto\start_dataset\train\img_2450.jpg
# 261 работаем  с файлом:  ..\avto\start_dataset\train\img_2451.jpg
# 262 работаем  с файлом:  ..\avto\start_dataset\train\img_2452.jpg
# 263 работаем  с файлом:  ..\avto\start_dataset\train\img_2453.jpg
# 264 работаем  с файлом:  ..\avto\start_dataset\train\img_2454.jpg
# 265 работаем  с файлом:  ..\avto\start_dataset\train\img_2455.jpg
# 266 работаем  с файлом:  ..\avto\start_dataset\train\img_2458.jpg
# 267 работаем  с файлом:  ..\avto\start_dataset\train\img_2459.jpg
# 268 работаем  с файлом:  ..\avto\start_dataset\train\img_2460.jpg
# 269 работаем  с файлом:  ..\avto\start_dataset\train\img_2462.jpg
# 270 работаем  с файлом:  ..\avto\start_dataset\train\img_2463.jpg
# 271 работаем  с файлом:  ..\avto\start_dataset\train\img_2468.jpg
# 272 работаем  с файлом:  ..\avto\start_dataset\train\img_2469.jpg
# 273 работаем  с файлом:  ..\avto\start_dataset\train\img_2470.jpg
# 274 работаем  с файлом:  ..\avto\start_dataset\train\img_2474.jpg
# 275 работаем  с файлом:  ..\avto\start_dataset\train\img_2476.jpg
# 276 работаем  с файлом:  ..\avto\start_dataset\train\img_2477.jpg
# 277 работаем  с файлом:  ..\avto\start_dataset\train\img_2480.jpg
# 278 работаем  с файлом:  ..\avto\start_dataset\train\img_2484.jpg
# 279 работаем  с файлом:  ..\avto\start_dataset\train\img_2485.jpg
# 280 работаем  с файлом:  ..\avto\start_dataset\train\img_2487.jpg
# 281 работаем  с файлом:  ..\avto\start_dataset\train\img_2490.jpg
# 282 работаем  с файлом:  ..\avto\start_dataset\train\img_2492.jpg
# 283 работаем  с файлом:  ..\avto\start_dataset\train\img_2494.jpg
# 284 работаем  с файлом:  ..\avto\start_dataset\train\img_2495.jpg
# 285 работаем  с файлом:  ..\avto\start_dataset\train\img_2502.jpg
# 286 работаем  с файлом:  ..\avto\start_dataset\train\img_2503.jpg
# 287 работаем  с файлом:  ..\avto\start_dataset\train\img_2504.jpg
# 288 работаем  с файлом:  ..\avto\start_dataset\train\img_2505.jpg
# 289 работаем  с файлом:  ..\avto\start_dataset\train\img_2507.jpg
# 290 работаем  с файлом:  ..\avto\start_dataset\train\img_2510.jpg
# 291 работаем  с файлом:  ..\avto\start_dataset\train\img_2511.jpg
# 292 работаем  с файлом:  ..\avto\start_dataset\train\img_2512.jpg
# 293 работаем  с файлом:  ..\avto\start_dataset\train\img_2514.jpg
# 294 работаем  с файлом:  ..\avto\start_dataset\train\img_2516.jpg
# 295 работаем  с файлом:  ..\avto\start_dataset\train\img_2519.jpg
# 296 работаем  с файлом:  ..\avto\start_dataset\train\img_2520.jpg
# 297 работаем  с файлом:  ..\avto\start_dataset\train\img_2527.jpg
# 298 работаем  с файлом:  ..\avto\start_dataset\train\img_2528.jpg
# 299 работаем  с файлом:  ..\avto\start_dataset\train\img_2533.jpg
# 300 работаем  с файлом:  ..\avto\start_dataset\train\img_2535.jpg
# 301 работаем  с файлом:  ..\avto\start_dataset\train\img_2536.jpg
# 302 работаем  с файлом:  ..\avto\start_dataset\train\img_2538.jpg
# 303 работаем  с файлом:  ..\avto\start_dataset\train\img_2539.jpg
# 304 работаем  с файлом:  ..\avto\start_dataset\train\img_2544.jpg
# 305 работаем  с файлом:  ..\avto\start_dataset\train\img_2547.jpg
# 306 работаем  с файлом:  ..\avto\start_dataset\train\img_2548.jpg
# 307 работаем  с файлом:  ..\avto\start_dataset\train\img_2549.jpg
# 308 работаем  с файлом:  ..\avto\start_dataset\train\img_2550.jpg
# 309 работаем  с файлом:  ..\avto\start_dataset\train\img_2553.jpg
# 310 работаем  с файлом:  ..\avto\start_dataset\train\img_2554.jpg
# 311 работаем  с файлом:  ..\avto\start_dataset\train\img_2561.jpg
# 312 работаем  с файлом:  ..\avto\start_dataset\train\img_2562.jpg
# 313 работаем  с файлом:  ..\avto\start_dataset\train\img_2563.jpg
# 314 работаем  с файлом:  ..\avto\start_dataset\train\img_2568.jpg
# 315 работаем  с файлом:  ..\avto\start_dataset\train\img_2570.jpg
# 316 работаем  с файлом:  ..\avto\start_dataset\train\img_2574.jpg
# 317 работаем  с файлом:  ..\avto\start_dataset\train\img_2575.jpg
# 318 работаем  с файлом:  ..\avto\start_dataset\train\img_2577.jpg
# 319 работаем  с файлом:  ..\avto\start_dataset\train\img_2578.jpg
# 320 работаем  с файлом:  ..\avto\start_dataset\train\img_2579.jpg
# 321 работаем  с файлом:  ..\avto\start_dataset\train\img_2581.jpg
# 322 работаем  с файлом:  ..\avto\start_dataset\train\img_2583.jpg
# 323 работаем  с файлом:  ..\avto\start_dataset\train\img_2584.jpg
# 324 работаем  с файлом:  ..\avto\start_dataset\train\img_2586.jpg
# 325 работаем  с файлом:  ..\avto\start_dataset\train\img_2588.jpg
# 326 работаем  с файлом:  ..\avto\start_dataset\train\img_2590.jpg
# 327 работаем  с файлом:  ..\avto\start_dataset\train\img_2593.jpg
# 328 работаем  с файлом:  ..\avto\start_dataset\train\img_2597.jpg
# 329 работаем  с файлом:  ..\avto\start_dataset\train\img_2600.jpg
# 330 работаем  с файлом:  ..\avto\start_dataset\train\img_2601.jpg
# 331 работаем  с файлом:  ..\avto\start_dataset\train\img_2604.jpg
# 332 работаем  с файлом:  ..\avto\start_dataset\train\img_2608.jpg
# 333 работаем  с файлом:  ..\avto\start_dataset\train\img_2613.jpg
# 334 работаем  с файлом:  ..\avto\start_dataset\train\img_2614.jpg
# 335 работаем  с файлом:  ..\avto\start_dataset\train\img_2615.jpg
# 336 работаем  с файлом:  ..\avto\start_dataset\train\img_2620.jpg
# 337 работаем  с файлом:  ..\avto\start_dataset\train\img_2621.jpg
# 338 работаем  с файлом:  ..\avto\start_dataset\train\img_2623.jpg
# 339 работаем  с файлом:  ..\avto\start_dataset\train\img_2624.jpg
# 340 работаем  с файлом:  ..\avto\start_dataset\train\img_2625.jpg
# 341 работаем  с файлом:  ..\avto\start_dataset\train\img_2627.jpg
# 342 работаем  с файлом:  ..\avto\start_dataset\train\img_2629.jpg
# 343 работаем  с файлом:  ..\avto\start_dataset\train\img_2630.jpg
# 344 работаем  с файлом:  ..\avto\start_dataset\train\img_2631.jpg
# 345 работаем  с файлом:  ..\avto\start_dataset\train\img_2634.jpg
# 346 работаем  с файлом:  ..\avto\start_dataset\train\img_2635.jpg
# 347 работаем  с файлом:  ..\avto\start_dataset\train\img_2636.jpg
# 348 работаем  с файлом:  ..\avto\start_dataset\train\img_2638.jpg
# 349 работаем  с файлом:  ..\avto\start_dataset\train\img_2639.jpg
# 350 работаем  с файлом:  ..\avto\start_dataset\train\img_2642.jpg
# 351 работаем  с файлом:  ..\avto\start_dataset\train\img_2643.jpg
# 352 работаем  с файлом:  ..\avto\start_dataset\train\img_2645.jpg
# 353 работаем  с файлом:  ..\avto\start_dataset\train\img_2646.jpg
# 354 работаем  с файлом:  ..\avto\start_dataset\train\img_2648.jpg
# 355 работаем  с файлом:  ..\avto\start_dataset\train\img_2650.jpg
# 356 работаем  с файлом:  ..\avto\start_dataset\train\img_2651.jpg
# 357 работаем  с файлом:  ..\avto\start_dataset\train\img_2654.jpg
# 358 работаем  с файлом:  ..\avto\start_dataset\train\img_2656.jpg
# 359 работаем  с файлом:  ..\avto\start_dataset\train\img_2657.jpg
# 360 работаем  с файлом:  ..\avto\start_dataset\train\img_2658.jpg
# 361 работаем  с файлом:  ..\avto\start_dataset\train\img_2659.jpg
# 362 работаем  с файлом:  ..\avto\start_dataset\train\img_2660.jpg
# 363 работаем  с файлом:  ..\avto\start_dataset\train\img_2664.jpg
# 364 работаем  с файлом:  ..\avto\start_dataset\train\img_2665.jpg
# 365 работаем  с файлом:  ..\avto\start_dataset\train\img_2666.jpg
# 366 работаем  с файлом:  ..\avto\start_dataset\train\img_2667.jpg
# 367 работаем  с файлом:  ..\avto\start_dataset\train\img_2669.jpg
# 368 работаем  с файлом:  ..\avto\start_dataset\train\img_2671.jpg
# 369 работаем  с файлом:  ..\avto\start_dataset\train\img_2672.heic
# 370 работаем  с файлом:  ..\avto\start_dataset\train\img_2672.jpg
# 371 работаем  с файлом:  ..\avto\start_dataset\train\img_2673.heic
# 372 работаем  с файлом:  ..\avto\start_dataset\train\img_2673.jpg
# 373 работаем  с файлом:  ..\avto\start_dataset\train\img_2674.jpg
# 374 работаем  с файлом:  ..\avto\start_dataset\train\img_2675.heic
# 375 работаем  с файлом:  ..\avto\start_dataset\train\img_2676.heic
# 376 работаем  с файлом:  ..\avto\start_dataset\train\img_2678.heic
# 377 работаем  с файлом:  ..\avto\start_dataset\train\img_2680.heic
# 378 работаем  с файлом:  ..\avto\start_dataset\train\img_2681.heic
# 379 работаем  с файлом:  ..\avto\start_dataset\train\img_2681.jpg
# 380 работаем  с файлом:  ..\avto\start_dataset\train\img_2682.heic
# 381 работаем  с файлом:  ..\avto\start_dataset\train\img_2682.jpg
# 382 работаем  с файлом:  ..\avto\start_dataset\train\img_2683.heic
# 383 работаем  с файлом:  ..\avto\start_dataset\train\img_2683.jpg
# 384 работаем  с файлом:  ..\avto\start_dataset\train\img_2684.jpg
# 385 работаем  с файлом:  ..\avto\start_dataset\train\img_2685.heic
# 386 работаем  с файлом:  ..\avto\start_dataset\train\img_2686.jpg
# 387 работаем  с файлом:  ..\avto\start_dataset\train\img_2687.heic
# 388 работаем  с файлом:  ..\avto\start_dataset\train\img_2688.heic
# 389 работаем  с файлом:  ..\avto\start_dataset\train\img_2688.jpg
# 390 работаем  с файлом:  ..\avto\start_dataset\train\img_2690.heic
# 391 работаем  с файлом:  ..\avto\start_dataset\train\img_2690.jpg
# 392 работаем  с файлом:  ..\avto\start_dataset\train\img_2691.heic
# 393 работаем  с файлом:  ..\avto\start_dataset\train\img_2691.jpg
# 394 работаем  с файлом:  ..\avto\start_dataset\train\img_2694.heic
# 395 работаем  с файлом:  ..\avto\start_dataset\train\img_2694.jpg
# 396 работаем  с файлом:  ..\avto\start_dataset\train\img_2695.heic
# 397 работаем  с файлом:  ..\avto\start_dataset\train\img_2696.heic
# 398 работаем  с файлом:  ..\avto\start_dataset\train\img_2699.heic
# 399 работаем  с файлом:  ..\avto\start_dataset\train\img_2700.heic
# 400 работаем  с файлом:  ..\avto\start_dataset\train\img_2701.heic
# 401 работаем  с файлом:  ..\avto\start_dataset\train\img_2704.jpg
# 402 работаем  с файлом:  ..\avto\start_dataset\train\img_2705.heic
# 403 работаем  с файлом:  ..\avto\start_dataset\train\img_2705.jpg
# 404 работаем  с файлом:  ..\avto\start_dataset\train\img_2706.jpg
# 405 работаем  с файлом:  ..\avto\start_dataset\train\img_2707.jpg
# 406 работаем  с файлом:  ..\avto\start_dataset\train\img_2708.jpg
# 407 работаем  с файлом:  ..\avto\start_dataset\train\img_2709.heic
# 408 работаем  с файлом:  ..\avto\start_dataset\train\img_2709.jpg
# 409 работаем  с файлом:  ..\avto\start_dataset\train\img_2710.heic
# 410 работаем  с файлом:  ..\avto\start_dataset\train\img_2712.jpg
# 411 работаем  с файлом:  ..\avto\start_dataset\train\img_2713.jpg
# 412 работаем  с файлом:  ..\avto\start_dataset\train\img_2714.heic
# 413 работаем  с файлом:  ..\avto\start_dataset\train\img_2716.jpg
# 414 работаем  с файлом:  ..\avto\start_dataset\train\img_2721.heic
# 415 работаем  с файлом:  ..\avto\start_dataset\train\img_2721.jpg
# 416 работаем  с файлом:  ..\avto\start_dataset\train\img_2722.heic
# 417 работаем  с файлом:  ..\avto\start_dataset\train\img_2723.heic
# 418 работаем  с файлом:  ..\avto\start_dataset\train\img_2723.jpg
# 419 работаем  с файлом:  ..\avto\start_dataset\train\img_2724.heic
# 420 работаем  с файлом:  ..\avto\start_dataset\train\img_2725.jpg
# 421 работаем  с файлом:  ..\avto\start_dataset\train\img_2726.heic
# 422 работаем  с файлом:  ..\avto\start_dataset\train\img_2727.heic
# 423 работаем  с файлом:  ..\avto\start_dataset\train\img_2728.jpg
# 424 работаем  с файлом:  ..\avto\start_dataset\train\img_2729.heic
# 425 работаем  с файлом:  ..\avto\start_dataset\train\img_2730.heic
# 426 работаем  с файлом:  ..\avto\start_dataset\train\img_2730.jpg
# 427 работаем  с файлом:  ..\avto\start_dataset\train\img_2732.jpg
# 428 работаем  с файлом:  ..\avto\start_dataset\train\img_2733.heic
# 429 работаем  с файлом:  ..\avto\start_dataset\train\img_2734.heic
# 430 работаем  с файлом:  ..\avto\start_dataset\train\img_2735.heic
# 431 работаем  с файлом:  ..\avto\start_dataset\train\img_2735.jpg
# 432 работаем  с файлом:  ..\avto\start_dataset\train\img_2737.heic
# 433 работаем  с файлом:  ..\avto\start_dataset\train\img_2737.jpg
# 434 работаем  с файлом:  ..\avto\start_dataset\train\img_2738.heic
# 435 работаем  с файлом:  ..\avto\start_dataset\train\img_2739.jpg
# 436 работаем  с файлом:  ..\avto\start_dataset\train\img_2740.heic
# 437 работаем  с файлом:  ..\avto\start_dataset\train\img_2741.jpg
# 438 работаем  с файлом:  ..\avto\start_dataset\train\img_2742.jpg
# 439 работаем  с файлом:  ..\avto\start_dataset\train\img_2743.heic
# 440 работаем  с файлом:  ..\avto\start_dataset\train\img_2743.jpg
# 441 работаем  с файлом:  ..\avto\start_dataset\train\img_2744.heic
# 442 работаем  с файлом:  ..\avto\start_dataset\train\img_2745.heic
# 443 работаем  с файлом:  ..\avto\start_dataset\train\img_2745.jpg
# 444 работаем  с файлом:  ..\avto\start_dataset\train\img_2746.heic
# 445 работаем  с файлом:  ..\avto\start_dataset\train\img_2747.heic
# 446 работаем  с файлом:  ..\avto\start_dataset\train\img_2747.jpg
# 447 работаем  с файлом:  ..\avto\start_dataset\train\img_2748.heic
# 448 работаем  с файлом:  ..\avto\start_dataset\train\img_2748.jpg
# 449 работаем  с файлом:  ..\avto\start_dataset\train\img_2749.heic
# 450 работаем  с файлом:  ..\avto\start_dataset\train\img_2750.jpg
# 451 работаем  с файлом:  ..\avto\start_dataset\train\img_2751.heic
# 452 работаем  с файлом:  ..\avto\start_dataset\train\img_2751.jpg
# 453 работаем  с файлом:  ..\avto\start_dataset\train\img_2754.heic
# 454 работаем  с файлом:  ..\avto\start_dataset\train\img_2755.jpg
# 455 работаем  с файлом:  ..\avto\start_dataset\train\img_2756.heic
# 456 работаем  с файлом:  ..\avto\start_dataset\train\img_2760.jpg
# 457 работаем  с файлом:  ..\avto\start_dataset\train\img_2763.jpg
# 458 работаем  с файлом:  ..\avto\start_dataset\train\img_2764.jpg
# 459 работаем  с файлом:  ..\avto\start_dataset\train\img_2765.jpg
# 460 работаем  с файлом:  ..\avto\start_dataset\train\img_2766.jpg
# 461 работаем  с файлом:  ..\avto\start_dataset\train\img_2767.jpg
# 462 работаем  с файлом:  ..\avto\start_dataset\train\img_2770.jpg
# 463 работаем  с файлом:  ..\avto\start_dataset\train\img_2774.jpg
# 464 работаем  с файлом:  ..\avto\start_dataset\train\img_2775.jpg
# 465 работаем  с файлом:  ..\avto\start_dataset\train\img_2779.jpg
# 466 работаем  с файлом:  ..\avto\start_dataset\train\img_2780.jpg
# 467 работаем  с файлом:  ..\avto\start_dataset\train\img_2783.jpg
# 468 работаем  с файлом:  ..\avto\start_dataset\train\img_2786.jpg
# 469 работаем  с файлом:  ..\avto\start_dataset\train\img_2787.jpg
# 470 работаем  с файлом:  ..\avto\start_dataset\train\img_2788.jpg
# 471 работаем  с файлом:  ..\avto\start_dataset\train\img_2789.jpg
# 472 работаем  с файлом:  ..\avto\start_dataset\train\img_2791.jpg
# 473 работаем  с файлом:  ..\avto\start_dataset\train\img_2792.jpg
# 474 работаем  с файлом:  ..\avto\start_dataset\train\img_2793.jpg
# 475 работаем  с файлом:  ..\avto\start_dataset\train\img_2794.jpg
# 476 работаем  с файлом:  ..\avto\start_dataset\train\img_2795.jpg
# 477 работаем  с файлом:  ..\avto\start_dataset\train\img_2796.jpg
# 478 работаем  с файлом:  ..\avto\start_dataset\train\img_2797.jpg
# 479 работаем  с файлом:  ..\avto\start_dataset\train\img_2799.jpg
# 480 работаем  с файлом:  ..\avto\start_dataset\train\img_2857.jpg
# 481 работаем  с файлом:  ..\avto\start_dataset\train\img_2858.jpg
# 482 работаем  с файлом:  ..\avto\start_dataset\train\img_2860.jpg
# 483 работаем  с файлом:  ..\avto\start_dataset\train\img_2861.jpg
# 484 работаем  с файлом:  ..\avto\start_dataset\train\img_2862.jpg
# 485 работаем  с файлом:  ..\avto\start_dataset\train\img_2863.jpg
# 486 работаем  с файлом:  ..\avto\start_dataset\train\img_2866.jpg
# 487 работаем  с файлом:  ..\avto\start_dataset\train\img_2867.jpg
# 488 работаем  с файлом:  ..\avto\start_dataset\train\img_2869.jpg
# 489 работаем  с файлом:  ..\avto\start_dataset\train\img_2870.jpg
# 490 работаем  с файлом:  ..\avto\start_dataset\train\img_2872.jpg
# 491 работаем  с файлом:  ..\avto\start_dataset\train\img_2874.jpg
# 492 работаем  с файлом:  ..\avto\start_dataset\train\img_2876.jpg
# 493 работаем  с файлом:  ..\avto\start_dataset\train\img_2879.jpg
# 494 работаем  с файлом:  ..\avto\start_dataset\train\img_2881.jpg
# 495 работаем  с файлом:  ..\avto\start_dataset\train\img_2882.jpg
# 496 работаем  с файлом:  ..\avto\start_dataset\train\img_2883.jpg
# 497 работаем  с файлом:  ..\avto\start_dataset\train\img_2885.jpg
# 498 работаем  с файлом:  ..\avto\start_dataset\train\img_2890.jpg
# 499 работаем  с файлом:  ..\avto\start_dataset\train\img_2891.jpg
# 500 работаем  с файлом:  ..\avto\start_dataset\train\img_2892.jpg
# 501 работаем  с файлом:  ..\avto\start_dataset\train\img_2894.jpg
# 502 работаем  с файлом:  ..\avto\start_dataset\train\img_2895.jpg
# 503 работаем  с файлом:  ..\avto\start_dataset\train\img_2896.jpg
# 504 работаем  с файлом:  ..\avto\start_dataset\train\img_2897.jpg
# 505 работаем  с файлом:  ..\avto\start_dataset\train\img_2899.jpg
# 506 работаем  с файлом:  ..\avto\start_dataset\train\img_2901.jpg
# 507 работаем  с файлом:  ..\avto\start_dataset\train\img_2902.jpg
# 508 работаем  с файлом:  ..\avto\start_dataset\train\img_2903.jpg
# 509 работаем  с файлом:  ..\avto\start_dataset\train\img_2904.jpg
# 510 работаем  с файлом:  ..\avto\start_dataset\train\img_2905.jpg
# 511 работаем  с файлом:  ..\avto\start_dataset\train\img_2908.jpg
# 512 работаем  с файлом:  ..\avto\start_dataset\train\img_2911.jpg
# 513 работаем  с файлом:  ..\avto\start_dataset\train\img_2912.jpg
# 514 работаем  с файлом:  ..\avto\start_dataset\train\img_2913.jpg
# 515 работаем  с файлом:  ..\avto\start_dataset\train\img_2915.jpg
# 516 работаем  с файлом:  ..\avto\start_dataset\train\img_2916.jpg
# 517 работаем  с файлом:  ..\avto\start_dataset\train\img_2918.jpg
# 518 работаем  с файлом:  ..\avto\start_dataset\train\img_2920.jpg
# 519 работаем  с файлом:  ..\avto\start_dataset\train\img_2927.jpg
# 520 работаем  с файлом:  ..\avto\start_dataset\train\img_2928.jpg
# 521 работаем  с файлом:  ..\avto\start_dataset\train\img_2930.jpg
# 522 работаем  с файлом:  ..\avto\start_dataset\train\img_2931.jpg
# 523 работаем  с файлом:  ..\avto\start_dataset\train\img_2932.jpg
# 524 работаем  с файлом:  ..\avto\start_dataset\train\img_2934.jpg
# 525 работаем  с файлом:  ..\avto\start_dataset\train\img_2937.jpg
# 526 работаем  с файлом:  ..\avto\start_dataset\train\img_2939.jpg
# 527 работаем  с файлом:  ..\avto\start_dataset\train\img_2940.jpg
# 528 работаем  с файлом:  ..\avto\start_dataset\train\img_2941.jpg
# 529 работаем  с файлом:  ..\avto\start_dataset\train\img_2944.jpg
# 530 работаем  с файлом:  ..\avto\start_dataset\train\img_2945.jpg
# не распознано файлов 0
# не распознанные
# сохранено в  ..\avto\start_dataset\my_train_new.csv

# %% [markdown]
# # После обработки, получили файл new_train_csv, где есть расстояние и ширина знака в пикселях. Анализируем это:

# %%
pd = PD.read_csv(new_train_csv,delimiter=';')
pd = pd.sort_values(['dist'] )

# %%
print(pd)
# Out:
#               file  dist       width      height             s2  ...         ymin         xmax         ymax  im_width  im_height
# 480   img_2858.jpg  0.85  961.315308  209.111938  201022.507463  ...  2016.593384  2407.237305  2225.705322      4032       3024
# 76    img_1841.jpg  1.06  786.042725  168.560791  132495.983432  ...  1860.200073  2355.505371  2028.760864      4032       3024
# 479   img_2857.jpg  1.09  791.589355  205.183350  162420.955470  ...  1871.091064  2322.714600  2076.274414      4032       3024
# 19    img_1628.jpg  1.12  993.943359  222.567627  221219.614822  ...  1793.561890  2622.851807  2016.129517      4032       3024
# 151   img_2001.jpg  1.16  740.509399  159.739868  118288.873837  ...  1932.869995  2249.339355  2092.609863      4032       3024
# ..             ...   ...         ...         ...            ...  ...          ...          ...          ...       ...        ...
# 320   img_2581.jpg  8.74   90.658417   41.296143    3743.842904  ...  1671.533813   357.185760  1712.829956      4032       3024
# 416  img_2723.heic  8.78  106.535889   28.271484    3011.927712  ...  1535.093750  1975.258301  1563.365234      4032       3024
# 396  img_2696.heic  8.80  104.339600   25.871216    2699.392300  ...  1538.928467  2022.067139  1564.799683      4032       3024
# 212   img_2333.jpg  9.06   86.117920   20.632812    1776.854895  ...  1483.279053  2292.810791  1503.911865      4032       3024
# 418  img_2724.heic  9.38  104.984375   25.504395    2677.562920  ...  1516.482544  1994.750732  1541.986938      4032       3024
#
# [530 rows x 11 columns]

# %%
pd.sample(5)
# Out:
#               file  dist       width      height            s2  ...         ymin         xmax         ymax  im_width  im_height
# 237   img_2406.jpg  3.75  224.246460   51.197876  11480.942445  ...  1496.687378  1988.623169  1547.885254      4032       3024
# 329   img_2601.jpg  5.83  151.773315   33.918213   5147.879624  ...  1622.825562  1956.122559  1656.743774      4032       3024
# 440  img_2744.heic  2.66  317.836670   63.618408  20220.263009  ...  1504.446045  2088.950195  1568.064453      4032       3024
# 518   img_2927.jpg  4.50  193.047852   47.595947   9188.295363  ...  1352.682373  1981.385132  1400.278320      4032       3024
# 314   img_2570.jpg  2.07  415.149292  108.716919  45133.751928  ...  1676.187744  1978.208008  1784.904663      4032       3024
#
# [5 rows x 11 columns]

# %%
# %matplotlib inline

# %%
#график зависимости расстояния до автомобиля от ширины знака и высоты
width = pd['width'].to_list()
dist = pd['dist'].to_list()
height = pd['height'].to_list()
plt.plot(width,dist,'o')
plt.plot(height,dist,'o')
plt.xlabel("ширина/высота знака в пикселях")
plt.ylabel("расстояние до авто")
plt.show()

# %%
#чистим один параметр. длиную сторону номера
#удаляем выбросы квантилями

width = pd['width'].to_list()
dist = pd['dist'].to_list()
ind = []
step = 50 #скользящее окно. С ним можно ЭКСПЕРИМЕНТИРОВАТЬ. Его ширина влияет на количество убитых точек
for i in range(len(width)-step):
    lit = width[i:i+step] 
    
    q1 = np.quantile(lit, 0.25 )
    q3 = np.quantile(lit, 0.75 )
    med = np.median(lit)
    iqr = q3 - q1
    upper_bound = q3 + ( 1.5 * iqr)
    lower_bound = q1 - ( 1.5 * iqr)
    for j in range(i,i+step):
        if (width[j] >upper_bound) or (width[j] < lower_bound):
            ind.append(j)
            #print(j, width[j], dist[j])
            
ind = list(set(ind))
ind.sort()         
ind.reverse()
for i in ind:
    width.pop(i)
    dist.pop(i)
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(width, dist)
 
# x-axis label
ax.set_xlabel('ширина')
 
# y-axis label
ax.set_ylabel('расстояние')
plt.show()
print('Осталось точек', len(width), len(dist))
# Out:
# Осталось точек 440 440

# %%
#чистим сразу два параметра таким же спосомбом. Решил, что буду искать зависимость от ширины и высоты знака
width = pd['width'].to_list()
dist = pd['dist'].to_list()
height = pd['height'].to_list()
ind = []
step = 40
for i in range(len(dist)-step):
    lit = width[i:i+step] 
    
    q1 = np.quantile(lit, 0.25 )
    q3 = np.quantile(lit, 0.75 )
    med = np.median(lit)
    iqr = q3 - q1
    upper_bound = q3 + ( 1.5 * iqr)
    lower_bound = q1 - ( 1.5 * iqr)
    for j in range(i,i+step):
        if (width[j] >upper_bound) or (width[j] < lower_bound):
            ind.append(j)
            #print(j, width[j], dist[j])
for i in range(len(dist)-step):
    lit = height[i:i+step] 
    
    q1 = np.quantile(lit, 0.25 )
    q3 = np.quantile(lit, 0.75 )
    med = np.median(lit)
    iqr = q3 - q1
    upper_bound = q3 + ( 1.5 * iqr)
    lower_bound = q1 - ( 1.5 * iqr)
    for j in range(i,i+step):
        if (height[j] >upper_bound) or (height[j] < lower_bound):
            ind.append(j)
            
            
            
ind = list(set(ind))
ind.sort()         
ind.reverse()
for i in ind:
    width.pop(i)
    dist.pop(i)
    height.pop(i)
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(width, dist)
ax.scatter(height, dist)
 
# x-axis label
ax.set_xlabel('ширина')
 
# y-axis label
ax.set_ylabel('расстояние')
plt.show()
print(len(width), len(dist))

plt.plot(width,dist,'o')
plt.plot(height,dist,'o')
plt.xlabel("ширина/высота знака в пикселях")
plt.ylabel("расстояние до авто")
plt.show()
# Out:
# 422 422

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(dist,width)
ax.scatter(dist,height)
 
# x-axis label
ax.set_xlabel('расстояние')
 
# y-axis label
ax.set_ylabel('ширины')
plt.show()

# %%
#эта функция делает апросимацию гиперболой по двум заданным  массивам
def mnkGP(x,y): 
    n=len(x) # количество элементов в списках
    s=sum(y) # сумма значений y
    s1=sum([1/x[i] for i in  range(0,n)]) #  сумма 1/x
    s2=sum([(1/x[i])**2 for i in  range(0,n)]) #  сумма (1/x)**2
    s3=sum([y[i]/x[i]  for i in range(0,n)])  # сумма y/x                   
    a= round((s*s2-s1*s3)/(n*s2-s1**2),3) # коэфициент а с тремя дробными цифрами
    b=round((n*s3-s1*s)/(n*s2-s1**2),3)# коэфициент b с тремя дробными цифрами
    s4=[a+b/x[i] for i in range(0,n)] # список значений гиперболической функции              
    so=round(sum([abs(y[i] -s4[i]) for i in range(0,n)])/(n*sum(y))*100,3)   # средняя ошибка аппроксимации
    plt.title('Аппроксимация гиперболой Y='+str(a)+'+'+str(b)+'/x\n Средняя ошибка--'+str(so)+'%',size=14)
    plt.xlabel('Координата X', size=14)
    plt.ylabel('Координата Y', size=14)
    plt.plot(x, y, color='r', linestyle=' ', marker='o', label='Data(x,y)')
    plt.plot(x, s4, color='g', linewidth=2, label='Data(x,f(x)=a+b/x')
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

# %%
mnkGP(width,dist)

# %%
mnkGP(height,dist)

# %% [markdown]
# # Полученную формулу используем для обработки тестового датасета

# %%
import pillow_heif
def conv_heic_to_jpg(file, new_name):

    heif_file = pillow_heif.read_heif(file)
    image = Image.frombytes(
        heif_file.mode,
        heif_file.size,
        heif_file.data,
        "raw",
    )
    
    #new_name = 'Y:\\temp.jpg' #так просто мы меняем расширение
    
    image.save(new_name, format("jpeg"))
    image.close()
    return new_name


keys = ['width', 'height', 's2', 'xmin', 'ymin', 'xmax', 'ymax', 'main_line', 'im_width', 'im_height']
pic_data = '..\\avto\\start_dataset\\test'
train_csv = '..\\avto\\start_dataset\\my_train.csv'
test = '..\\avto\\start_dataset\\sample_solution.csv'

temp_path = 'Y:'

new_f = 'image_name;distance'
#print(new_f)
not_recognize = []
n = 0
for f in os.listdir(pic_data):
    n += 1
#     if n <275:
#         continue
#     if n > 385:
#         break
    work_file = os.path.join(pic_data, f)
    print(n,'работаем  с файлом: ',work_file)
    #ОРИГИНАЛЬНЫЙ ФАЙЛ ТРОГАТ НЕЛЬЗЯ. ИНАЧЕ СОТРЕТСЯ EXIF
    #temp_file = os.path.join(temp_path, f)
    temp_file = f #будем складывать его рядом
    
    if '.heic' in f:
        #temp_file = 'Y:\\tmp.jpg'
        temp_file = 'tmp.jpg'
        conv_heic_to_jpg(work_file, temp_file)
        work_file = temp_file
    
    img = Image.open(work_file)
    img = exif_transpose(img)
    img.save(temp_file)
    
    
    
    
    znak = res(temp_file)
    
    if len(znak) == 3:
        print('ФАЙЛ НЕ РАСПОЗНАН')
        not_recognize.append(f)
        continue
    #формируем строку с параметрами знака для записи в csv
    if 'width' in znak:
        d1 = 888.613 / znak['width'] - 0.129
    else:
        d1 = 0 #не нашли автомобиль
    itog = d1
    #можно попробовать усреднить
    #d2 = 215.216 / znak['height']  - 0.338
    #itog = (d1+d2)/2
    st = f+';' + str(itog)
        
    new_f = new_f +'\n'+st
    
#print(new_f)
with open(test, 'w', encoding = 'utf-8') as file:
    file.write(new_f)
print('не распознано файлов', len(not_recognize))
print('не распознанные', *not_recognize)
# Out:
# 1 работаем  с файлом:  ..\avto\start_dataset\test\img_1597.jpg
# 2 работаем  с файлом:  ..\avto\start_dataset\test\img_1598.jpg
# 3 работаем  с файлом:  ..\avto\start_dataset\test\img_1599.jpg
# 4 работаем  с файлом:  ..\avto\start_dataset\test\img_1602.jpg
# 5 работаем  с файлом:  ..\avto\start_dataset\test\img_1604.jpg
# 6 работаем  с файлом:  ..\avto\start_dataset\test\img_1609.jpg
# 7 работаем  с файлом:  ..\avto\start_dataset\test\img_1610.jpg
# 8 работаем  с файлом:  ..\avto\start_dataset\test\img_1611.jpg
# 9 работаем  с файлом:  ..\avto\start_dataset\test\img_1617.jpg
# 10 работаем  с файлом:  ..\avto\start_dataset\test\img_1622.jpg
# 11 работаем  с файлом:  ..\avto\start_dataset\test\img_1625.jpg
# 12 работаем  с файлом:  ..\avto\start_dataset\test\img_1629.jpg
# 13 работаем  с файлом:  ..\avto\start_dataset\test\img_1630.jpg
# 14 работаем  с файлом:  ..\avto\start_dataset\test\img_1632.jpg
# 15 работаем  с файлом:  ..\avto\start_dataset\test\img_1633.jpg
# 16 работаем  с файлом:  ..\avto\start_dataset\test\img_1636.jpg
# 17 работаем  с файлом:  ..\avto\start_dataset\test\img_1638.jpg
# 18 работаем  с файлом:  ..\avto\start_dataset\test\img_1639.jpg
# 19 работаем  с файлом:  ..\avto\start_dataset\test\img_1642.jpg
# 20 работаем  с файлом:  ..\avto\start_dataset\test\img_1644.jpg
# 21 работаем  с файлом:  ..\avto\start_dataset\test\img_1646.jpg
# 22 работаем  с файлом:  ..\avto\start_dataset\test\img_1648.jpg
# 23 работаем  с файлом:  ..\avto\start_dataset\test\img_1651.jpg
# 24 работаем  с файлом:  ..\avto\start_dataset\test\img_1652.jpg
# 25 работаем  с файлом:  ..\avto\start_dataset\test\img_1654.jpg
# 26 работаем  с файлом:  ..\avto\start_dataset\test\img_1655.jpg
# 27 работаем  с файлом:  ..\avto\start_dataset\test\img_1657.jpg
# 28 работаем  с файлом:  ..\avto\start_dataset\test\img_1659.jpg
# 29 работаем  с файлом:  ..\avto\start_dataset\test\img_1660.jpg
# 30 работаем  с файлом:  ..\avto\start_dataset\test\img_1661.jpg
# 31 работаем  с файлом:  ..\avto\start_dataset\test\img_1663.jpg
# 32 работаем  с файлом:  ..\avto\start_dataset\test\img_1664.jpg
# 33 работаем  с файлом:  ..\avto\start_dataset\test\img_1678.jpg
# 34 работаем  с файлом:  ..\avto\start_dataset\test\img_1679.jpg
# 35 работаем  с файлом:  ..\avto\start_dataset\test\img_1682.jpg
# 36 работаем  с файлом:  ..\avto\start_dataset\test\img_1683.jpg
# 37 работаем  с файлом:  ..\avto\start_dataset\test\img_1689.jpg
# 38 работаем  с файлом:  ..\avto\start_dataset\test\img_1693.jpg
# 39 работаем  с файлом:  ..\avto\start_dataset\test\img_1694.jpg
# 40 работаем  с файлом:  ..\avto\start_dataset\test\img_1695.jpg
# 41 работаем  с файлом:  ..\avto\start_dataset\test\img_1697.jpg
# 42 работаем  с файлом:  ..\avto\start_dataset\test\img_1698.jpg
# 43 работаем  с файлом:  ..\avto\start_dataset\test\img_1699.jpg
# 44 работаем  с файлом:  ..\avto\start_dataset\test\img_1701.jpg
# 45 работаем  с файлом:  ..\avto\start_dataset\test\img_1702.jpg
# 46 работаем  с файлом:  ..\avto\start_dataset\test\img_1703.jpg
# 47 работаем  с файлом:  ..\avto\start_dataset\test\img_1704.jpg
# 48 работаем  с файлом:  ..\avto\start_dataset\test\img_1705.jpg
# 49 работаем  с файлом:  ..\avto\start_dataset\test\img_1706.jpg
# 50 работаем  с файлом:  ..\avto\start_dataset\test\img_1710.jpg
# 51 работаем  с файлом:  ..\avto\start_dataset\test\img_1716.jpg
# 52 работаем  с файлом:  ..\avto\start_dataset\test\img_1717.jpg
# 53 работаем  с файлом:  ..\avto\start_dataset\test\img_1718.jpg
# 54 работаем  с файлом:  ..\avto\start_dataset\test\img_1719.jpg
# 55 работаем  с файлом:  ..\avto\start_dataset\test\img_1720.jpg
# 56 работаем  с файлом:  ..\avto\start_dataset\test\img_1819.jpg
# 57 работаем  с файлом:  ..\avto\start_dataset\test\img_1821.jpg
# 58 работаем  с файлом:  ..\avto\start_dataset\test\img_1823.jpg
# 59 работаем  с файлом:  ..\avto\start_dataset\test\img_1825.jpg
# 60 работаем  с файлом:  ..\avto\start_dataset\test\img_1826.jpg
# 61 работаем  с файлом:  ..\avto\start_dataset\test\img_1828.jpg
# 62 работаем  с файлом:  ..\avto\start_dataset\test\img_1830.jpg
# 63 работаем  с файлом:  ..\avto\start_dataset\test\img_1833.jpg
# 64 работаем  с файлом:  ..\avto\start_dataset\test\img_1836.jpg
# 65 работаем  с файлом:  ..\avto\start_dataset\test\img_1839.jpg
# 66 работаем  с файлом:  ..\avto\start_dataset\test\img_1840.jpg
# 67 работаем  с файлом:  ..\avto\start_dataset\test\img_1842.jpg
# 68 работаем  с файлом:  ..\avto\start_dataset\test\img_1843.jpg
# 69 работаем  с файлом:  ..\avto\start_dataset\test\img_1844.jpg
# 70 работаем  с файлом:  ..\avto\start_dataset\test\img_1846.jpg
# 71 работаем  с файлом:  ..\avto\start_dataset\test\img_1849.jpg
# 72 работаем  с файлом:  ..\avto\start_dataset\test\img_1851.jpg
# 73 работаем  с файлом:  ..\avto\start_dataset\test\img_1852.jpg
# 74 работаем  с файлом:  ..\avto\start_dataset\test\img_1855.jpg
# 75 работаем  с файлом:  ..\avto\start_dataset\test\img_1858.jpg
# 76 работаем  с файлом:  ..\avto\start_dataset\test\img_1859.jpg
# 77 работаем  с файлом:  ..\avto\start_dataset\test\img_1866.jpg
# 78 работаем  с файлом:  ..\avto\start_dataset\test\img_1867.jpg
# 79 работаем  с файлом:  ..\avto\start_dataset\test\img_1868.jpg
# 80 работаем  с файлом:  ..\avto\start_dataset\test\img_1869.jpg
# 81 работаем  с файлом:  ..\avto\start_dataset\test\img_1870.jpg
# 82 работаем  с файлом:  ..\avto\start_dataset\test\img_1871.jpg
# 83 работаем  с файлом:  ..\avto\start_dataset\test\img_1872.jpg
# 84 работаем  с файлом:  ..\avto\start_dataset\test\img_1873.jpg
# 85 работаем  с файлом:  ..\avto\start_dataset\test\img_1875.jpg
# 86 работаем  с файлом:  ..\avto\start_dataset\test\img_1876.jpg
# 87 работаем  с файлом:  ..\avto\start_dataset\test\img_1877.jpg
# 88 работаем  с файлом:  ..\avto\start_dataset\test\img_1879.jpg
# 89 работаем  с файлом:  ..\avto\start_dataset\test\img_1880.jpg
# 90 работаем  с файлом:  ..\avto\start_dataset\test\img_1884.jpg
# 91 работаем  с файлом:  ..\avto\start_dataset\test\img_1888.jpg
# 92 работаем  с файлом:  ..\avto\start_dataset\test\img_1889.jpg
# 93 работаем  с файлом:  ..\avto\start_dataset\test\img_1891.jpg
# 94 работаем  с файлом:  ..\avto\start_dataset\test\img_1892.jpg
# 95 работаем  с файлом:  ..\avto\start_dataset\test\img_1894.jpg
# 96 работаем  с файлом:  ..\avto\start_dataset\test\img_1895.jpg
# 97 работаем  с файлом:  ..\avto\start_dataset\test\img_1897.jpg
# 98 работаем  с файлом:  ..\avto\start_dataset\test\img_1898.jpg
# 99 работаем  с файлом:  ..\avto\start_dataset\test\img_1900.jpg
# 100 работаем  с файлом:  ..\avto\start_dataset\test\img_1904.jpg
# 101 работаем  с файлом:  ..\avto\start_dataset\test\img_1905.jpg
# 102 работаем  с файлом:  ..\avto\start_dataset\test\img_1906.jpg
# 103 работаем  с файлом:  ..\avto\start_dataset\test\img_1908.jpg
# 104 работаем  с файлом:  ..\avto\start_dataset\test\img_1911.jpg
# 105 работаем  с файлом:  ..\avto\start_dataset\test\img_1913.jpg
# 106 работаем  с файлом:  ..\avto\start_dataset\test\img_1914.jpg
# 107 работаем  с файлом:  ..\avto\start_dataset\test\img_1915.jpg
# 108 работаем  с файлом:  ..\avto\start_dataset\test\img_1917.jpg
# 109 работаем  с файлом:  ..\avto\start_dataset\test\img_1919.jpg
# 110 работаем  с файлом:  ..\avto\start_dataset\test\img_1920.jpg
# 111 работаем  с файлом:  ..\avto\start_dataset\test\img_1923.jpg
# 112 работаем  с файлом:  ..\avto\start_dataset\test\img_1928.jpg
# 113 работаем  с файлом:  ..\avto\start_dataset\test\img_1931.jpg
# 114 работаем  с файлом:  ..\avto\start_dataset\test\img_1934.jpg
# 115 работаем  с файлом:  ..\avto\start_dataset\test\img_1935.jpg
# 116 работаем  с файлом:  ..\avto\start_dataset\test\img_1936.jpg
# 117 работаем  с файлом:  ..\avto\start_dataset\test\img_1940.jpg
# 118 работаем  с файлом:  ..\avto\start_dataset\test\img_1941.jpg
# 119 работаем  с файлом:  ..\avto\start_dataset\test\img_1942.jpg
# 120 работаем  с файлом:  ..\avto\start_dataset\test\img_1943.jpg
# 121 работаем  с файлом:  ..\avto\start_dataset\test\img_1944.jpg
# 122 работаем  с файлом:  ..\avto\start_dataset\test\img_1946.jpg
# 123 работаем  с файлом:  ..\avto\start_dataset\test\img_1947.jpg
# 124 работаем  с файлом:  ..\avto\start_dataset\test\img_1949.jpg
# 125 работаем  с файлом:  ..\avto\start_dataset\test\img_1952.jpg
# 126 работаем  с файлом:  ..\avto\start_dataset\test\img_1953.jpg
# 127 работаем  с файлом:  ..\avto\start_dataset\test\img_1954.jpg
# 128 работаем  с файлом:  ..\avto\start_dataset\test\img_1955.jpg
# 129 работаем  с файлом:  ..\avto\start_dataset\test\img_1956.jpg
# 130 работаем  с файлом:  ..\avto\start_dataset\test\img_1957.jpg
# 131 работаем  с файлом:  ..\avto\start_dataset\test\img_1960.jpg
# 132 работаем  с файлом:  ..\avto\start_dataset\test\img_1961.jpg
# 133 работаем  с файлом:  ..\avto\start_dataset\test\img_1962.jpg
# 134 работаем  с файлом:  ..\avto\start_dataset\test\img_1969.jpg
# 135 работаем  с файлом:  ..\avto\start_dataset\test\img_1972.jpg
# 136 работаем  с файлом:  ..\avto\start_dataset\test\img_1974.jpg
# 137 работаем  с файлом:  ..\avto\start_dataset\test\img_1975.jpg
# 138 работаем  с файлом:  ..\avto\start_dataset\test\img_1978.jpg
# 139 работаем  с файлом:  ..\avto\start_dataset\test\img_1981.jpg
# 140 работаем  с файлом:  ..\avto\start_dataset\test\img_1982.jpg
# 141 работаем  с файлом:  ..\avto\start_dataset\test\img_1986.jpg
# 142 работаем  с файлом:  ..\avto\start_dataset\test\img_1987.jpg
# 143 работаем  с файлом:  ..\avto\start_dataset\test\img_1988.jpg
# 144 работаем  с файлом:  ..\avto\start_dataset\test\img_1989.jpg
# 145 работаем  с файлом:  ..\avto\start_dataset\test\img_1990.jpg
# 146 работаем  с файлом:  ..\avto\start_dataset\test\img_1993.jpg
# 147 работаем  с файлом:  ..\avto\start_dataset\test\img_1995.jpg
# 148 работаем  с файлом:  ..\avto\start_dataset\test\img_1997.jpg
# 149 работаем  с файлом:  ..\avto\start_dataset\test\img_1998.jpg
# 150 работаем  с файлом:  ..\avto\start_dataset\test\img_1999.jpg
# 151 работаем  с файлом:  ..\avto\start_dataset\test\img_2004.jpg
# 152 работаем  с файлом:  ..\avto\start_dataset\test\img_2006.jpg
# 153 работаем  с файлом:  ..\avto\start_dataset\test\img_2009.jpg
# 154 работаем  с файлом:  ..\avto\start_dataset\test\img_2011.jpg
# 155 работаем  с файлом:  ..\avto\start_dataset\test\img_2013.jpg
# 156 работаем  с файлом:  ..\avto\start_dataset\test\img_2015.jpg
# 157 работаем  с файлом:  ..\avto\start_dataset\test\img_2017.jpg
# 158 работаем  с файлом:  ..\avto\start_dataset\test\img_2019.jpg
# 159 работаем  с файлом:  ..\avto\start_dataset\test\img_2020.jpg
# 160 работаем  с файлом:  ..\avto\start_dataset\test\img_2022.jpg
# 161 работаем  с файлом:  ..\avto\start_dataset\test\img_2023.jpg
# 162 работаем  с файлом:  ..\avto\start_dataset\test\img_2024.jpg
# 163 работаем  с файлом:  ..\avto\start_dataset\test\img_2028.jpg
# 164 работаем  с файлом:  ..\avto\start_dataset\test\img_2029.jpg
# 165 работаем  с файлом:  ..\avto\start_dataset\test\img_2257.jpg
# 166 работаем  с файлом:  ..\avto\start_dataset\test\img_2258.jpg
# 167 работаем  с файлом:  ..\avto\start_dataset\test\img_2259.jpg
# 168 работаем  с файлом:  ..\avto\start_dataset\test\img_2262.jpg
# 169 работаем  с файлом:  ..\avto\start_dataset\test\img_2263.jpg
# 170 работаем  с файлом:  ..\avto\start_dataset\test\img_2265.jpg
# 171 работаем  с файлом:  ..\avto\start_dataset\test\img_2267.jpg
# 172 работаем  с файлом:  ..\avto\start_dataset\test\img_2273.jpg
# 173 работаем  с файлом:  ..\avto\start_dataset\test\img_2274.jpg
# 174 работаем  с файлом:  ..\avto\start_dataset\test\img_2276.jpg
# 175 работаем  с файлом:  ..\avto\start_dataset\test\img_2279.jpg
# 176 работаем  с файлом:  ..\avto\start_dataset\test\img_2281.jpg
# 177 работаем  с файлом:  ..\avto\start_dataset\test\img_2283.jpg
# 178 работаем  с файлом:  ..\avto\start_dataset\test\img_2284.jpg
# 179 работаем  с файлом:  ..\avto\start_dataset\test\img_2286.jpg
# 180 работаем  с файлом:  ..\avto\start_dataset\test\img_2288.jpg
# 181 работаем  с файлом:  ..\avto\start_dataset\test\img_2292.jpg
# 182 работаем  с файлом:  ..\avto\start_dataset\test\img_2293.jpg
# 183 работаем  с файлом:  ..\avto\start_dataset\test\img_2298.jpg
# 184 работаем  с файлом:  ..\avto\start_dataset\test\img_2299.jpg
# 185 работаем  с файлом:  ..\avto\start_dataset\test\img_2303.jpg
# 186 работаем  с файлом:  ..\avto\start_dataset\test\img_2307.jpg
# 187 работаем  с файлом:  ..\avto\start_dataset\test\img_2311.jpg
# 188 работаем  с файлом:  ..\avto\start_dataset\test\img_2312.jpg
# 189 работаем  с файлом:  ..\avto\start_dataset\test\img_2314.jpg
# 190 работаем  с файлом:  ..\avto\start_dataset\test\img_2315.jpg
# 191 работаем  с файлом:  ..\avto\start_dataset\test\img_2317.jpg
# 192 работаем  с файлом:  ..\avto\start_dataset\test\img_2318.jpg
# 193 работаем  с файлом:  ..\avto\start_dataset\test\img_2323.jpg
# 194 работаем  с файлом:  ..\avto\start_dataset\test\img_2324.jpg
# 195 работаем  с файлом:  ..\avto\start_dataset\test\img_2325.jpg
# 196 работаем  с файлом:  ..\avto\start_dataset\test\img_2326.jpg
# 197 работаем  с файлом:  ..\avto\start_dataset\test\img_2328.jpg
# 198 работаем  с файлом:  ..\avto\start_dataset\test\img_2329.jpg
# 199 работаем  с файлом:  ..\avto\start_dataset\test\img_2334.jpg
# 200 работаем  с файлом:  ..\avto\start_dataset\test\img_2335.jpg
# 201 работаем  с файлом:  ..\avto\start_dataset\test\img_2337.jpg
# 202 работаем  с файлом:  ..\avto\start_dataset\test\img_2338.jpg
# 203 работаем  с файлом:  ..\avto\start_dataset\test\img_2339.jpg
# 204 работаем  с файлом:  ..\avto\start_dataset\test\img_2340.jpg
# 205 работаем  с файлом:  ..\avto\start_dataset\test\img_2343.jpg
# 206 работаем  с файлом:  ..\avto\start_dataset\test\img_2346.jpg
# 207 работаем  с файлом:  ..\avto\start_dataset\test\img_2349.jpg
# 208 работаем  с файлом:  ..\avto\start_dataset\test\img_2351.jpg
# 209 работаем  с файлом:  ..\avto\start_dataset\test\img_2353.jpg
# 210 работаем  с файлом:  ..\avto\start_dataset\test\img_2354.jpg
# 211 работаем  с файлом:  ..\avto\start_dataset\test\img_2355.jpg
# 212 работаем  с файлом:  ..\avto\start_dataset\test\img_2356.jpg
# 213 работаем  с файлом:  ..\avto\start_dataset\test\img_2357.jpg
# 214 работаем  с файлом:  ..\avto\start_dataset\test\img_2358.jpg
# 215 работаем  с файлом:  ..\avto\start_dataset\test\img_2360.jpg
# 216 работаем  с файлом:  ..\avto\start_dataset\test\img_2362.jpg
# 217 работаем  с файлом:  ..\avto\start_dataset\test\img_2363.jpg
# 218 работаем  с файлом:  ..\avto\start_dataset\test\img_2364.jpg
# 219 работаем  с файлом:  ..\avto\start_dataset\test\img_2365.jpg
# 220 работаем  с файлом:  ..\avto\start_dataset\test\img_2366.jpg
# 221 работаем  с файлом:  ..\avto\start_dataset\test\img_2367.jpg
# 222 работаем  с файлом:  ..\avto\start_dataset\test\img_2368.jpg
# 223 работаем  с файлом:  ..\avto\start_dataset\test\img_2370.jpg
# 224 работаем  с файлом:  ..\avto\start_dataset\test\img_2371.jpg
# 225 работаем  с файлом:  ..\avto\start_dataset\test\img_2375.jpg
# 226 работаем  с файлом:  ..\avto\start_dataset\test\img_2377.jpg
# 227 работаем  с файлом:  ..\avto\start_dataset\test\img_2379.jpg
# 228 работаем  с файлом:  ..\avto\start_dataset\test\img_2380.jpg
# 229 работаем  с файлом:  ..\avto\start_dataset\test\img_2381.jpg
# 230 работаем  с файлом:  ..\avto\start_dataset\test\img_2382.jpg
# 231 работаем  с файлом:  ..\avto\start_dataset\test\img_2386.jpg
# 232 работаем  с файлом:  ..\avto\start_dataset\test\img_2387.jpg
# 233 работаем  с файлом:  ..\avto\start_dataset\test\img_2388.jpg
# 234 работаем  с файлом:  ..\avto\start_dataset\test\img_2389.jpg
# 235 работаем  с файлом:  ..\avto\start_dataset\test\img_2391.jpg
# 236 работаем  с файлом:  ..\avto\start_dataset\test\img_2392.jpg
# 237 работаем  с файлом:  ..\avto\start_dataset\test\img_2393.jpg
# 238 работаем  с файлом:  ..\avto\start_dataset\test\img_2394.jpg
# 239 работаем  с файлом:  ..\avto\start_dataset\test\img_2395.jpg
# 240 работаем  с файлом:  ..\avto\start_dataset\test\img_2396.jpg
# 241 работаем  с файлом:  ..\avto\start_dataset\test\img_2399.jpg
# 242 работаем  с файлом:  ..\avto\start_dataset\test\img_2400.jpg
# 243 работаем  с файлом:  ..\avto\start_dataset\test\img_2401.jpg
# 244 работаем  с файлом:  ..\avto\start_dataset\test\img_2402.jpg
# 245 работаем  с файлом:  ..\avto\start_dataset\test\img_2403.jpg
# 246 работаем  с файлом:  ..\avto\start_dataset\test\img_2407.jpg
# 247 работаем  с файлом:  ..\avto\start_dataset\test\img_2412.jpg
# 248 работаем  с файлом:  ..\avto\start_dataset\test\img_2413.jpg
# 249 работаем  с файлом:  ..\avto\start_dataset\test\img_2414.jpg
# 250 работаем  с файлом:  ..\avto\start_dataset\test\img_2415.jpg
# 251 работаем  с файлом:  ..\avto\start_dataset\test\img_2416.jpg
# 252 работаем  с файлом:  ..\avto\start_dataset\test\img_2417.jpg
# 253 работаем  с файлом:  ..\avto\start_dataset\test\img_2419.jpg
# 254 работаем  с файлом:  ..\avto\start_dataset\test\img_2421.jpg
# 255 работаем  с файлом:  ..\avto\start_dataset\test\img_2424.jpg
# 256 работаем  с файлом:  ..\avto\start_dataset\test\img_2425.jpg
# 257 работаем  с файлом:  ..\avto\start_dataset\test\img_2428.jpg
# 258 работаем  с файлом:  ..\avto\start_dataset\test\img_2431.jpg
# 259 работаем  с файлом:  ..\avto\start_dataset\test\img_2433.jpg
# 260 работаем  с файлом:  ..\avto\start_dataset\test\img_2435.jpg
# 261 работаем  с файлом:  ..\avto\start_dataset\test\img_2438.jpg
# 262 работаем  с файлом:  ..\avto\start_dataset\test\img_2439.jpg
# 263 работаем  с файлом:  ..\avto\start_dataset\test\img_2441.jpg
# 264 работаем  с файлом:  ..\avto\start_dataset\test\img_2444.jpg
# 265 работаем  с файлом:  ..\avto\start_dataset\test\img_2446.jpg
# 266 работаем  с файлом:  ..\avto\start_dataset\test\img_2447.jpg
# 267 работаем  с файлом:  ..\avto\start_dataset\test\img_2448.jpg
# 268 работаем  с файлом:  ..\avto\start_dataset\test\img_2456.jpg
# 269 работаем  с файлом:  ..\avto\start_dataset\test\img_2457.jpg
# 270 работаем  с файлом:  ..\avto\start_dataset\test\img_2461.jpg
# 271 работаем  с файлом:  ..\avto\start_dataset\test\img_2464.jpg
# 272 работаем  с файлом:  ..\avto\start_dataset\test\img_2465.jpg
# 273 работаем  с файлом:  ..\avto\start_dataset\test\img_2466.jpg
# 274 работаем  с файлом:  ..\avto\start_dataset\test\img_2467.jpg
# 275 работаем  с файлом:  ..\avto\start_dataset\test\img_2471.jpg
# 276 работаем  с файлом:  ..\avto\start_dataset\test\img_2472.jpg
# 277 работаем  с файлом:  ..\avto\start_dataset\test\img_2473.jpg
# 278 работаем  с файлом:  ..\avto\start_dataset\test\img_2475.jpg
# 279 работаем  с файлом:  ..\avto\start_dataset\test\img_2478.jpg
# 280 работаем  с файлом:  ..\avto\start_dataset\test\img_2479.jpg
# 281 работаем  с файлом:  ..\avto\start_dataset\test\img_2481.jpg
# 282 работаем  с файлом:  ..\avto\start_dataset\test\img_2482.jpg
# 283 работаем  с файлом:  ..\avto\start_dataset\test\img_2483.jpg
# 284 работаем  с файлом:  ..\avto\start_dataset\test\img_2486.jpg
# 285 работаем  с файлом:  ..\avto\start_dataset\test\img_2488.jpg
# 286 работаем  с файлом:  ..\avto\start_dataset\test\img_2489.jpg
# 287 работаем  с файлом:  ..\avto\start_dataset\test\img_2491.jpg
# 288 работаем  с файлом:  ..\avto\start_dataset\test\img_2493.jpg
# 289 работаем  с файлом:  ..\avto\start_dataset\test\img_2496.jpg
# 290 работаем  с файлом:  ..\avto\start_dataset\test\img_2497.jpg
# 291 работаем  с файлом:  ..\avto\start_dataset\test\img_2498.jpg
# 292 работаем  с файлом:  ..\avto\start_dataset\test\img_2499.jpg
# 293 работаем  с файлом:  ..\avto\start_dataset\test\img_2500.jpg
# 294 работаем  с файлом:  ..\avto\start_dataset\test\img_2501.jpg
# 295 работаем  с файлом:  ..\avto\start_dataset\test\img_2506.jpg
# 296 работаем  с файлом:  ..\avto\start_dataset\test\img_2508.jpg
# 297 работаем  с файлом:  ..\avto\start_dataset\test\img_2509.jpg
# 298 работаем  с файлом:  ..\avto\start_dataset\test\img_2513.jpg
# 299 работаем  с файлом:  ..\avto\start_dataset\test\img_2515.jpg
# 300 работаем  с файлом:  ..\avto\start_dataset\test\img_2517.jpg
# 301 работаем  с файлом:  ..\avto\start_dataset\test\img_2518.jpg
# 302 работаем  с файлом:  ..\avto\start_dataset\test\img_2521.jpg
# 303 работаем  с файлом:  ..\avto\start_dataset\test\img_2522.jpg
# 304 работаем  с файлом:  ..\avto\start_dataset\test\img_2523.jpg
# 305 работаем  с файлом:  ..\avto\start_dataset\test\img_2524.jpg
# 306 работаем  с файлом:  ..\avto\start_dataset\test\img_2525.jpg
# 307 работаем  с файлом:  ..\avto\start_dataset\test\img_2526.jpg
# 308 работаем  с файлом:  ..\avto\start_dataset\test\img_2529.jpg
# 309 работаем  с файлом:  ..\avto\start_dataset\test\img_2530.jpg
# 310 работаем  с файлом:  ..\avto\start_dataset\test\img_2531.jpg
# 311 работаем  с файлом:  ..\avto\start_dataset\test\img_2532.jpg
# 312 работаем  с файлом:  ..\avto\start_dataset\test\img_2534.jpg
# 313 работаем  с файлом:  ..\avto\start_dataset\test\img_2537.jpg
# 314 работаем  с файлом:  ..\avto\start_dataset\test\img_2540.jpg
# 315 работаем  с файлом:  ..\avto\start_dataset\test\img_2541.jpg
# 316 работаем  с файлом:  ..\avto\start_dataset\test\img_2542.jpg
# 317 работаем  с файлом:  ..\avto\start_dataset\test\img_2543.jpg
# 318 работаем  с файлом:  ..\avto\start_dataset\test\img_2545.jpg
# 319 работаем  с файлом:  ..\avto\start_dataset\test\img_2546.jpg
# 320 работаем  с файлом:  ..\avto\start_dataset\test\img_2551.jpg
# 321 работаем  с файлом:  ..\avto\start_dataset\test\img_2552.jpg
# 322 работаем  с файлом:  ..\avto\start_dataset\test\img_2555.jpg
# 323 работаем  с файлом:  ..\avto\start_dataset\test\img_2556.jpg
# 324 работаем  с файлом:  ..\avto\start_dataset\test\img_2557.jpg
# 325 работаем  с файлом:  ..\avto\start_dataset\test\img_2558.jpg
# 326 работаем  с файлом:  ..\avto\start_dataset\test\img_2559.jpg
# 327 работаем  с файлом:  ..\avto\start_dataset\test\img_2560.jpg
# 328 работаем  с файлом:  ..\avto\start_dataset\test\img_2564.jpg
# 329 работаем  с файлом:  ..\avto\start_dataset\test\img_2565.jpg
# 330 работаем  с файлом:  ..\avto\start_dataset\test\img_2566.jpg
# 331 работаем  с файлом:  ..\avto\start_dataset\test\img_2567.jpg
# 332 работаем  с файлом:  ..\avto\start_dataset\test\img_2569.jpg
# 333 работаем  с файлом:  ..\avto\start_dataset\test\img_2571.jpg
# 334 работаем  с файлом:  ..\avto\start_dataset\test\img_2572.jpg
# 335 работаем  с файлом:  ..\avto\start_dataset\test\img_2573.jpg
# 336 работаем  с файлом:  ..\avto\start_dataset\test\img_2576.jpg
# 337 работаем  с файлом:  ..\avto\start_dataset\test\img_2580.jpg
# 338 работаем  с файлом:  ..\avto\start_dataset\test\img_2582.jpg
# 339 работаем  с файлом:  ..\avto\start_dataset\test\img_2585.jpg
# 340 работаем  с файлом:  ..\avto\start_dataset\test\img_2587.jpg
# 341 работаем  с файлом:  ..\avto\start_dataset\test\img_2589.jpg
# 342 работаем  с файлом:  ..\avto\start_dataset\test\img_2591.jpg
# 343 работаем  с файлом:  ..\avto\start_dataset\test\img_2592.jpg
# 344 работаем  с файлом:  ..\avto\start_dataset\test\img_2594.jpg
# 345 работаем  с файлом:  ..\avto\start_dataset\test\img_2595.jpg
# 346 работаем  с файлом:  ..\avto\start_dataset\test\img_2596.jpg
# 347 работаем  с файлом:  ..\avto\start_dataset\test\img_2598.jpg
# 348 работаем  с файлом:  ..\avto\start_dataset\test\img_2599.jpg
# 349 работаем  с файлом:  ..\avto\start_dataset\test\img_2602.jpg
# 350 работаем  с файлом:  ..\avto\start_dataset\test\img_2603.jpg
# 351 работаем  с файлом:  ..\avto\start_dataset\test\img_2605.jpg
# 352 работаем  с файлом:  ..\avto\start_dataset\test\img_2606.jpg
# 353 работаем  с файлом:  ..\avto\start_dataset\test\img_2607.jpg
# 354 работаем  с файлом:  ..\avto\start_dataset\test\img_2609.jpg
# 355 работаем  с файлом:  ..\avto\start_dataset\test\img_2610.jpg
# 356 работаем  с файлом:  ..\avto\start_dataset\test\img_2611.jpg
# 357 работаем  с файлом:  ..\avto\start_dataset\test\img_2612.jpg
# 358 работаем  с файлом:  ..\avto\start_dataset\test\img_2616.jpg
# 359 работаем  с файлом:  ..\avto\start_dataset\test\img_2617.jpg
# 360 работаем  с файлом:  ..\avto\start_dataset\test\img_2618.jpg
# 361 работаем  с файлом:  ..\avto\start_dataset\test\img_2619.jpg
# 362 работаем  с файлом:  ..\avto\start_dataset\test\img_2622.jpg
# 363 работаем  с файлом:  ..\avto\start_dataset\test\img_2626.jpg
# 364 работаем  с файлом:  ..\avto\start_dataset\test\img_2628.jpg
# 365 работаем  с файлом:  ..\avto\start_dataset\test\img_2632.jpg
# 366 работаем  с файлом:  ..\avto\start_dataset\test\img_2633.jpg
# 367 работаем  с файлом:  ..\avto\start_dataset\test\img_2637.jpg
# 368 работаем  с файлом:  ..\avto\start_dataset\test\img_2640.jpg
# 369 работаем  с файлом:  ..\avto\start_dataset\test\img_2641.jpg
# 370 работаем  с файлом:  ..\avto\start_dataset\test\img_2644.jpg
# 371 работаем  с файлом:  ..\avto\start_dataset\test\img_2647.jpg
# 372 работаем  с файлом:  ..\avto\start_dataset\test\img_2649.jpg
# 373 работаем  с файлом:  ..\avto\start_dataset\test\img_2652.jpg
# 374 работаем  с файлом:  ..\avto\start_dataset\test\img_2653.jpg
# 375 работаем  с файлом:  ..\avto\start_dataset\test\img_2655.jpg
# 376 работаем  с файлом:  ..\avto\start_dataset\test\img_2661.jpg
# 377 работаем  с файлом:  ..\avto\start_dataset\test\img_2662.jpg
# 378 работаем  с файлом:  ..\avto\start_dataset\test\img_2663.jpg
# 379 работаем  с файлом:  ..\avto\start_dataset\test\img_2668.jpg
# 380 работаем  с файлом:  ..\avto\start_dataset\test\img_2670.jpg
# 381 работаем  с файлом:  ..\avto\start_dataset\test\img_2674.heic
# 382 работаем  с файлом:  ..\avto\start_dataset\test\img_2675.jpg
# 383 работаем  с файлом:  ..\avto\start_dataset\test\img_2676.jpg
# 384 работаем  с файлом:  ..\avto\start_dataset\test\img_2677.heic
# 385 работаем  с файлом:  ..\avto\start_dataset\test\img_2677.jpg
# 386 работаем  с файлом:  ..\avto\start_dataset\test\img_2678.jpg
# 387 работаем  с файлом:  ..\avto\start_dataset\test\img_2679.heic
# 388 работаем  с файлом:  ..\avto\start_dataset\test\img_2679.jpg
# 389 работаем  с файлом:  ..\avto\start_dataset\test\img_2680.jpg
# 390 работаем  с файлом:  ..\avto\start_dataset\test\img_2684.heic
# 391 работаем  с файлом:  ..\avto\start_dataset\test\img_2685.jpg
# 392 работаем  с файлом:  ..\avto\start_dataset\test\img_2686.heic
# 393 работаем  с файлом:  ..\avto\start_dataset\test\img_2687.jpg
# 394 работаем  с файлом:  ..\avto\start_dataset\test\img_2689.heic
# 395 работаем  с файлом:  ..\avto\start_dataset\test\img_2689.jpg
# 396 работаем  с файлом:  ..\avto\start_dataset\test\img_2692.heic
# 397 работаем  с файлом:  ..\avto\start_dataset\test\img_2692.jpg
# 398 работаем  с файлом:  ..\avto\start_dataset\test\img_2693.heic
# 399 работаем  с файлом:  ..\avto\start_dataset\test\img_2693.jpg
# 400 работаем  с файлом:  ..\avto\start_dataset\test\img_2695.jpg
# 401 работаем  с файлом:  ..\avto\start_dataset\test\img_2696.jpg
# 402 работаем  с файлом:  ..\avto\start_dataset\test\img_2697.heic
# 403 работаем  с файлом:  ..\avto\start_dataset\test\img_2697.jpg
# 404 работаем  с файлом:  ..\avto\start_dataset\test\img_2698.heic
# 405 работаем  с файлом:  ..\avto\start_dataset\test\img_2698.jpg
# 406 работаем  с файлом:  ..\avto\start_dataset\test\img_2699.jpg
# 407 работаем  с файлом:  ..\avto\start_dataset\test\img_2700.jpg
# 408 работаем  с файлом:  ..\avto\start_dataset\test\img_2701.jpg
# 409 работаем  с файлом:  ..\avto\start_dataset\test\img_2702.heic
# 410 работаем  с файлом:  ..\avto\start_dataset\test\img_2702.jpg
# 411 работаем  с файлом:  ..\avto\start_dataset\test\img_2703.heic
# 412 работаем  с файлом:  ..\avto\start_dataset\test\img_2703.jpg
# 413 работаем  с файлом:  ..\avto\start_dataset\test\img_2704.heic
# 414 работаем  с файлом:  ..\avto\start_dataset\test\img_2706.heic
# 415 работаем  с файлом:  ..\avto\start_dataset\test\img_2707.heic
# 416 работаем  с файлом:  ..\avto\start_dataset\test\img_2708.heic
# 417 работаем  с файлом:  ..\avto\start_dataset\test\img_2710.jpg
# 418 работаем  с файлом:  ..\avto\start_dataset\test\img_2711.heic
# 419 работаем  с файлом:  ..\avto\start_dataset\test\img_2711.jpg
# 420 работаем  с файлом:  ..\avto\start_dataset\test\img_2712.heic
# 421 работаем  с файлом:  ..\avto\start_dataset\test\img_2713.heic
# 422 работаем  с файлом:  ..\avto\start_dataset\test\img_2714.jpg
# 423 работаем  с файлом:  ..\avto\start_dataset\test\img_2715.heic
# 424 работаем  с файлом:  ..\avto\start_dataset\test\img_2715.jpg
# 425 работаем  с файлом:  ..\avto\start_dataset\test\img_2716.heic
# 426 работаем  с файлом:  ..\avto\start_dataset\test\img_2717.heic
# 427 работаем  с файлом:  ..\avto\start_dataset\test\img_2717.jpg
# 428 работаем  с файлом:  ..\avto\start_dataset\test\img_2718.heic
# 429 работаем  с файлом:  ..\avto\start_dataset\test\img_2718.jpg
# 430 работаем  с файлом:  ..\avto\start_dataset\test\img_2719.heic
# 431 работаем  с файлом:  ..\avto\start_dataset\test\img_2719.jpg
# 432 работаем  с файлом:  ..\avto\start_dataset\test\img_2720.heic
# 433 работаем  с файлом:  ..\avto\start_dataset\test\img_2720.jpg
# 434 работаем  с файлом:  ..\avto\start_dataset\test\img_2722.jpg
# 435 работаем  с файлом:  ..\avto\start_dataset\test\img_2724.jpg
# 436 работаем  с файлом:  ..\avto\start_dataset\test\img_2725.heic
# 437 работаем  с файлом:  ..\avto\start_dataset\test\img_2726.jpg
# 438 работаем  с файлом:  ..\avto\start_dataset\test\img_2727.jpg
# 439 работаем  с файлом:  ..\avto\start_dataset\test\img_2728.heic
# 440 работаем  с файлом:  ..\avto\start_dataset\test\img_2729.jpg
# 441 работаем  с файлом:  ..\avto\start_dataset\test\img_2731.heic
# 442 работаем  с файлом:  ..\avto\start_dataset\test\img_2731.jpg
# 443 работаем  с файлом:  ..\avto\start_dataset\test\img_2732.heic
# 444 работаем  с файлом:  ..\avto\start_dataset\test\img_2733.jpg
# 445 работаем  с файлом:  ..\avto\start_dataset\test\img_2734.jpg
# 446 работаем  с файлом:  ..\avto\start_dataset\test\img_2736.heic
# 447 работаем  с файлом:  ..\avto\start_dataset\test\img_2736.jpg
# 448 работаем  с файлом:  ..\avto\start_dataset\test\img_2738.jpg
# 449 работаем  с файлом:  ..\avto\start_dataset\test\img_2739.heic
# 450 работаем  с файлом:  ..\avto\start_dataset\test\img_2740.jpg
# 451 работаем  с файлом:  ..\avto\start_dataset\test\img_2742.heic
# 452 работаем  с файлом:  ..\avto\start_dataset\test\img_2744.jpg
# 453 работаем  с файлом:  ..\avto\start_dataset\test\img_2746.jpg
# 454 работаем  с файлом:  ..\avto\start_dataset\test\img_2749.jpg
# 455 работаем  с файлом:  ..\avto\start_dataset\test\img_2750.heic
# 456 работаем  с файлом:  ..\avto\start_dataset\test\img_2752.heic
# 457 работаем  с файлом:  ..\avto\start_dataset\test\img_2752.jpg
# 458 работаем  с файлом:  ..\avto\start_dataset\test\img_2753.heic
# 459 работаем  с файлом:  ..\avto\start_dataset\test\img_2753.jpg
# 460 работаем  с файлом:  ..\avto\start_dataset\test\img_2754.jpg
# 461 работаем  с файлом:  ..\avto\start_dataset\test\img_2755.heic
# 462 работаем  с файлом:  ..\avto\start_dataset\test\img_2756.jpg
# 463 работаем  с файлом:  ..\avto\start_dataset\test\img_2757.jpg
# 464 работаем  с файлом:  ..\avto\start_dataset\test\img_2758.jpg
# 465 работаем  с файлом:  ..\avto\start_dataset\test\img_2759.jpg
# 466 работаем  с файлом:  ..\avto\start_dataset\test\img_2761.jpg
# 467 работаем  с файлом:  ..\avto\start_dataset\test\img_2762.jpg
# 468 работаем  с файлом:  ..\avto\start_dataset\test\img_2768.jpg
# 469 работаем  с файлом:  ..\avto\start_dataset\test\img_2769.jpg
# 470 работаем  с файлом:  ..\avto\start_dataset\test\img_2771.jpg
# 471 работаем  с файлом:  ..\avto\start_dataset\test\img_2772.jpg
# 472 работаем  с файлом:  ..\avto\start_dataset\test\img_2773.jpg
# 473 работаем  с файлом:  ..\avto\start_dataset\test\img_2776.jpg
# 474 работаем  с файлом:  ..\avto\start_dataset\test\img_2777.jpg
# 475 работаем  с файлом:  ..\avto\start_dataset\test\img_2778.jpg
# 476 работаем  с файлом:  ..\avto\start_dataset\test\img_2781.jpg
# 477 работаем  с файлом:  ..\avto\start_dataset\test\img_2782.jpg
# 478 работаем  с файлом:  ..\avto\start_dataset\test\img_2784.jpg
# 479 работаем  с файлом:  ..\avto\start_dataset\test\img_2785.jpg
# 480 работаем  с файлом:  ..\avto\start_dataset\test\img_2790.jpg
# 481 работаем  с файлом:  ..\avto\start_dataset\test\img_2798.jpg
# 482 работаем  с файлом:  ..\avto\start_dataset\test\img_2800.jpg
# 483 работаем  с файлом:  ..\avto\start_dataset\test\img_2826.jpg
# 484 работаем  с файлом:  ..\avto\start_dataset\test\img_2859.jpg
# 485 работаем  с файлом:  ..\avto\start_dataset\test\img_2864.jpg
# 486 работаем  с файлом:  ..\avto\start_dataset\test\img_2865.jpg
# 487 работаем  с файлом:  ..\avto\start_dataset\test\img_2868.jpg
# 488 работаем  с файлом:  ..\avto\start_dataset\test\img_2871.jpg
# 489 работаем  с файлом:  ..\avto\start_dataset\test\img_2873.jpg
# 490 работаем  с файлом:  ..\avto\start_dataset\test\img_2875.jpg
# 491 работаем  с файлом:  ..\avto\start_dataset\test\img_2877.jpg
# 492 работаем  с файлом:  ..\avto\start_dataset\test\img_2878.jpg
# 493 работаем  с файлом:  ..\avto\start_dataset\test\img_2880.jpg
# 494 работаем  с файлом:  ..\avto\start_dataset\test\img_2884.jpg
# 495 работаем  с файлом:  ..\avto\start_dataset\test\img_2886.jpg
# 496 работаем  с файлом:  ..\avto\start_dataset\test\img_2887.jpg
# 497 работаем  с файлом:  ..\avto\start_dataset\test\img_2888.jpg
# 498 работаем  с файлом:  ..\avto\start_dataset\test\img_2889.jpg
# 499 работаем  с файлом:  ..\avto\start_dataset\test\img_2893.jpg
# 500 работаем  с файлом:  ..\avto\start_dataset\test\img_2898.jpg
# 501 работаем  с файлом:  ..\avto\start_dataset\test\img_2900.jpg
# 502 работаем  с файлом:  ..\avto\start_dataset\test\img_2906.jpg
# 503 работаем  с файлом:  ..\avto\start_dataset\test\img_2907.jpg
# 504 работаем  с файлом:  ..\avto\start_dataset\test\img_2909.jpg
# 505 работаем  с файлом:  ..\avto\start_dataset\test\img_2910.jpg
# 506 работаем  с файлом:  ..\avto\start_dataset\test\img_2914.jpg
# 507 работаем  с файлом:  ..\avto\start_dataset\test\img_2917.jpg
# 508 работаем  с файлом:  ..\avto\start_dataset\test\img_2919.jpg
# 509 работаем  с файлом:  ..\avto\start_dataset\test\img_2921.jpg
# 510 работаем  с файлом:  ..\avto\start_dataset\test\img_2922.jpg
# 511 работаем  с файлом:  ..\avto\start_dataset\test\img_2923.jpg
# 512 работаем  с файлом:  ..\avto\start_dataset\test\img_2924.jpg
# 513 работаем  с файлом:  ..\avto\start_dataset\test\img_2926.jpg
# 514 работаем  с файлом:  ..\avto\start_dataset\test\img_2929.jpg
# 515 работаем  с файлом:  ..\avto\start_dataset\test\img_2933.jpg
# 516 работаем  с файлом:  ..\avto\start_dataset\test\img_2935.jpg
# 517 работаем  с файлом:  ..\avto\start_dataset\test\img_2936.jpg
# 518 работаем  с файлом:  ..\avto\start_dataset\test\img_2938.jpg
# 519 работаем  с файлом:  ..\avto\start_dataset\test\img_2942.jpg
# 520 работаем  с файлом:  ..\avto\start_dataset\test\img_2943.jpg
# 521 работаем  с файлом:  ..\avto\start_dataset\test\img_2946.jpg
# не распознано файлов 0
# не распознанные
