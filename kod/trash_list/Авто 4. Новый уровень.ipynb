# %%
import utils
import torch
import math
import numpy as np 
from PIL import Image
import cv2
import os
from pathlib import *
import shutil
import pandas as PD
import pillow_heif
import matplotlib.pyplot as plt
# %matplotlib inline
PD.options.display.expand_frame_repr = False

# %%
display = utils.notebook_init() 
print('cuda доступна', torch.cuda.is_available())
print('под каким номером куда:',torch.cuda.current_device())
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE" #без этого ошибка будет
# Out:
# YOLOv5  v6.1-258-g1156a32 Python-3.8.13 torch-1.11.0 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Setup complete  (16 CPUs, 39.3 GB RAM, 224.8/953.9 GB disk)
# cuda доступна True
# под каким номером куда: 0

# %%
#Вот без этого ничего не работает.
#функция крутит картинку в зависимости от того, что нашла в характеристиках файла. 
def exif_transpose(img):
    if not img:
        return img
    wh = img.size
    if wh[0] > wh[1]:
        return img
    exif_orientation_tag = 274

    # Check for EXIF data (only present on some files)
    if hasattr(img, "_getexif") and isinstance(img._getexif(), dict) and exif_orientation_tag in img._getexif():
        exif_data = img._getexif()
        orientation = exif_data[exif_orientation_tag]

        # Handle EXIF Orientation
        if orientation == 1:
            # Normal image - nothing to do!
            pass
        elif orientation == 2:
            # Mirrored left to right
            img = img.transpose(PIL.Image.FLIP_LEFT_RIGHT)
        elif orientation == 3:
            # Rotated 180 degrees
            img = img.rotate(180)
        elif orientation == 4:
            # Mirrored top to bottom
            img = img.rotate(180).transpose(PIL.Image.FLIP_LEFT_RIGHT)
        elif orientation == 5:
            # Mirrored along top-left diagonal
            img = img.rotate(-90, expand=True).transpose(PIL.Image.FLIP_LEFT_RIGHT)
        elif orientation == 6:
            # Rotated 90 degrees
            #print('повернули')
            img = img.rotate(-90, expand=True)
        elif orientation == 7:
            # Mirrored along top-right diagonal
            img = img.rotate(90, expand=True).transpose(PIL.Image.FLIP_LEFT_RIGHT)
        elif orientation == 8:
            # Rotated 270 degrees
            img = img.rotate(90, expand=True)

    return img

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom',  path='runs\\train\\exp003\\weights\\best.pt') #работает, но загружает каждый раз
# Out:
# Using cache found in C:\Users\Алексей/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  v6.1-258-g1156a32 Python-3.8.13 torch-1.11.0 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
#
# Fusing layers...
# Model summary: 290 layers, 20852934 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# # Вариант 2. По фокусному расстоянию

# %%
from exif import Image as exif
def  get_focus_from_exif(f):
    with open(f, "rb") as palm_1_file:
        palm_1_image = exif(palm_1_file)
    if palm_1_image.has_exif:
        focal = palm_1_image.get('focal_length_in_35mm_film', 'Unknown')
        digital_zoom = palm_1_image.get('digital_zoom_ratio', 'Unknown')
        
         
    else:
        focal = 0
        digital_zoom = 1
    
    return focal, digital_zoom

# %%
def conv_heic_to_jpg(file, new_name):

    heif_file = pillow_heif.read_heif(file)
    image = Image.frombytes(
        heif_file.mode,
        heif_file.size,
        heif_file.data,
        "raw",
    )
    
    #new_name = 'Y:\\temp.jpg' #так просто мы меняем расширение
    ex = heif_file.info['exif']
    image.save(new_name, format("jpeg"), exif=ex)
    image.close()
    return new_name

# %%
def get_distance(p):
    if len(p) != 2: 
        return 0
    d = (p[0][0]-p[1][0])**2 + (p[0][1]-p[1][1])**2
    d = d**0.5
    return d
def res(file, show_pandas = 0):
    if '.heic' in file:
        
        #name_f =file[file.rfind('\\')+1:]
        #name_f = name_f.replace('.heic','.jpg')
        temp_file = 'Y:\\tmp.jpg'
        file = conv_heic_to_jpg(work_file,temp_file)
    
    im = Image.open(file)
    (width, height) = im.size
    
    results = model(file)
    pd = results.pandas().xyxy[0]
    
    pd_point = pd.loc[pd['name'] == 'point']            #таблица с точками
    pd = pd.loc[pd['name'] == 'znak']                   #таблица со знаками
    
    #все номера нам не надо. Нам надо только тот, что ближе к центру

    #ОБРАБАТЫВАЕМ ЗНАКИ
    if show_pandas == 1:
        print('Знаки\n',pd)
        print('Точки\n',pd_point)
    
    pd = pd.assign(to_centre_x = abs(width/2 - (pd.xmin + (pd.xmax-pd.xmin)/2)))     #считаем расстояние до центра
    pd = pd.assign(centre_x = pd.xmin + (pd.xmax-pd.xmin)/2)                         #считаем координаты центра 
    
    pd = pd.assign(width = pd.xmax - pd.xmin)                                        #ширина
    pd = pd.assign(height = pd.ymax - pd.ymin)                                       #высота
    pd = pd.assign(s2 = pd.width * pd.height)                                        #площадь
    
    pd = pd.sort_values(['to_centre_x'] )                                            #сортируем по близости к центру. Нам надо самый близкий номер
    
    
    d = dict()   #в этом словаре будут все результаты
    for index, row in pd.iterrows():
        d ['width']  = row['width']
        d ['height']  = row['height']
        d ['s2']  = row['s2']
        d ['xmin']  = row['xmin']
        d ['ymin']  = row['ymin']
        d ['xmax']  = row['xmax']
        d ['ymax']  = row['ymax']
        break
    #Сейчас в d - все характеристики знака. 
    
    
    #ОБРАБАТЫВАЕМ POINTS. Берем только те, что входят в область нашего знака. В идеале их должно быть две.
    pd_point = pd_point.assign(centre_x = pd_point.xmin + (pd_point.xmax-pd_point.xmin)/2)   #Yнам нужны будут только центры точек
    pd_point = pd_point.assign(centre_y = pd_point.ymin + (pd_point.ymax-pd_point.ymin)/2)   #Yнам нужны будут только центры точек
    
    
    pd_point = pd_point.sort_values(['centre_x'] )
    if show_pandas == 1:
        print('все найденные точки\n',pd_point)
    points_in_znak =[]
    for index, row in pd_point.iterrows():
        if (d['xmin'] < row['centre_x'] < d['xmax']) and (d['ymin'] < row['centre_y'] < d['ymax']):
            points_in_znak.append([row['centre_x'],row['centre_y']])
    
    if show_pandas == 1:
        print('координаты точек в знаке', points_in_znak)
    
    d['main_line'] = get_distance(points_in_znak)
    
    d['im_width'] = width
    d['im_height'] = height
    
    
    return d

# %%
def crop_znak(temp_file,znak):
    if len(znak) == 3:
        print('не смог кроопнуть', temp_file)
        return
    img = Image.open(temp_file)
    xmin  = znak['xmin']
    ymin = znak['ymin']
    xmax  = znak['xmax']
    ymax  = znak['ymax']
    #print((xmin, ymin,xmax, ymax))
    img = img.crop((xmin, ymin,xmax, ymax))
    img.save(temp_file)

# %%
#пытаемся вырезать область вокруг знака, чтобы подать ее потом снова в сеть для более точного распознавания.
def mini_pic(temp_file,znak):
    if len(znak) == 3:
        print('не смог кроопнуть', temp_file)
        return
    if znak['width'] >400:
        return
    
    img = Image.open(temp_file)
    xmin  = znak['xmin']
    ymin = znak['ymin']
    xmax  = znak['xmax']
    ymax  = znak['ymax']
    centre_x = xmin + (xmax - xmin)/2
    centre_y = ymin + (ymax - ymin)/2
    #print((xmin, ymin,xmax, ymax))
    img = img.crop((centre_x-480, centre_y - 480,centre_x+480, centre_y + 480))
    img.save(temp_file)
    print('минипик',temp_file,centre_x,centre_y, znak['width'])

# %%
from math import atan, sin, cos, tan,degrees

def correct_znak2(znak):
    
    w_znak = 520 #ширина знака в мм
    h_znak = 112
    if len(znak) == 3: #похоже, что не рааспознался
        return w_znak
    #сначала ищем угол наклона знака по соотношению сторон
    HW  = 112/520 #стандартное соотношение между сторонами
    hw = znak['height']/znak['width']#найденное соотнощение между сторонами
    tan_alfa = -(HW - hw) / (1 - HW * hw)
    alfa_rad = abs(math.atan(tan_alfa)) #нашли угол наклона знака в радианах
    print('приблизительно повернуто',degrees(alfa_rad))
    
    new_AB = w_znak * cos(alfa_rad) + h_znak * sin(alfa_rad)
    #new_w = (CD-AB/tan(alfa_rad)) / (sin(alfa_rad) - cos(alfa_rad)*cos(alfa_rad)/sin(alfa_rad))
    
    print('корректировка длины знака','520', '---->',new_AB)
    
    return new_AB

def correct_znak(znak):
    if len(znak) == 3: #похоже, что не рааспознался
        return znak
    #сначала ищем угол наклона знака по соотношению сторон
    HW  = 112/520 #стандартное соотношение между сторонами
    hw = znak['height']/znak['width']#найденное соотнощение между сторонами
    tan_alfa = -(HW - hw) / (1 - HW * hw)
    alfa_rad = math.atan(tan_alfa) #нашли угол наклона знака в радианах
    print('приблизительно повернуто',degrees(alfa_rad))
    
    CD = znak['height']
    AB = znak['width']
    new_w = (CD-AB/tan(alfa_rad)) / (sin(alfa_rad) - cos(alfa_rad)*cos(alfa_rad)/sin(alfa_rad))
    
    print('корректировка длины знака',znak['width'], '---->',new_w)
    znak['width'] = new_w
    return znak

def correct_zoom(znak,digital_zoom):
    if digital_zoom != 0:
        new_w = znak['width'] / digital_zoom
        znak['width'] = new_w
    return znak

# %%
def file_recognition(f):
    temp_path = 'Y:\\'
    w_znak = 520 #ширина знака в мм
    w = 4032    #разрешение матрицы/фото в пикселях
    w_matrix = 34.974 #ширина матрицы в мм
    pixel_in_mm = w/w_matrix
    name_file = f[f.rfind('\\')+1:]
    
    
    
    work_file = f
    temp_file = os.path.join(temp_path, name_file)
    
    
    if '.heic' in f:
        temp_file = temp_file.replace('.heic','.jpg')
        work_file = conv_heic_to_jpg(work_file,temp_file)
        print('Сконвертирован',work_file)
    focus, digital_zoom = get_focus_from_exif(work_file)
    print('focus, digital_zoom',focus, digital_zoom)
     
    img = Image.open(work_file)
    img = exif_transpose(img)
    #print('сохранили поворот',temp_file)
    img.save(temp_file)
    img.close()


    
    znak1 = res(temp_file)
    znak = znak1
    
    #ЭКСПЕРИМЕНТ
#     if len(znak1) == 3:
#         print('ФАЙЛ НЕ РАСПОЗНАН', f)
#         not_recognize.append(f) 
#         return 0.0
    
#     #пробуем вырезать область,чтобы знак был бллиже. количество пикселей от этого не меняется
#     print('ширина до мини пика', znak1['width'])

#     mini_pic(temp_file,znak1)
#     #вырезали и еще раз на распознавание
#     znak = res(temp_file)
#     if len(znak) != 3:
#         print('ширина после мини пика', znak['width'], 'уточнение', znak1['width']-znak['width'])
#     else: #почему то после зума, знак не распознался. Возвращаем то, что было, это всяко лучше чем ноль
#         znak = znak1
        
    #....конец эксперимента.
    
    
    #crop_znak(temp_file,znak)
    
    
    #кооректировка длины знака
    #znak = correct_znak(znak) #корректируем длину знака в зависимости от наклона
    
    #уточнение полученнного расстояние
    #w_znak = correct_znak2(znak)
    
    #znak = correct_zoom(znak,digital_zoom) #корректируем длину знака взависимости от цифрового увеличения
    #pixel_in_mm = pixel_in_mm / digital_zoom
    
    if len(znak) == 3:
        print('ФАЙЛ НЕ РАСПОЗНАН', f)
        not_recognize.append(f)
        d = 0.0
    #формируем строку с параметрами знака для записи в csv
    else:
        d = (znak['width']/pixel_in_mm + w_znak)/(znak['width']/pixel_in_mm) * focus/1000
        #d = (w_znak)/(znak['width']/pixel_in_mm) * focus/1000
    
    return d

# %%
train_csv = '..\\avto\\start_dataset\\train.csv'
#сначала прочитаем все данные нам растояния
dist = dict()  #здесь будем храть все расстояния добытые из файла
with open(train_csv, 'r', encoding='utf-8') as file:
    for line in file:
        line = line.replace('\n','')
        key, d = line.split(';')
        dist[key] = d
        
        

keys = ['width', 'height', 's2', 'xmin', 'ymin', 'xmax', 'ymax', 'main_line', 'im_width', 'im_height']
pic_data = '..\\avto\\start_dataset\\test'
train_csv = '..\\avto\\start_dataset\\my_train.csv'
test = '..\\avto\\start_dataset\\sample_solution.csv'
temp_path = 'Y:\\'


new_f = 'image_name;distance'
#print(new_f)
not_recognize = []
n = 0
abs_mistake, otn_mistake, vsego = 0, 0, 0
for f in os.listdir(pic_data):
    n +=1
#     if n<= 400:
#         continue
#     if n>425:
#         break
    
    
    work_file = os.path.join(pic_data, f)
    print(n,'работаем  с файлом: ',work_file)

    itog = file_recognition(work_file)
    
    if f in dist:
        y = float(dist[f])
        mistake = (y - itog) / y
        print('ошибка',mistake, 'ист', y, 'предск',itog)
        otn_mistake += mistake
        abs_mistake += mistake
        vsego +=1
    
    
    st = f+';' + str(itog)
    print('ВЫХОД',st)
    print('\n\n')    
    new_f = new_f +'\n'+st
    
#print(new_f)
with open(test, 'w', encoding = 'utf-8') as file:
    file.write(new_f)
print('не распознано файлов', len(not_recognize))
print('не распознанные', *not_recognize)
print('сохранено в ',test)
if vsego != 0:
    print('Абс ошибка', round(all_mistake/vsego*100, 2))
    print('Относительная ошибка', round(otn_mistake/vsego*100, 2))
else:
    print('Ошибка не посчитана. Истинных данных не обнаружено. Датасет тестовый?')
# Out:
# 1 работаем  с файлом:  ..\avto\start_dataset\test\img_1597.jpg
# focus, digital_zoom 17 1.261050875729775
# ВЫХОД img_1597.jpg;3.7305827658002806
#
#
#
# 2 работаем  с файлом:  ..\avto\start_dataset\test\img_1598.jpg
# focus, digital_zoom 17 1.261050875729775
# ВЫХОД img_1598.jpg;2.6515282614713525
#
#
#
# 3 работаем  с файлом:  ..\avto\start_dataset\test\img_1599.jpg
# focus, digital_zoom 17 1.261050875729775
# ВЫХОД img_1599.jpg;1.9455029612471137
#
#
#
# 4 работаем  с файлом:  ..\avto\start_dataset\test\img_1602.jpg
# focus, digital_zoom 17 1.261050875729775
# ВЫХОД img_1602.jpg;2.6660451853071927
#
#
#
# 5 работаем  с файлом:  ..\avto\start_dataset\test\img_1604.jpg
# focus, digital_zoom 17 1.261050875729775
# ВЫХОД img_1604.jpg;1.507550110625344
#
#
#
# 6 работаем  с файлом:  ..\avto\start_dataset\test\img_1609.jpg
# focus, digital_zoom 17 1.305699481865285
# ВЫХОД img_1609.jpg;7.922662895353168
#
#
#
# 7 работаем  с файлом:  ..\avto\start_dataset\test\img_1610.jpg
# focus, digital_zoom 16 1.2383292383292384
# ВЫХОД img_1610.jpg;8.714935150869847
#
#
#
# 8 работаем  с файлом:  ..\avto\start_dataset\test\img_1611.jpg
# focus, digital_zoom 16 1.2383292383292384
# ВЫХОД img_1611.jpg;7.862980719106922
#
#
#
# 9 работаем  с файлом:  ..\avto\start_dataset\test\img_1617.jpg
# focus, digital_zoom 26 Unknown
# ВЫХОД img_1617.jpg;1.7579778317748005
#
#
#
# 10 работаем  с файлом:  ..\avto\start_dataset\test\img_1622.jpg
# focus, digital_zoom 16 1.2352941176470589
# ВЫХОД img_1622.jpg;3.57506112471961
#
#
#
# 11 работаем  с файлом:  ..\avto\start_dataset\test\img_1625.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1625.jpg;2.3140998566880784
#
#
#
# 12 работаем  с файлом:  ..\avto\start_dataset\test\img_1629.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1629.jpg;0.8655170759905451
#
#
#
# 13 работаем  с файлом:  ..\avto\start_dataset\test\img_1630.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1630.jpg;1.6250572203484224
#
#
#
# 14 работаем  с файлом:  ..\avto\start_dataset\test\img_1632.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1632.jpg;1.814607557483772
#
#
#
# 15 работаем  с файлом:  ..\avto\start_dataset\test\img_1633.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1633.jpg;1.5069755533797136
#
#
#
# 16 работаем  с файлом:  ..\avto\start_dataset\test\img_1636.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1636.jpg;2.5250216607640747
#
#
#
# 17 работаем  с файлом:  ..\avto\start_dataset\test\img_1638.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1638.jpg;1.8246128056529705
#
#
#
# 18 работаем  с файлом:  ..\avto\start_dataset\test\img_1639.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1639.jpg;3.188713224857611
#
#
#
# 19 работаем  с файлом:  ..\avto\start_dataset\test\img_1642.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1642.jpg;4.79985515415793
#
#
#
# 20 работаем  с файлом:  ..\avto\start_dataset\test\img_1644.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1644.jpg;5.774513306071084
#
#
#
# 21 работаем  с файлом:  ..\avto\start_dataset\test\img_1646.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1646.jpg;2.7572203651321767
#
#
#
# 22 работаем  с файлом:  ..\avto\start_dataset\test\img_1648.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1648.jpg;3.7738494030901717
#
#
#
# 23 работаем  с файлом:  ..\avto\start_dataset\test\img_1651.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1651.jpg;4.837388680119741
#
#
#
# 24 работаем  с файлом:  ..\avto\start_dataset\test\img_1652.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1652.jpg;5.418721241613043
#
#
#
# 25 работаем  с файлом:  ..\avto\start_dataset\test\img_1654.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1654.jpg;3.994895130049833
#
#
#
# 26 работаем  с файлом:  ..\avto\start_dataset\test\img_1655.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1655.jpg;3.4106763540688916
#
#
#
# 27 работаем  с файлом:  ..\avto\start_dataset\test\img_1657.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1657.jpg;2.271510407832842
#
#
#
# 28 работаем  с файлом:  ..\avto\start_dataset\test\img_1659.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1659.jpg;1.3455817683100166
#
#
#
# 29 работаем  с файлом:  ..\avto\start_dataset\test\img_1660.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1660.jpg;3.991066455736209
#
#
#
# 30 работаем  с файлом:  ..\avto\start_dataset\test\img_1661.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1661.jpg;3.4260663429545963
#
#
#
# 31 работаем  с файлом:  ..\avto\start_dataset\test\img_1663.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1663.jpg;5.976971626714971
#
#
#
# 32 работаем  с файлом:  ..\avto\start_dataset\test\img_1664.jpg
# focus, digital_zoom 18 1.3795620437956204
# ВЫХОД img_1664.jpg;3.531929438532837
#
#
#
# 33 работаем  с файлом:  ..\avto\start_dataset\test\img_1678.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1678.jpg;4.64462880371778
#
#
#
# 34 работаем  с файлом:  ..\avto\start_dataset\test\img_1679.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1679.jpg;5.232432016127944
#
#
#
# 35 работаем  с файлом:  ..\avto\start_dataset\test\img_1682.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1682.jpg;8.663715949371818
#
#
#
# 36 работаем  с файлом:  ..\avto\start_dataset\test\img_1683.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1683.jpg;8.07179503572681
#
#
#
# 37 работаем  с файлом:  ..\avto\start_dataset\test\img_1689.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1689.jpg;3.518370019316994
#
#
#
# 38 работаем  с файлом:  ..\avto\start_dataset\test\img_1693.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1693.jpg;3.6692073733315893
#
#
#
# 39 работаем  с файлом:  ..\avto\start_dataset\test\img_1694.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1694.jpg;3.088826630891096
#
#
#
# 40 работаем  с файлом:  ..\avto\start_dataset\test\img_1695.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1695.jpg;2.468047559156034
#
#
#
# 41 работаем  с файлом:  ..\avto\start_dataset\test\img_1697.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1697.jpg;1.5457391813130643
#
#
#
# 42 работаем  с файлом:  ..\avto\start_dataset\test\img_1698.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1698.jpg;2.9679310849696248
#
#
#
# 43 работаем  с файлом:  ..\avto\start_dataset\test\img_1699.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1699.jpg;3.6878940219735443
#
#
#
# 44 работаем  с файлом:  ..\avto\start_dataset\test\img_1701.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1701.jpg;5.414899234835792
#
#
#
# 45 работаем  с файлом:  ..\avto\start_dataset\test\img_1702.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1702.jpg;3.2317848602227084
#
#
#
# 46 работаем  с файлом:  ..\avto\start_dataset\test\img_1703.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1703.jpg;2.6766189924848898
#
#
#
# 47 работаем  с файлом:  ..\avto\start_dataset\test\img_1704.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1704.jpg;2.2192216623582297
#
#
#
# 48 работаем  с файлом:  ..\avto\start_dataset\test\img_1705.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1705.jpg;4.1597459653651585
#
#
#
# 49 работаем  с файлом:  ..\avto\start_dataset\test\img_1706.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1706.jpg;4.745802829775485
#
#
#
# 50 работаем  с файлом:  ..\avto\start_dataset\test\img_1710.jpg
# focus, digital_zoom 16 1.237315875613748
# ФАЙЛ НЕ РАСПОЗНАН ..\avto\start_dataset\test\img_1710.jpg
# ВЫХОД img_1710.jpg;0.0
#
#
#
# 51 работаем  с файлом:  ..\avto\start_dataset\test\img_1716.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1716.jpg;4.782667036557984
#
#
#
# 52 работаем  с файлом:  ..\avto\start_dataset\test\img_1717.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1717.jpg;5.154315775103593
#
#
#
# 53 работаем  с файлом:  ..\avto\start_dataset\test\img_1718.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1718.jpg;5.623598245748374
#
#
#
# 54 работаем  с файлом:  ..\avto\start_dataset\test\img_1719.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1719.jpg;1.928014845095461
#
#
#
# 55 работаем  с файлом:  ..\avto\start_dataset\test\img_1720.jpg
# focus, digital_zoom 16 1.237315875613748
# ВЫХОД img_1720.jpg;2.6673129208327673
#
#
#
# 56 работаем  с файлом:  ..\avto\start_dataset\test\img_1819.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1819.jpg;3.3543930589679416
#
#
#
# 57 работаем  с файлом:  ..\avto\start_dataset\test\img_1821.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1821.jpg;4.366835313069123
#
#
#
# 58 работаем  с файлом:  ..\avto\start_dataset\test\img_1823.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1823.jpg;5.616034853086451
#
#
#
# 59 работаем  с файлом:  ..\avto\start_dataset\test\img_1825.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1825.jpg;6.219701508325112
#
#
#
# 60 работаем  с файлом:  ..\avto\start_dataset\test\img_1826.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1826.jpg;6.885446907561875
#
#
#
# 61 работаем  с файлом:  ..\avto\start_dataset\test\img_1828.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1828.jpg;4.793562928750536
#
#
#
# 62 работаем  с файлом:  ..\avto\start_dataset\test\img_1830.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1830.jpg;3.3539435690757156
#
#
#
# 63 работаем  с файлом:  ..\avto\start_dataset\test\img_1833.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1833.jpg;2.5340797640062926
#
#
#
# 64 работаем  с файлом:  ..\avto\start_dataset\test\img_1836.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1836.jpg;3.6182671001648177
#
#
#
# 65 работаем  с файлом:  ..\avto\start_dataset\test\img_1839.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1839.jpg;5.161808782460675
#
#
#
# 66 работаем  с файлом:  ..\avto\start_dataset\test\img_1840.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1840.jpg;1.6860531893346133
#
#
#
# 67 работаем  с файлом:  ..\avto\start_dataset\test\img_1842.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1842.jpg;3.6872446862115305
#
#
#
# 68 работаем  с файлом:  ..\avto\start_dataset\test\img_1843.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1843.jpg;3.6670486937643365
#
#
#
# 69 работаем  с файлом:  ..\avto\start_dataset\test\img_1844.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1844.jpg;3.5261946283448946
#
#
#
# 70 работаем  с файлом:  ..\avto\start_dataset\test\img_1846.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1846.jpg;4.987748999114542
#
#
#
# 71 работаем  с файлом:  ..\avto\start_dataset\test\img_1849.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1849.jpg;4.915513415289031
#
#
#
# 72 работаем  с файлом:  ..\avto\start_dataset\test\img_1851.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1851.jpg;3.41186066382547
#
#
#
# 73 работаем  с файлом:  ..\avto\start_dataset\test\img_1852.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1852.jpg;6.1817125413375535
#
#
#
# 74 работаем  с файлом:  ..\avto\start_dataset\test\img_1855.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1855.jpg;4.095880931504158
#
#
#
# 75 работаем  с файлом:  ..\avto\start_dataset\test\img_1858.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1858.jpg;2.1620654023279062
#
#
#
# 76 работаем  с файлом:  ..\avto\start_dataset\test\img_1859.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1859.jpg;1.7104340262035942
#
#
#
# 77 работаем  с файлом:  ..\avto\start_dataset\test\img_1866.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1866.jpg;2.382617786772367
#
#
#
# 78 работаем  с файлом:  ..\avto\start_dataset\test\img_1867.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1867.jpg;1.8257600025911358
#
#
#
# 79 работаем  с файлом:  ..\avto\start_dataset\test\img_1868.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1868.jpg;3.6508075370579602
#
#
#
# 80 работаем  с файлом:  ..\avto\start_dataset\test\img_1869.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1869.jpg;4.232864114128891
#
#
#
# 81 работаем  с файлом:  ..\avto\start_dataset\test\img_1870.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1870.jpg;4.729693498251003
#
#
#
# 82 работаем  с файлом:  ..\avto\start_dataset\test\img_1871.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1871.jpg;5.213866115669685
#
#
#
# 83 работаем  с файлом:  ..\avto\start_dataset\test\img_1872.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1872.jpg;6.019588056910633
#
#
#
# 84 работаем  с файлом:  ..\avto\start_dataset\test\img_1873.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1873.jpg;6.028329830657142
#
#
#
# 85 работаем  с файлом:  ..\avto\start_dataset\test\img_1875.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1875.jpg;6.325240804630316
#
#
#
# 86 работаем  с файлом:  ..\avto\start_dataset\test\img_1876.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1876.jpg;7.268642848679096
#
#
#
# 87 работаем  с файлом:  ..\avto\start_dataset\test\img_1877.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1877.jpg;7.9180681301242855
#
#
#
# 88 работаем  с файлом:  ..\avto\start_dataset\test\img_1879.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1879.jpg;9.126531097132261
#
#
#
# 89 работаем  с файлом:  ..\avto\start_dataset\test\img_1880.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1880.jpg;9.853200335434636
#
#
#
# 90 работаем  с файлом:  ..\avto\start_dataset\test\img_1884.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1884.jpg;4.761647799244562
#
#
#
# 91 работаем  с файлом:  ..\avto\start_dataset\test\img_1888.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1888.jpg;2.0929804015653035
#
#
#
# 92 работаем  с файлом:  ..\avto\start_dataset\test\img_1889.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1889.jpg;1.6114100318797664
#
#
#
# 93 работаем  с файлом:  ..\avto\start_dataset\test\img_1891.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1891.jpg;3.1068345431956432
#
#
#
# 94 работаем  с файлом:  ..\avto\start_dataset\test\img_1892.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1892.jpg;3.779951627126619
#
#
#
# 95 работаем  с файлом:  ..\avto\start_dataset\test\img_1894.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1894.jpg;4.901259684554832
#
#
#
# 96 работаем  с файлом:  ..\avto\start_dataset\test\img_1895.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1895.jpg;5.256041207572675
#
#
#
# 97 работаем  с файлом:  ..\avto\start_dataset\test\img_1897.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1897.jpg;6.806958410794827
#
#
#
# 98 работаем  с файлом:  ..\avto\start_dataset\test\img_1898.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1898.jpg;6.766900027396117
#
#
#
# 99 работаем  с файлом:  ..\avto\start_dataset\test\img_1900.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1900.jpg;4.509591211482581
#
#
#
# 100 работаем  с файлом:  ..\avto\start_dataset\test\img_1904.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1904.jpg;4.345172826795353
#
#
#
# 101 работаем  с файлом:  ..\avto\start_dataset\test\img_1905.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1905.jpg;7.9613749385259505
#
#
#
# 102 работаем  с файлом:  ..\avto\start_dataset\test\img_1906.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1906.jpg;7.314445833870087
#
#
#
# 103 работаем  с файлом:  ..\avto\start_dataset\test\img_1908.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1908.jpg;6.170280695942093
#
#
#
# 104 работаем  с файлом:  ..\avto\start_dataset\test\img_1911.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1911.jpg;4.153110657906683
#
#
#
# 105 работаем  с файлом:  ..\avto\start_dataset\test\img_1913.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1913.jpg;2.946666005460218
#
#
#
# 106 работаем  с файлом:  ..\avto\start_dataset\test\img_1914.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1914.jpg;2.351207516724309
#
#
#
# 107 работаем  с файлом:  ..\avto\start_dataset\test\img_1915.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1915.jpg;5.60540148629023
#
#
#
# 108 работаем  с файлом:  ..\avto\start_dataset\test\img_1917.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1917.jpg;4.062364182742256
#
#
#
# 109 работаем  с файлом:  ..\avto\start_dataset\test\img_1919.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1919.jpg;2.769654543331141
#
#
#
# 110 работаем  с файлом:  ..\avto\start_dataset\test\img_1920.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1920.jpg;2.270120190032992
#
#
#
# 111 работаем  с файлом:  ..\avto\start_dataset\test\img_1923.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1923.jpg;4.23863201646318
#
#
#
# 112 работаем  с файлом:  ..\avto\start_dataset\test\img_1928.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1928.jpg;6.999184475142238
#
#
#
# 113 работаем  с файлом:  ..\avto\start_dataset\test\img_1931.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1931.jpg;3.3367883285880886
#
#
#
# 114 работаем  с файлом:  ..\avto\start_dataset\test\img_1934.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1934.jpg;4.0324842321539425
#
#
#
# 115 работаем  с файлом:  ..\avto\start_dataset\test\img_1935.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1935.jpg;4.822057074758912
#
#
#
# 116 работаем  с файлом:  ..\avto\start_dataset\test\img_1936.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1936.jpg;5.086248742109306
#
#
#
# 117 работаем  с файлом:  ..\avto\start_dataset\test\img_1940.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1940.jpg;6.701765489904704
#
#
#
# 118 работаем  с файлом:  ..\avto\start_dataset\test\img_1941.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1941.jpg;5.092606887315776
#
#
#
# 119 работаем  с файлом:  ..\avto\start_dataset\test\img_1942.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1942.jpg;4.375298266736317
#
#
#
# 120 работаем  с файлом:  ..\avto\start_dataset\test\img_1943.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1943.jpg;3.7640469753879526
#
#
#
# 121 работаем  с файлом:  ..\avto\start_dataset\test\img_1944.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1944.jpg;3.2628800249467216
#
#
#
# 122 работаем  с файлом:  ..\avto\start_dataset\test\img_1946.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1946.jpg;2.1277999348810113
#
#
#
# 123 работаем  с файлом:  ..\avto\start_dataset\test\img_1947.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1947.jpg;3.2956667638112407
#
#
#
# 124 работаем  с файлом:  ..\avto\start_dataset\test\img_1949.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1949.jpg;4.708074031345135
#
#
#
# 125 работаем  с файлом:  ..\avto\start_dataset\test\img_1952.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1952.jpg;6.431130113768772
#
#
#
# 126 работаем  с файлом:  ..\avto\start_dataset\test\img_1953.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1953.jpg;7.012886729305047
#
#
#
# 127 работаем  с файлом:  ..\avto\start_dataset\test\img_1954.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1954.jpg;8.15779840875123
#
#
#
# 128 работаем  с файлом:  ..\avto\start_dataset\test\img_1955.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1955.jpg;8.067924213151953
#
#
#
# 129 работаем  с файлом:  ..\avto\start_dataset\test\img_1956.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1956.jpg;6.294007540338727
#
#
#
# 130 работаем  с файлом:  ..\avto\start_dataset\test\img_1957.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1957.jpg;5.304721603422351
#
#
#
# 131 работаем  с файлом:  ..\avto\start_dataset\test\img_1960.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1960.jpg;3.0935590650268647
#
#
#
# 132 работаем  с файлом:  ..\avto\start_dataset\test\img_1961.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1961.jpg;2.4792631663618874
#
#
#
# 133 работаем  с файлом:  ..\avto\start_dataset\test\img_1962.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1962.jpg;1.8528190094813668
#
#
#
# 134 работаем  с файлом:  ..\avto\start_dataset\test\img_1969.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1969.jpg;7.170655402476536
#
#
#
# 135 работаем  с файлом:  ..\avto\start_dataset\test\img_1972.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1972.jpg;3.038845653433309
#
#
#
# 136 работаем  с файлом:  ..\avto\start_dataset\test\img_1974.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1974.jpg;1.8611263448875157
#
#
#
# 137 работаем  с файлом:  ..\avto\start_dataset\test\img_1975.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1975.jpg;1.3794512285989435
#
#
#
# 138 работаем  с файлом:  ..\avto\start_dataset\test\img_1978.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1978.jpg;2.844516095260268
#
#
#
# 139 работаем  с файлом:  ..\avto\start_dataset\test\img_1981.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1981.jpg;2.424756036532433
#
#
#
# 140 работаем  с файлом:  ..\avto\start_dataset\test\img_1982.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1982.jpg;3.0956681847182748
#
#
#
# 141 работаем  с файлом:  ..\avto\start_dataset\test\img_1986.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1986.jpg;5.349221607270868
#
#
#
# 142 работаем  с файлом:  ..\avto\start_dataset\test\img_1987.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1987.jpg;5.415018222776042
#
#
#
# 143 работаем  с файлом:  ..\avto\start_dataset\test\img_1988.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1988.jpg;5.826660315103295
#
#
#
# 144 работаем  с файлом:  ..\avto\start_dataset\test\img_1989.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1989.jpg;6.124430866329775
#
#
#
# 145 работаем  с файлом:  ..\avto\start_dataset\test\img_1990.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1990.jpg;6.2417533086287005
#
#
#
# 146 работаем  с файлом:  ..\avto\start_dataset\test\img_1993.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1993.jpg;4.618097706778266
#
#
#
# 147 работаем  с файлом:  ..\avto\start_dataset\test\img_1995.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1995.jpg;3.562602017969135
#
#
#
# 148 работаем  с файлом:  ..\avto\start_dataset\test\img_1997.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1997.jpg;2.3961456549945055
#
#
#
# 149 работаем  с файлом:  ..\avto\start_dataset\test\img_1998.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1998.jpg;1.959565464951324
#
#
#
# 150 работаем  с файлом:  ..\avto\start_dataset\test\img_1999.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_1999.jpg;1.511356494194387
#
#
#
# 151 работаем  с файлом:  ..\avto\start_dataset\test\img_2004.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2004.jpg;3.414453719369406
#
#
#
# 152 работаем  с файлом:  ..\avto\start_dataset\test\img_2006.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2006.jpg;4.160949806984709
#
#
#
# 153 работаем  с файлом:  ..\avto\start_dataset\test\img_2009.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2009.jpg;4.32322786961149
#
#
#
# 154 работаем  с файлом:  ..\avto\start_dataset\test\img_2011.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2011.jpg;2.8314796989469975
#
#
#
# 155 работаем  с файлом:  ..\avto\start_dataset\test\img_2013.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2013.jpg;4.097677457195313
#
#
#
# 156 работаем  с файлом:  ..\avto\start_dataset\test\img_2015.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2015.jpg;5.035888663493496
#
#
#
# 157 работаем  с файлом:  ..\avto\start_dataset\test\img_2017.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2017.jpg;5.932447304342999
#
#
#
# 158 работаем  с файлом:  ..\avto\start_dataset\test\img_2019.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2019.jpg;3.3014238316744913
#
#
#
# 159 работаем  с файлом:  ..\avto\start_dataset\test\img_2020.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2020.jpg;2.651868494871882
#
#
#
# 160 работаем  с файлом:  ..\avto\start_dataset\test\img_2022.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2022.jpg;2.548186557935328
#
#
#
# 161 работаем  с файлом:  ..\avto\start_dataset\test\img_2023.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2023.jpg;3.189617664237626
#
#
#
# 162 работаем  с файлом:  ..\avto\start_dataset\test\img_2024.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2024.jpg;3.754010572194562
#
#
#
# 163 работаем  с файлом:  ..\avto\start_dataset\test\img_2028.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2028.jpg;5.778940333160046
#
#
#
# 164 работаем  с файлом:  ..\avto\start_dataset\test\img_2029.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2029.jpg;6.418517265810605
#
#
#
# 165 работаем  с файлом:  ..\avto\start_dataset\test\img_2257.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2257.jpg;2.87339826390735
#
#
#
# 166 работаем  с файлом:  ..\avto\start_dataset\test\img_2258.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2258.jpg;3.913241958187108
#
#
#
# 167 работаем  с файлом:  ..\avto\start_dataset\test\img_2259.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2259.jpg;4.305901563972355
#
#
#
# 168 работаем  с файлом:  ..\avto\start_dataset\test\img_2262.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2262.jpg;3.5711373601503493
#
#
#
# 169 работаем  с файлом:  ..\avto\start_dataset\test\img_2263.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2263.jpg;2.4761176541847445
#
#
#
# 170 работаем  с файлом:  ..\avto\start_dataset\test\img_2265.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2265.jpg;3.3866802752902805
#
#
#
# 171 работаем  с файлом:  ..\avto\start_dataset\test\img_2267.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2267.jpg;2.183723797547637
#
#
#
# 172 работаем  с файлом:  ..\avto\start_dataset\test\img_2273.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2273.jpg;5.218577790119793
#
#
#
# 173 работаем  с файлом:  ..\avto\start_dataset\test\img_2274.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2274.jpg;5.663229138392355
#
#
#
# 174 работаем  с файлом:  ..\avto\start_dataset\test\img_2276.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2276.jpg;7.096235303950796
#
#
#
# 175 работаем  с файлом:  ..\avto\start_dataset\test\img_2279.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2279.jpg;5.011457705797097
#
#
#
# 176 работаем  с файлом:  ..\avto\start_dataset\test\img_2281.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2281.jpg;3.3374789937169154
#
#
#
# 177 работаем  с файлом:  ..\avto\start_dataset\test\img_2283.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2283.jpg;3.0748737080229227
#
#
#
# 178 работаем  с файлом:  ..\avto\start_dataset\test\img_2284.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2284.jpg;3.705989212569043
#
#
#
# 179 работаем  с файлом:  ..\avto\start_dataset\test\img_2286.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2286.jpg;4.969476943120013
#
#
#
# 180 работаем  с файлом:  ..\avto\start_dataset\test\img_2288.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2288.jpg;6.179113180954748
#
#
#
# 181 работаем  с файлом:  ..\avto\start_dataset\test\img_2292.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2292.jpg;3.6244524476699542
#
#
#
# 182 работаем  с файлом:  ..\avto\start_dataset\test\img_2293.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2293.jpg;2.5177298520688236
#
#
#
# 183 работаем  с файлом:  ..\avto\start_dataset\test\img_2298.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2298.jpg;3.780269322061075
#
#
#
# 184 работаем  с файлом:  ..\avto\start_dataset\test\img_2299.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2299.jpg;3.3661828827156315
#
#
#
# 185 работаем  с файлом:  ..\avto\start_dataset\test\img_2303.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2303.jpg;1.2158276873302676
#
#
#
# 186 работаем  с файлом:  ..\avto\start_dataset\test\img_2307.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2307.jpg;3.7410089373880613
#
#
#
# 187 работаем  с файлом:  ..\avto\start_dataset\test\img_2311.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2311.jpg;6.062876972325378
#
#
#
# 188 работаем  с файлом:  ..\avto\start_dataset\test\img_2312.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2312.jpg;6.516049215392793
#
#
#
# 189 работаем  с файлом:  ..\avto\start_dataset\test\img_2314.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2314.jpg;4.293279636161694
#
#
#
# 190 работаем  с файлом:  ..\avto\start_dataset\test\img_2315.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2315.jpg;3.680326294831644
#
#
#
# 191 работаем  с файлом:  ..\avto\start_dataset\test\img_2317.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2317.jpg;2.1398986647284692
#
#
#
# 192 работаем  с файлом:  ..\avto\start_dataset\test\img_2318.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2318.jpg;2.967111195045832
#
#
#
# 193 работаем  с файлом:  ..\avto\start_dataset\test\img_2323.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2323.jpg;2.9114833420469397
#
#
#
# 194 работаем  с файлом:  ..\avto\start_dataset\test\img_2324.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2324.jpg;3.5235394895663936
#
#
#
# 195 работаем  с файлом:  ..\avto\start_dataset\test\img_2325.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2325.jpg;4.092921690303141
#
#
#
# 196 работаем  с файлом:  ..\avto\start_dataset\test\img_2326.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2326.jpg;4.592264972896828
#
#
#
# 197 работаем  с файлом:  ..\avto\start_dataset\test\img_2328.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2328.jpg;5.8673427565074965
#
#
#
# 198 работаем  с файлом:  ..\avto\start_dataset\test\img_2329.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2329.jpg;6.444827155581934
#
#
#
# 199 работаем  с файлом:  ..\avto\start_dataset\test\img_2334.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2334.jpg;4.014496543582072
#
#
#
# 200 работаем  с файлом:  ..\avto\start_dataset\test\img_2335.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2335.jpg;4.797976108007554
#
#
#
# 201 работаем  с файлом:  ..\avto\start_dataset\test\img_2337.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2337.jpg;5.695698065265286
#
#
#
# 202 работаем  с файлом:  ..\avto\start_dataset\test\img_2338.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2338.jpg;6.211763496584433
#
#
#
# 203 работаем  с файлом:  ..\avto\start_dataset\test\img_2339.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2339.jpg;6.68561297180804
#
#
#
# 204 работаем  с файлом:  ..\avto\start_dataset\test\img_2340.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2340.jpg;7.615587428596542
#
#
#
# 205 работаем  с файлом:  ..\avto\start_dataset\test\img_2343.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2343.jpg;3.399737924877185
#
#
#
# 206 работаем  с файлом:  ..\avto\start_dataset\test\img_2346.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2346.jpg;2.1065802168107606
#
#
#
# 207 работаем  с файлом:  ..\avto\start_dataset\test\img_2349.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2349.jpg;3.6099763757021583
#
#
#
# 208 работаем  с файлом:  ..\avto\start_dataset\test\img_2351.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2351.jpg;1.96728381550791
#
#
#
# 209 работаем  с файлом:  ..\avto\start_dataset\test\img_2353.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2353.jpg;2.9261466807767786
#
#
#
# 210 работаем  с файлом:  ..\avto\start_dataset\test\img_2354.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2354.jpg;3.5497709744271084
#
#
#
# 211 работаем  с файлом:  ..\avto\start_dataset\test\img_2355.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2355.jpg;4.06005325502154
#
#
#
# 212 работаем  с файлом:  ..\avto\start_dataset\test\img_2356.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2356.jpg;4.378875552447372
#
#
#
# 213 работаем  с файлом:  ..\avto\start_dataset\test\img_2357.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2357.jpg;4.964823826012037
#
#
#
# 214 работаем  с файлом:  ..\avto\start_dataset\test\img_2358.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2358.jpg;2.4711162490607186
#
#
#
# 215 работаем  с файлом:  ..\avto\start_dataset\test\img_2360.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2360.jpg;2.9510808749470288
#
#
#
# 216 работаем  с файлом:  ..\avto\start_dataset\test\img_2362.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2362.jpg;3.9710380621379144
#
#
#
# 217 работаем  с файлом:  ..\avto\start_dataset\test\img_2363.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2363.jpg;4.61299461475116
#
#
#
# 218 работаем  с файлом:  ..\avto\start_dataset\test\img_2364.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2364.jpg;5.139829313805058
#
#
#
# 219 работаем  с файлом:  ..\avto\start_dataset\test\img_2365.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2365.jpg;5.843036227224981
#
#
#
# 220 работаем  с файлом:  ..\avto\start_dataset\test\img_2366.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2366.jpg;5.931683197278273
#
#
#
# 221 работаем  с файлом:  ..\avto\start_dataset\test\img_2367.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2367.jpg;5.122109431016075
#
#
#
# 222 работаем  с файлом:  ..\avto\start_dataset\test\img_2368.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2368.jpg;4.474982254500803
#
#
#
# 223 работаем  с файлом:  ..\avto\start_dataset\test\img_2370.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2370.jpg;2.926749974450972
#
#
#
# 224 работаем  с файлом:  ..\avto\start_dataset\test\img_2371.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2371.jpg;2.263253084560404
#
#
#
# 225 работаем  с файлом:  ..\avto\start_dataset\test\img_2375.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2375.jpg;2.31432820960745
#
#
#
# 226 работаем  с файлом:  ..\avto\start_dataset\test\img_2377.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2377.jpg;3.3084556397472107
#
#
#
# 227 работаем  с файлом:  ..\avto\start_dataset\test\img_2379.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2379.jpg;4.73177737649228
#
#
#
# 228 работаем  с файлом:  ..\avto\start_dataset\test\img_2380.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2380.jpg;5.442948148844508
#
#
#
# 229 работаем  с файлом:  ..\avto\start_dataset\test\img_2381.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2381.jpg;5.794732153814529
#
#
#
# 230 работаем  с файлом:  ..\avto\start_dataset\test\img_2382.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2382.jpg;4.616864783083409
#
#
#
# 231 работаем  с файлом:  ..\avto\start_dataset\test\img_2386.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2386.jpg;2.0867597862636185
#
#
#
# 232 работаем  с файлом:  ..\avto\start_dataset\test\img_2387.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2387.jpg;1.5578372669703875
#
#
#
# 233 работаем  с файлом:  ..\avto\start_dataset\test\img_2388.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2388.jpg;2.2928803224904364
#
#
#
# 234 работаем  с файлом:  ..\avto\start_dataset\test\img_2389.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2389.jpg;1.5990038453409325
#
#
#
# 235 работаем  с файлом:  ..\avto\start_dataset\test\img_2391.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2391.jpg;2.951049508116278
#
#
#
# 236 работаем  с файлом:  ..\avto\start_dataset\test\img_2392.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2392.jpg;2.4933038623786024
#
#
#
# 237 работаем  с файлом:  ..\avto\start_dataset\test\img_2393.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2393.jpg;1.8974735908193991
#
#
#
# 238 работаем  с файлом:  ..\avto\start_dataset\test\img_2394.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2394.jpg;1.3730055067227054
#
#
#
# 239 работаем  с файлом:  ..\avto\start_dataset\test\img_2395.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2395.jpg;1.088414702748507
#
#
#
# 240 работаем  с файлом:  ..\avto\start_dataset\test\img_2396.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2396.jpg;2.702672832557083
#
#
#
# 241 работаем  с файлом:  ..\avto\start_dataset\test\img_2399.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2399.jpg;4.381623409680283
#
#
#
# 242 работаем  с файлом:  ..\avto\start_dataset\test\img_2400.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2400.jpg;4.444970477624667
#
#
#
# 243 работаем  с файлом:  ..\avto\start_dataset\test\img_2401.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2401.jpg;2.5333077854220885
#
#
#
# 244 работаем  с файлом:  ..\avto\start_dataset\test\img_2402.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2402.jpg;1.90397132492033
#
#
#
# 245 работаем  с файлом:  ..\avto\start_dataset\test\img_2403.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2403.jpg;6.049681318763926
#
#
#
# 246 работаем  с файлом:  ..\avto\start_dataset\test\img_2407.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2407.jpg;3.174426087181143
#
#
#
# 247 работаем  с файлом:  ..\avto\start_dataset\test\img_2412.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2412.jpg;2.713985224604057
#
#
#
# 248 работаем  с файлом:  ..\avto\start_dataset\test\img_2413.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2413.jpg;3.0781899752306714
#
#
#
# 249 работаем  с файлом:  ..\avto\start_dataset\test\img_2414.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2414.jpg;2.130329680885159
#
#
#
# 250 работаем  с файлом:  ..\avto\start_dataset\test\img_2415.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2415.jpg;2.4372112836827267
#
#
#
# 251 работаем  с файлом:  ..\avto\start_dataset\test\img_2416.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2416.jpg;2.937065472729615
#
#
#
# 252 работаем  с файлом:  ..\avto\start_dataset\test\img_2417.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2417.jpg;3.3968376662569764
#
#
#
# 253 работаем  с файлом:  ..\avto\start_dataset\test\img_2419.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2419.jpg;1.9753982005174953
#
#
#
# 254 работаем  с файлом:  ..\avto\start_dataset\test\img_2421.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2421.jpg;3.306522995008091
#
#
#
# 255 работаем  с файлом:  ..\avto\start_dataset\test\img_2424.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2424.jpg;3.256018294444453
#
#
#
# 256 работаем  с файлом:  ..\avto\start_dataset\test\img_2425.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2425.jpg;2.6538120845664896
#
#
#
# 257 работаем  с файлом:  ..\avto\start_dataset\test\img_2428.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2428.jpg;3.3470024147515685
#
#
#
# 258 работаем  с файлом:  ..\avto\start_dataset\test\img_2431.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2431.jpg;1.6546203841902511
#
#
#
# 259 работаем  с файлом:  ..\avto\start_dataset\test\img_2433.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2433.jpg;2.622029016833856
#
#
#
# 260 работаем  с файлом:  ..\avto\start_dataset\test\img_2435.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2435.jpg;3.8208019110995823
#
#
#
# 261 работаем  с файлом:  ..\avto\start_dataset\test\img_2438.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2438.jpg;5.59567830449124
#
#
#
# 262 работаем  с файлом:  ..\avto\start_dataset\test\img_2439.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2439.jpg;5.8436639204674
#
#
#
# 263 работаем  с файлом:  ..\avto\start_dataset\test\img_2441.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2441.jpg;7.090010579154343
#
#
#
# 264 работаем  с файлом:  ..\avto\start_dataset\test\img_2444.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2444.jpg;3.924572741017695
#
#
#
# 265 работаем  с файлом:  ..\avto\start_dataset\test\img_2446.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2446.jpg;2.7287688250268602
#
#
#
# 266 работаем  с файлом:  ..\avto\start_dataset\test\img_2447.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2447.jpg;2.182755352649601
#
#
#
# 267 работаем  с файлом:  ..\avto\start_dataset\test\img_2448.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2448.jpg;1.6197340301158447
#
#
#
# 268 работаем  с файлом:  ..\avto\start_dataset\test\img_2456.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2456.jpg;5.898307072243343
#
#
#
# 269 работаем  с файлом:  ..\avto\start_dataset\test\img_2457.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2457.jpg;6.005019084111035
#
#
#
# 270 работаем  с файлом:  ..\avto\start_dataset\test\img_2461.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2461.jpg;3.5075310344161257
#
#
#
# 271 работаем  с файлом:  ..\avto\start_dataset\test\img_2464.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2464.jpg;1.4008470326517481
#
#
#
# 272 работаем  с файлом:  ..\avto\start_dataset\test\img_2465.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2465.jpg;5.077082452792938
#
#
#
# 273 работаем  с файлом:  ..\avto\start_dataset\test\img_2466.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2466.jpg;4.759540730858058
#
#
#
# 274 работаем  с файлом:  ..\avto\start_dataset\test\img_2467.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2467.jpg;4.0962105397739865
#
#
#
# 275 работаем  с файлом:  ..\avto\start_dataset\test\img_2471.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2471.jpg;2.3804663025754342
#
#
#
# 276 работаем  с файлом:  ..\avto\start_dataset\test\img_2472.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2472.jpg;1.8111046574195575
#
#
#
# 277 работаем  с файлом:  ..\avto\start_dataset\test\img_2473.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2473.jpg;1.362536016526162
#
#
#
# 278 работаем  с файлом:  ..\avto\start_dataset\test\img_2475.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2475.jpg;2.3178909577806253
#
#
#
# 279 работаем  с файлом:  ..\avto\start_dataset\test\img_2478.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2478.jpg;3.906010904500673
#
#
#
# 280 работаем  с файлом:  ..\avto\start_dataset\test\img_2479.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2479.jpg;4.217833058714083
#
#
#
# 281 работаем  с файлом:  ..\avto\start_dataset\test\img_2481.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2481.jpg;3.240004710502732
#
#
#
# 282 работаем  с файлом:  ..\avto\start_dataset\test\img_2482.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2482.jpg;2.6278442026000146
#
#
#
# 283 работаем  с файлом:  ..\avto\start_dataset\test\img_2483.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2483.jpg;2.0719269014179913
#
#
#
# 284 работаем  с файлом:  ..\avto\start_dataset\test\img_2486.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2486.jpg;3.715827000474885
#
#
#
# 285 работаем  с файлом:  ..\avto\start_dataset\test\img_2488.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2488.jpg;4.825879739139046
#
#
#
# 286 работаем  с файлом:  ..\avto\start_dataset\test\img_2489.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2489.jpg;3.864623808930493
#
#
#
# 287 работаем  с файлом:  ..\avto\start_dataset\test\img_2491.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2491.jpg;5.680993102055503
#
#
#
# 288 работаем  с файлом:  ..\avto\start_dataset\test\img_2493.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2493.jpg;6.428023107120902
#
#
#
# 289 работаем  с файлом:  ..\avto\start_dataset\test\img_2496.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2496.jpg;5.333185752941059
#
#
#
# 290 работаем  с файлом:  ..\avto\start_dataset\test\img_2497.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2497.jpg;4.766889166076535
#
#
#
# 291 работаем  с файлом:  ..\avto\start_dataset\test\img_2498.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2498.jpg;3.9800566726714766
#
#
#
# 292 работаем  с файлом:  ..\avto\start_dataset\test\img_2499.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2499.jpg;2.7826778346757166
#
#
#
# 293 работаем  с файлом:  ..\avto\start_dataset\test\img_2500.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2500.jpg;3.2685533436714374
#
#
#
# 294 работаем  с файлом:  ..\avto\start_dataset\test\img_2501.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2501.jpg;3.871197486195077
#
#
#
# 295 работаем  с файлом:  ..\avto\start_dataset\test\img_2506.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2506.jpg;6.250967607823768
#
#
#
# 296 работаем  с файлом:  ..\avto\start_dataset\test\img_2508.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2508.jpg;4.544472675463318
#
#
#
# 297 работаем  с файлом:  ..\avto\start_dataset\test\img_2509.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2509.jpg;3.7909659884027413
#
#
#
# 298 работаем  с файлом:  ..\avto\start_dataset\test\img_2513.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2513.jpg;2.760240303884469
#
#
#
# 299 работаем  с файлом:  ..\avto\start_dataset\test\img_2515.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2515.jpg;1.5288354010035041
#
#
#
# 300 работаем  с файлом:  ..\avto\start_dataset\test\img_2517.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2517.jpg;3.1209169846587734
#
#
#
# 301 работаем  с файлом:  ..\avto\start_dataset\test\img_2518.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2518.jpg;3.7781599240491714
#
#
#
# 302 работаем  с файлом:  ..\avto\start_dataset\test\img_2521.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2521.jpg;1.4491895369451786
#
#
#
# 303 работаем  с файлом:  ..\avto\start_dataset\test\img_2522.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2522.jpg;2.546945783270213
#
#
#
# 304 работаем  с файлом:  ..\avto\start_dataset\test\img_2523.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2523.jpg;3.170430236709174
#
#
#
# 305 работаем  с файлом:  ..\avto\start_dataset\test\img_2524.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2524.jpg;3.7892342714214253
#
#
#
# 306 работаем  с файлом:  ..\avto\start_dataset\test\img_2525.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2525.jpg;3.5905649149620187
#
#
#
# 307 работаем  с файлом:  ..\avto\start_dataset\test\img_2526.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2526.jpg;4.163670474010004
#
#
#
# 308 работаем  с файлом:  ..\avto\start_dataset\test\img_2529.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2529.jpg;5.950255775286846
#
#
#
# 309 работаем  с файлом:  ..\avto\start_dataset\test\img_2530.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2530.jpg;6.321228535907031
#
#
#
# 310 работаем  с файлом:  ..\avto\start_dataset\test\img_2531.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2531.jpg;4.620000787293495
#
#
#
# 311 работаем  с файлом:  ..\avto\start_dataset\test\img_2532.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2532.jpg;3.9148790681484478
#
#
#
# 312 работаем  с файлом:  ..\avto\start_dataset\test\img_2534.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2534.jpg;2.5421714308381747
#
#
#
# 313 работаем  с файлом:  ..\avto\start_dataset\test\img_2537.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2537.jpg;2.004867523274643
#
#
#
# 314 работаем  с файлом:  ..\avto\start_dataset\test\img_2540.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2540.jpg;4.315027482647011
#
#
#
# 315 работаем  с файлом:  ..\avto\start_dataset\test\img_2541.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2541.jpg;4.759242680954988
#
#
#
# 316 работаем  с файлом:  ..\avto\start_dataset\test\img_2542.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2542.jpg;5.2946926776312155
#
#
#
# 317 работаем  с файлом:  ..\avto\start_dataset\test\img_2543.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2543.jpg;5.733605294186206
#
#
#
# 318 работаем  с файлом:  ..\avto\start_dataset\test\img_2545.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2545.jpg;7.09434632083485
#
#
#
# 319 работаем  с файлом:  ..\avto\start_dataset\test\img_2546.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2546.jpg;7.519813138101565
#
#
#
# 320 работаем  с файлом:  ..\avto\start_dataset\test\img_2551.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2551.jpg;2.141012120424352
#
#
#
# 321 работаем  с файлом:  ..\avto\start_dataset\test\img_2552.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2552.jpg;2.772574533272
#
#
#
# 322 работаем  с файлом:  ..\avto\start_dataset\test\img_2555.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2555.jpg;4.459107950515572
#
#
#
# 323 работаем  с файлом:  ..\avto\start_dataset\test\img_2556.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2556.jpg;5.10678159143319
#
#
#
# 324 работаем  с файлом:  ..\avto\start_dataset\test\img_2557.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2557.jpg;5.61750501410213
#
#
#
# 325 работаем  с файлом:  ..\avto\start_dataset\test\img_2558.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2558.jpg;5.8329228391340235
#
#
#
# 326 работаем  с файлом:  ..\avto\start_dataset\test\img_2559.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2559.jpg;6.7176238290684385
#
#
#
# 327 работаем  с файлом:  ..\avto\start_dataset\test\img_2560.jpg
# ...
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2711.jpg;5.129554879036231
#
#
#
# 420 работаем  с файлом:  ..\avto\start_dataset\test\img_2712.heic
# Сконвертирован Y:\img_2712.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2712.heic;2.1094712494854564
#
#
#
# 421 работаем  с файлом:  ..\avto\start_dataset\test\img_2713.heic
# Сконвертирован Y:\img_2713.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2713.heic;2.6628463511468583
#
#
#
# 422 работаем  с файлом:  ..\avto\start_dataset\test\img_2714.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2714.jpg;5.267368370569456
#
#
#
# 423 работаем  с файлом:  ..\avto\start_dataset\test\img_2715.heic
# Сконвертирован Y:\img_2715.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2715.heic;3.5943905224547175
#
#
#
# 424 работаем  с файлом:  ..\avto\start_dataset\test\img_2715.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2715.jpg;4.788454891476868
#
#
#
# 425 работаем  с файлом:  ..\avto\start_dataset\test\img_2716.heic
# Сконвертирован Y:\img_2716.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2716.heic;4.199820360656666
#
#
#
# 426 работаем  с файлом:  ..\avto\start_dataset\test\img_2717.heic
# Сконвертирован Y:\img_2717.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2717.heic;4.716286297224949
#
#
#
# 427 работаем  с файлом:  ..\avto\start_dataset\test\img_2717.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2717.jpg;3.6593670723943426
#
#
#
# 428 работаем  с файлом:  ..\avto\start_dataset\test\img_2718.heic
# Сконвертирован Y:\img_2718.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2718.heic;5.308310853467679
#
#
#
# 429 работаем  с файлом:  ..\avto\start_dataset\test\img_2718.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2718.jpg;2.976172601038147
#
#
#
# 430 работаем  с файлом:  ..\avto\start_dataset\test\img_2719.heic
# Сконвертирован Y:\img_2719.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2719.heic;5.916300504773948
#
#
#
# 431 работаем  с файлом:  ..\avto\start_dataset\test\img_2719.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2719.jpg;2.304916564631123
#
#
#
# 432 работаем  с файлом:  ..\avto\start_dataset\test\img_2720.heic
# Сконвертирован Y:\img_2720.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2720.heic;6.400580441131037
#
#
#
# 433 работаем  с файлом:  ..\avto\start_dataset\test\img_2720.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2720.jpg;3.332448535591364
#
#
#
# 434 работаем  с файлом:  ..\avto\start_dataset\test\img_2722.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2722.jpg;4.495084587931002
#
#
#
# 435 работаем  с файлом:  ..\avto\start_dataset\test\img_2724.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2724.jpg;3.653949776846532
#
#
#
# 436 работаем  с файлом:  ..\avto\start_dataset\test\img_2725.heic
# Сконвертирован Y:\img_2725.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2725.heic;9.342844935553774
#
#
#
# 437 работаем  с файлом:  ..\avto\start_dataset\test\img_2726.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2726.jpg;2.452192076148627
#
#
#
# 438 работаем  с файлом:  ..\avto\start_dataset\test\img_2727.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2727.jpg;2.0940779631521176
#
#
#
# 439 работаем  с файлом:  ..\avto\start_dataset\test\img_2728.heic
# Сконвертирован Y:\img_2728.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2728.heic;7.529059215627187
#
#
#
# 440 работаем  с файлом:  ..\avto\start_dataset\test\img_2729.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2729.jpg;2.6820507593313594
#
#
#
# 441 работаем  с файлом:  ..\avto\start_dataset\test\img_2731.heic
# Сконвертирован Y:\img_2731.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2731.heic;5.768474747982905
#
#
#
# 442 работаем  с файлом:  ..\avto\start_dataset\test\img_2731.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2731.jpg;3.8401798596456187
#
#
#
# 443 работаем  с файлом:  ..\avto\start_dataset\test\img_2732.heic
# Сконвертирован Y:\img_2732.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2732.heic;5.129170484067956
#
#
#
# 444 работаем  с файлом:  ..\avto\start_dataset\test\img_2733.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2733.jpg;4.896775348694827
#
#
#
# 445 работаем  с файлом:  ..\avto\start_dataset\test\img_2734.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2734.jpg;5.4393710159785185
#
#
#
# 446 работаем  с файлом:  ..\avto\start_dataset\test\img_2736.heic
# Сконвертирован Y:\img_2736.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2736.heic;2.8413372571987257
#
#
#
# 447 работаем  с файлом:  ..\avto\start_dataset\test\img_2736.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2736.jpg;5.995491345533747
#
#
#
# 448 работаем  с файлом:  ..\avto\start_dataset\test\img_2738.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2738.jpg;7.150539020653829
#
#
#
# 449 работаем  с файлом:  ..\avto\start_dataset\test\img_2739.heic
# Сконвертирован Y:\img_2739.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2739.heic;1.5224489071296243
#
#
#
# 450 работаем  с файлом:  ..\avto\start_dataset\test\img_2740.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2740.jpg;7.253670347404023
#
#
#
# 451 работаем  с файлом:  ..\avto\start_dataset\test\img_2742.heic
# Сконвертирован Y:\img_2742.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2742.heic;3.2327071643753857
#
#
#
# 452 работаем  с файлом:  ..\avto\start_dataset\test\img_2744.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2744.jpg;4.53846226028609
#
#
#
# 453 работаем  с файлом:  ..\avto\start_dataset\test\img_2746.jpg
# focus, digital_zoom 14 1.0595655220742817
# ВЫХОД img_2746.jpg;5.205408916495768
#
#
#
# 454 работаем  с файлом:  ..\avto\start_dataset\test\img_2749.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2749.jpg;4.00967930967343
#
#
#
# 455 работаем  с файлом:  ..\avto\start_dataset\test\img_2750.heic
# Сконвертирован Y:\img_2750.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2750.heic;3.979738691598979
#
#
#
# 456 работаем  с файлом:  ..\avto\start_dataset\test\img_2752.heic
# Сконвертирован Y:\img_2752.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2752.heic;4.83447933981848
#
#
#
# 457 работаем  с файлом:  ..\avto\start_dataset\test\img_2752.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2752.jpg;2.7026297247162434
#
#
#
# 458 работаем  с файлом:  ..\avto\start_dataset\test\img_2753.heic
# Сконвертирован Y:\img_2753.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2753.heic;5.356675865557679
#
#
#
# 459 работаем  с файлом:  ..\avto\start_dataset\test\img_2753.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2753.jpg;2.322778139167522
#
#
#
# 460 работаем  с файлом:  ..\avto\start_dataset\test\img_2754.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2754.jpg;2.0226404413078263
#
#
#
# 461 работаем  с файлом:  ..\avto\start_dataset\test\img_2755.heic
# Сконвертирован Y:\img_2755.jpg
# focus, digital_zoom 14 1.0327868852459017
# ВЫХОД img_2755.heic;6.710285226802176
#
#
#
# 462 работаем  с файлом:  ..\avto\start_dataset\test\img_2756.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2756.jpg;1.325620332641663
#
#
#
# 463 работаем  с файлом:  ..\avto\start_dataset\test\img_2757.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2757.jpg;1.9866906727389688
#
#
#
# 464 работаем  с файлом:  ..\avto\start_dataset\test\img_2758.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2758.jpg;2.5615588778732112
#
#
#
# 465 работаем  с файлом:  ..\avto\start_dataset\test\img_2759.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2759.jpg;2.9769857737915775
#
#
#
# 466 работаем  с файлом:  ..\avto\start_dataset\test\img_2761.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2761.jpg;3.9432990030661137
#
#
#
# 467 работаем  с файлом:  ..\avto\start_dataset\test\img_2762.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2762.jpg;4.36509158952821
#
#
#
# 468 работаем  с файлом:  ..\avto\start_dataset\test\img_2768.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2768.jpg;2.828618088626334
#
#
#
# 469 работаем  с файлом:  ..\avto\start_dataset\test\img_2769.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2769.jpg;2.4330625653790108
#
#
#
# 470 работаем  с файлом:  ..\avto\start_dataset\test\img_2771.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2771.jpg;2.6379124242181264
#
#
#
# 471 работаем  с файлом:  ..\avto\start_dataset\test\img_2772.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2772.jpg;3.039278222401408
#
#
#
# 472 работаем  с файлом:  ..\avto\start_dataset\test\img_2773.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2773.jpg;3.607416582011116
#
#
#
# 473 работаем  с файлом:  ..\avto\start_dataset\test\img_2776.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2776.jpg;4.979228965875763
#
#
#
# 474 работаем  с файлом:  ..\avto\start_dataset\test\img_2777.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2777.jpg;5.35693743254125
#
#
#
# 475 работаем  с файлом:  ..\avto\start_dataset\test\img_2778.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2778.jpg;5.852579876469226
#
#
#
# 476 работаем  с файлом:  ..\avto\start_dataset\test\img_2781.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2781.jpg;7.168458492050923
#
#
#
# 477 работаем  с файлом:  ..\avto\start_dataset\test\img_2782.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2782.jpg;5.6199539506906975
#
#
#
# 478 работаем  с файлом:  ..\avto\start_dataset\test\img_2784.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2784.jpg;4.346728596514346
#
#
#
# 479 работаем  с файлом:  ..\avto\start_dataset\test\img_2785.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2785.jpg;3.8837022463826605
#
#
#
# 480 работаем  с файлом:  ..\avto\start_dataset\test\img_2790.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2790.jpg;3.9661181185576115
#
#
#
# 481 работаем  с файлом:  ..\avto\start_dataset\test\img_2798.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2798.jpg;5.204382108314122
#
#
#
# 482 работаем  с файлом:  ..\avto\start_dataset\test\img_2800.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2800.jpg;2.120736060590081
#
#
#
# 483 работаем  с файлом:  ..\avto\start_dataset\test\img_2826.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2826.jpg;4.092769243433097
#
#
#
# 484 работаем  с файлом:  ..\avto\start_dataset\test\img_2859.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2859.jpg;3.627161895028563
#
#
#
# 485 работаем  с файлом:  ..\avto\start_dataset\test\img_2864.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2864.jpg;2.2442993871288786
#
#
#
# 486 работаем  с файлом:  ..\avto\start_dataset\test\img_2865.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2865.jpg;1.9357069341702668
#
#
#
# 487 работаем  с файлом:  ..\avto\start_dataset\test\img_2868.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2868.jpg;3.750002916472451
#
#
#
# 488 работаем  с файлом:  ..\avto\start_dataset\test\img_2871.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2871.jpg;4.897965047073868
#
#
#
# 489 работаем  с файлом:  ..\avto\start_dataset\test\img_2873.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2873.jpg;5.740493825048768
#
#
#
# 490 работаем  с файлом:  ..\avto\start_dataset\test\img_2875.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2875.jpg;6.3391698274156
#
#
#
# 491 работаем  с файлом:  ..\avto\start_dataset\test\img_2877.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2877.jpg;2.3856097759436423
#
#
#
# 492 работаем  с файлом:  ..\avto\start_dataset\test\img_2878.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2878.jpg;1.7987535060221425
#
#
#
# 493 работаем  с файлом:  ..\avto\start_dataset\test\img_2880.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2880.jpg;2.9756098967017017
#
#
#
# 494 работаем  с файлом:  ..\avto\start_dataset\test\img_2884.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2884.jpg;4.638997141197619
#
#
#
# 495 работаем  с файлом:  ..\avto\start_dataset\test\img_2886.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2886.jpg;3.093716321149525
#
#
#
# 496 работаем  с файлом:  ..\avto\start_dataset\test\img_2887.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2887.jpg;2.518107375764121
#
#
#
# 497 работаем  с файлом:  ..\avto\start_dataset\test\img_2888.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2888.jpg;2.010436339010548
#
#
#
# 498 работаем  с файлом:  ..\avto\start_dataset\test\img_2889.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2889.jpg;1.9298908431833977
#
#
#
# 499 работаем  с файлом:  ..\avto\start_dataset\test\img_2893.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2893.jpg;3.5997665010227355
#
#
#
# 500 работаем  с файлом:  ..\avto\start_dataset\test\img_2898.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2898.jpg;3.3770952352780332
#
#
#
# 501 работаем  с файлом:  ..\avto\start_dataset\test\img_2900.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2900.jpg;2.2637049776753173
#
#
#
# 502 работаем  с файлом:  ..\avto\start_dataset\test\img_2906.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2906.jpg;4.295814078699472
#
#
#
# 503 работаем  с файлом:  ..\avto\start_dataset\test\img_2907.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2907.jpg;4.604639199031179
#
#
#
# 504 работаем  с файлом:  ..\avto\start_dataset\test\img_2909.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2909.jpg;5.174052186986275
#
#
#
# 505 работаем  с файлом:  ..\avto\start_dataset\test\img_2910.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2910.jpg;5.522750119337417
#
#
#
# 506 работаем  с файлом:  ..\avto\start_dataset\test\img_2914.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2914.jpg;4.693569118848407
#
#
#
# 507 работаем  с файлом:  ..\avto\start_dataset\test\img_2917.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2917.jpg;2.8414360881095875
#
#
#
# 508 работаем  с файлом:  ..\avto\start_dataset\test\img_2919.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2919.jpg;1.8292768416373404
#
#
#
# 509 работаем  с файлом:  ..\avto\start_dataset\test\img_2921.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2921.jpg;2.5463673573454884
#
#
#
# 510 работаем  с файлом:  ..\avto\start_dataset\test\img_2922.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2922.jpg;3.0812014272044728
#
#
#
# 511 работаем  с файлом:  ..\avto\start_dataset\test\img_2923.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2923.jpg;3.3943062980342207
#
#
#
# 512 работаем  с файлом:  ..\avto\start_dataset\test\img_2924.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2924.jpg;3.6668701350786463
#
#
#
# 513 работаем  с файлом:  ..\avto\start_dataset\test\img_2926.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2926.jpg;4.006127303951147
#
#
#
# 514 работаем  с файлом:  ..\avto\start_dataset\test\img_2929.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2929.jpg;2.5125808386241593
#
#
#
# 515 работаем  с файлом:  ..\avto\start_dataset\test\img_2933.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2933.jpg;4.141603098980194
#
#
#
# 516 работаем  с файлом:  ..\avto\start_dataset\test\img_2935.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2935.jpg;2.982757165190286
#
#
#
# 517 работаем  с файлом:  ..\avto\start_dataset\test\img_2936.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2936.jpg;2.397089407980537
#
#
#
# 518 работаем  с файлом:  ..\avto\start_dataset\test\img_2938.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2938.jpg;1.5941389561572856
#
#
#
# 519 работаем  с файлом:  ..\avto\start_dataset\test\img_2942.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2942.jpg;4.184626193608951
#
#
#
# 520 работаем  с файлом:  ..\avto\start_dataset\test\img_2943.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2943.jpg;4.7450713345795155
#
#
#
# 521 работаем  с файлом:  ..\avto\start_dataset\test\img_2946.jpg
# focus, digital_zoom 14 1.0223123732251522
# ВЫХОД img_2946.jpg;5.674582423594978
#
#
#
# не распознано файлов 2
# не распознанные ..\avto\start_dataset\test\img_1710.jpg ..\avto\start_dataset\test\img_2674.heic
# сохранено в  ..\avto\start_dataset\sample_solution.csv
# Ошибка не посчитана. Истинных данных не обнаружено. Датасет тестовый?

# %%
itog = file_recognition('..\\avto\\start_dataset\\test\\img_1710.jpg')
itog = file_recognition('..\\avto\\start_dataset\\test\\img_2674.heic')
itog = file_recognition('..\\avto\\start_dataset\\test\\img_2715.jpg')
# Out:
# focus, digital_zoom 16 1.237315875613748
# ФАЙЛ НЕ РАСПОЗНАН ..\avto\start_dataset\test\img_1710.jpg
# Сконвертирован Y:\img_2674.jpg
# focus, digital_zoom 14 1.0327868852459017
# ФАЙЛ НЕ РАСПОЗНАН ..\avto\start_dataset\test\img_2674.heic
# focus, digital_zoom 14 1.0223123732251522
# приблизительно повернуто 0.7092206576181656
# корректировка длины знака 520 ----> 521.3464901064322

# %% [markdown]
# # Делаем  датасет ч/б

# %%
def get_grayscale2(image):  #уменьшает изображение в 3 раза, что и хотелось бы сделать
    #https://habr.com/ru/post/163663/
    #convert image -colorspace gray image
    img = Image.open(image).convert('L')
    img.save(image)

# %%
def get_grayscale(image):  #это не уменьшает почему то размер изображения
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
n = 0
pic_data = '..\\avto\\train_data3\\images\\train\\'
for f in os.listdir(pic_data):
    n +=1
    work_file = os.path.join(pic_data, f)
    print(n,'работаем  с файлом: ',work_file)
    #img = cv2.imread(work_file)
    img = get_grayscale2(work_file)
    #cv2.imwrite(work_file,img)
print('ОК')
# Out:
# 1 работаем  с файлом:  ..\avto\train_data3\images\train\000000000009.jpg
# 2 работаем  с файлом:  ..\avto\train_data3\images\train\000000000025.jpg
# 3 работаем  с файлом:  ..\avto\train_data3\images\train\000000000030.jpg
# 4 работаем  с файлом:  ..\avto\train_data3\images\train\000000000034.jpg
# 5 работаем  с файлом:  ..\avto\train_data3\images\train\000000000036.jpg
# 6 работаем  с файлом:  ..\avto\train_data3\images\train\000000000042.jpg
# 7 работаем  с файлом:  ..\avto\train_data3\images\train\000000000049.jpg
# 8 работаем  с файлом:  ..\avto\train_data3\images\train\000000000061.jpg
# 9 работаем  с файлом:  ..\avto\train_data3\images\train\000000000064.jpg
# 10 работаем  с файлом:  ..\avto\train_data3\images\train\000000000071.jpg
# 11 работаем  с файлом:  ..\avto\train_data3\images\train\000000000072.jpg
# 12 работаем  с файлом:  ..\avto\train_data3\images\train\000000000073.jpg
# 13 работаем  с файлом:  ..\avto\train_data3\images\train\000000000074.jpg
# 14 работаем  с файлом:  ..\avto\train_data3\images\train\000000000077.jpg
# 15 работаем  с файлом:  ..\avto\train_data3\images\train\000000000078.jpg
# 16 работаем  с файлом:  ..\avto\train_data3\images\train\000000000081.jpg
# 17 работаем  с файлом:  ..\avto\train_data3\images\train\000000000086.jpg
# 18 работаем  с файлом:  ..\avto\train_data3\images\train\000000000089.jpg
# 19 работаем  с файлом:  ..\avto\train_data3\images\train\000000000092.jpg
# 20 работаем  с файлом:  ..\avto\train_data3\images\train\000000000094.jpg
# 21 работаем  с файлом:  ..\avto\train_data3\images\train\000000000109.jpg
# 22 работаем  с файлом:  ..\avto\train_data3\images\train\000000000110.jpg
# 23 работаем  с файлом:  ..\avto\train_data3\images\train\000000000113.jpg
# 24 работаем  с файлом:  ..\avto\train_data3\images\train\000000000127.jpg
# 25 работаем  с файлом:  ..\avto\train_data3\images\train\000000000133.jpg
# 26 работаем  с файлом:  ..\avto\train_data3\images\train\000000000136.jpg
# 27 работаем  с файлом:  ..\avto\train_data3\images\train\000000000138.jpg
# 28 работаем  с файлом:  ..\avto\train_data3\images\train\000000000142.jpg
# 29 работаем  с файлом:  ..\avto\train_data3\images\train\000000000143.jpg
# 30 работаем  с файлом:  ..\avto\train_data3\images\train\000000000144.jpg
# 31 работаем  с файлом:  ..\avto\train_data3\images\train\000000000149.jpg
# 32 работаем  с файлом:  ..\avto\train_data3\images\train\000000000151.jpg
# 33 работаем  с файлом:  ..\avto\train_data3\images\train\000000000154.jpg
# 34 работаем  с файлом:  ..\avto\train_data3\images\train\000000000164.jpg
# 35 работаем  с файлом:  ..\avto\train_data3\images\train\000000000165.jpg
# 36 работаем  с файлом:  ..\avto\train_data3\images\train\000000000192.jpg
# 37 работаем  с файлом:  ..\avto\train_data3\images\train\000000000194.jpg
# 38 работаем  с файлом:  ..\avto\train_data3\images\train\000000000196.jpg
# 39 работаем  с файлом:  ..\avto\train_data3\images\train\000000000201.jpg
# 40 работаем  с файлом:  ..\avto\train_data3\images\train\000000000208.jpg
# 41 работаем  с файлом:  ..\avto\train_data3\images\train\000000000241.jpg
# 42 работаем  с файлом:  ..\avto\train_data3\images\train\000000000247.jpg
# 43 работаем  с файлом:  ..\avto\train_data3\images\train\000000000250.jpg
# 44 работаем  с файлом:  ..\avto\train_data3\images\train\000000000257.jpg
# 45 работаем  с файлом:  ..\avto\train_data3\images\train\000000000260.jpg
# 46 работаем  с файлом:  ..\avto\train_data3\images\train\000000000263.jpg
# 47 работаем  с файлом:  ..\avto\train_data3\images\train\000000000283.jpg
# 48 работаем  с файлом:  ..\avto\train_data3\images\train\000000000294.jpg
# 49 работаем  с файлом:  ..\avto\train_data3\images\train\000000000307.jpg
# 50 работаем  с файлом:  ..\avto\train_data3\images\train\000000000308.jpg
# 51 работаем  с файлом:  ..\avto\train_data3\images\train\000000000309.jpg
# 52 работаем  с файлом:  ..\avto\train_data3\images\train\000000000312.jpg
# 53 работаем  с файлом:  ..\avto\train_data3\images\train\000000000315.jpg
# 54 работаем  с файлом:  ..\avto\train_data3\images\train\000000000321.jpg
# 55 работаем  с файлом:  ..\avto\train_data3\images\train\000000000322.jpg
# 56 работаем  с файлом:  ..\avto\train_data3\images\train\000000000326.jpg
# 57 работаем  с файлом:  ..\avto\train_data3\images\train\000000000328.jpg
# 58 работаем  с файлом:  ..\avto\train_data3\images\train\000000000332.jpg
# 59 работаем  с файлом:  ..\avto\train_data3\images\train\000000000338.jpg
# 60 работаем  с файлом:  ..\avto\train_data3\images\train\000000000349.jpg
# 61 работаем  с файлом:  ..\avto\train_data3\images\train\000000000357.jpg
# 62 работаем  с файлом:  ..\avto\train_data3\images\train\000000000359.jpg
# 63 работаем  с файлом:  ..\avto\train_data3\images\train\000000000360.jpg
# 64 работаем  с файлом:  ..\avto\train_data3\images\train\000000000368.jpg
# 65 работаем  с файлом:  ..\avto\train_data3\images\train\000000000370.jpg
# 66 работаем  с файлом:  ..\avto\train_data3\images\train\000000000382.jpg
# 67 работаем  с файлом:  ..\avto\train_data3\images\train\000000000384.jpg
# 68 работаем  с файлом:  ..\avto\train_data3\images\train\000000000387.jpg
# 69 работаем  с файлом:  ..\avto\train_data3\images\train\000000000389.jpg
# 70 работаем  с файлом:  ..\avto\train_data3\images\train\000000000394.jpg
# 71 работаем  с файлом:  ..\avto\train_data3\images\train\000000000395.jpg
# 72 работаем  с файлом:  ..\avto\train_data3\images\train\000000000397.jpg
# 73 работаем  с файлом:  ..\avto\train_data3\images\train\000000000400.jpg
# 74 работаем  с файлом:  ..\avto\train_data3\images\train\000000000404.jpg
# 75 работаем  с файлом:  ..\avto\train_data3\images\train\000000000415.jpg
# 76 работаем  с файлом:  ..\avto\train_data3\images\train\000000000419.jpg
# 77 работаем  с файлом:  ..\avto\train_data3\images\train\000000000428.jpg
# 78 работаем  с файлом:  ..\avto\train_data3\images\train\000000000431.jpg
# 79 работаем  с файлом:  ..\avto\train_data3\images\train\000000000436.jpg
# 80 работаем  с файлом:  ..\avto\train_data3\images\train\000000000438.jpg
# 81 работаем  с файлом:  ..\avto\train_data3\images\train\000000000443.jpg
# 82 работаем  с файлом:  ..\avto\train_data3\images\train\000000000446.jpg
# 83 работаем  с файлом:  ..\avto\train_data3\images\train\000000000450.jpg
# 84 работаем  с файлом:  ..\avto\train_data3\images\train\000000000459.jpg
# 85 работаем  с файлом:  ..\avto\train_data3\images\train\000000000471.jpg
# 86 работаем  с файлом:  ..\avto\train_data3\images\train\000000000472.jpg
# 87 работаем  с файлом:  ..\avto\train_data3\images\train\000000000474.jpg
# 88 работаем  с файлом:  ..\avto\train_data3\images\train\000000000486.jpg
# 89 работаем  с файлом:  ..\avto\train_data3\images\train\000000000488.jpg
# 90 работаем  с файлом:  ..\avto\train_data3\images\train\000000000490.jpg
# 91 работаем  с файлом:  ..\avto\train_data3\images\train\000000000491.jpg
# 92 работаем  с файлом:  ..\avto\train_data3\images\train\000000000502.jpg
# 93 работаем  с файлом:  ..\avto\train_data3\images\train\000000000508.jpg
# 94 работаем  с файлом:  ..\avto\train_data3\images\train\000000000510.jpg
# 95 работаем  с файлом:  ..\avto\train_data3\images\train\000000000514.jpg
# 96 работаем  с файлом:  ..\avto\train_data3\images\train\000000000520.jpg
# 97 работаем  с файлом:  ..\avto\train_data3\images\train\000000000529.jpg
# 98 работаем  с файлом:  ..\avto\train_data3\images\train\000000000531.jpg
# 99 работаем  с файлом:  ..\avto\train_data3\images\train\000000000532.jpg
# 100 работаем  с файлом:  ..\avto\train_data3\images\train\000000000536.jpg
# 101 работаем  с файлом:  ..\avto\train_data3\images\train\000000000540.jpg
# 102 работаем  с файлом:  ..\avto\train_data3\images\train\000000000542.jpg
# 103 работаем  с файлом:  ..\avto\train_data3\images\train\000000000544.jpg
# 104 работаем  с файлом:  ..\avto\train_data3\images\train\000000000560.jpg
# 105 работаем  с файлом:  ..\avto\train_data3\images\train\000000000562.jpg
# 106 работаем  с файлом:  ..\avto\train_data3\images\train\000000000564.jpg
# 107 работаем  с файлом:  ..\avto\train_data3\images\train\000000000569.jpg
# 108 работаем  с файлом:  ..\avto\train_data3\images\train\000000000572.jpg
# 109 работаем  с файлом:  ..\avto\train_data3\images\train\000000000575.jpg
# 110 работаем  с файлом:  ..\avto\train_data3\images\train\000000000581.jpg
# 111 работаем  с файлом:  ..\avto\train_data3\images\train\000000000584.jpg
# 112 работаем  с файлом:  ..\avto\train_data3\images\train\000000000589.jpg
# 113 работаем  с файлом:  ..\avto\train_data3\images\train\000000000590.jpg
# 114 работаем  с файлом:  ..\avto\train_data3\images\train\000000000595.jpg
# 115 работаем  с файлом:  ..\avto\train_data3\images\train\000000000597.jpg
# 116 работаем  с файлом:  ..\avto\train_data3\images\train\000000000599.jpg
# 117 работаем  с файлом:  ..\avto\train_data3\images\train\000000000605.jpg
# 118 работаем  с файлом:  ..\avto\train_data3\images\train\000000000612.jpg
# 119 работаем  с файлом:  ..\avto\train_data3\images\train\000000000620.jpg
# 120 работаем  с файлом:  ..\avto\train_data3\images\train\000000000623.jpg
# 121 работаем  с файлом:  ..\avto\train_data3\images\train\000000000625.jpg
# 122 работаем  с файлом:  ..\avto\train_data3\images\train\000000000626.jpg
# 123 работаем  с файлом:  ..\avto\train_data3\images\train\000000000629.jpg
# 124 работаем  с файлом:  ..\avto\train_data3\images\train\000000000634.jpg
# 125 работаем  с файлом:  ..\avto\train_data3\images\train\000000000636.jpg
# 126 работаем  с файлом:  ..\avto\train_data3\images\train\000000000641.jpg
# 127 работаем  с файлом:  ..\avto\train_data3\images\train\000000000643.jpg
# 128 работаем  с файлом:  ..\avto\train_data3\images\train\000000000650.jpg
# 129 работаем  с файлом:  ..\avto\train_data3\images\train\img_1853.jpg
# 130 работаем  с файлом:  ..\avto\train_data3\images\train\img_1854.jpg
# 131 работаем  с файлом:  ..\avto\train_data3\images\train\img_1856.jpg
# 132 работаем  с файлом:  ..\avto\train_data3\images\train\img_1857.jpg
# 133 работаем  с файлом:  ..\avto\train_data3\images\train\img_1860.jpg
# 134 работаем  с файлом:  ..\avto\train_data3\images\train\img_1861.jpg
# 135 работаем  с файлом:  ..\avto\train_data3\images\train\img_1862.jpg
# 136 работаем  с файлом:  ..\avto\train_data3\images\train\img_1863.jpg
# 137 работаем  с файлом:  ..\avto\train_data3\images\train\img_1864.jpg
# 138 работаем  с файлом:  ..\avto\train_data3\images\train\img_1865.jpg
# 139 работаем  с файлом:  ..\avto\train_data3\images\train\img_1874.jpg
# 140 работаем  с файлом:  ..\avto\train_data3\images\train\img_1878.jpg
# 141 работаем  с файлом:  ..\avto\train_data3\images\train\img_1881.jpg
# 142 работаем  с файлом:  ..\avto\train_data3\images\train\img_1882.jpg
# 143 работаем  с файлом:  ..\avto\train_data3\images\train\img_1883.jpg
# 144 работаем  с файлом:  ..\avto\train_data3\images\train\img_1885.jpg
# 145 работаем  с файлом:  ..\avto\train_data3\images\train\img_1886.jpg
# 146 работаем  с файлом:  ..\avto\train_data3\images\train\img_1887.jpg
# 147 работаем  с файлом:  ..\avto\train_data3\images\train\img_1890.jpg
# 148 работаем  с файлом:  ..\avto\train_data3\images\train\img_1893.jpg
# 149 работаем  с файлом:  ..\avto\train_data3\images\train\img_1896.jpg
# 150 работаем  с файлом:  ..\avto\train_data3\images\train\img_1899.jpg
# 151 работаем  с файлом:  ..\avto\train_data3\images\train\img_1901.jpg
# 152 работаем  с файлом:  ..\avto\train_data3\images\train\img_1902.jpg
# 153 работаем  с файлом:  ..\avto\train_data3\images\train\img_1903.jpg
# 154 работаем  с файлом:  ..\avto\train_data3\images\train\img_1907.jpg
# 155 работаем  с файлом:  ..\avto\train_data3\images\train\img_1909.jpg
# 156 работаем  с файлом:  ..\avto\train_data3\images\train\img_1910.jpg
# 157 работаем  с файлом:  ..\avto\train_data3\images\train\img_1912.jpg
# 158 работаем  с файлом:  ..\avto\train_data3\images\train\img_1916.jpg
# 159 работаем  с файлом:  ..\avto\train_data3\images\train\img_1918.jpg
# 160 работаем  с файлом:  ..\avto\train_data3\images\train\img_1921.jpg
# 161 работаем  с файлом:  ..\avto\train_data3\images\train\img_1922.jpg
# 162 работаем  с файлом:  ..\avto\train_data3\images\train\img_1924.jpg
# 163 работаем  с файлом:  ..\avto\train_data3\images\train\img_1925.jpg
# 164 работаем  с файлом:  ..\avto\train_data3\images\train\img_1926.jpg
# 165 работаем  с файлом:  ..\avto\train_data3\images\train\img_1927.jpg
# 166 работаем  с файлом:  ..\avto\train_data3\images\train\img_1929.jpg
# 167 работаем  с файлом:  ..\avto\train_data3\images\train\img_1930.jpg
# 168 работаем  с файлом:  ..\avto\train_data3\images\train\img_1932.jpg
# 169 работаем  с файлом:  ..\avto\train_data3\images\train\img_1933.jpg
# 170 работаем  с файлом:  ..\avto\train_data3\images\train\img_1937.jpg
# 171 работаем  с файлом:  ..\avto\train_data3\images\train\img_1938.jpg
# 172 работаем  с файлом:  ..\avto\train_data3\images\train\img_1939.jpg
# 173 работаем  с файлом:  ..\avto\train_data3\images\train\img_1945.jpg
# 174 работаем  с файлом:  ..\avto\train_data3\images\train\img_1948.jpg
# 175 работаем  с файлом:  ..\avto\train_data3\images\train\img_1950.jpg
# 176 работаем  с файлом:  ..\avto\train_data3\images\train\img_1951.jpg
# 177 работаем  с файлом:  ..\avto\train_data3\images\train\img_1958.jpg
# 178 работаем  с файлом:  ..\avto\train_data3\images\train\img_1959.jpg
# 179 работаем  с файлом:  ..\avto\train_data3\images\train\img_1963.jpg
# 180 работаем  с файлом:  ..\avto\train_data3\images\train\img_1964.jpg
# 181 работаем  с файлом:  ..\avto\train_data3\images\train\img_1965.jpg
# 182 работаем  с файлом:  ..\avto\train_data3\images\train\img_1966.jpg
# 183 работаем  с файлом:  ..\avto\train_data3\images\train\img_1967.jpg
# 184 работаем  с файлом:  ..\avto\train_data3\images\train\img_1968.jpg
# 185 работаем  с файлом:  ..\avto\train_data3\images\train\img_1970.jpg
# 186 работаем  с файлом:  ..\avto\train_data3\images\train\img_1971.jpg
# 187 работаем  с файлом:  ..\avto\train_data3\images\train\img_1973.jpg
# 188 работаем  с файлом:  ..\avto\train_data3\images\train\img_1976.jpg
# 189 работаем  с файлом:  ..\avto\train_data3\images\train\img_1977.jpg
# 190 работаем  с файлом:  ..\avto\train_data3\images\train\img_1979.jpg
# 191 работаем  с файлом:  ..\avto\train_data3\images\train\img_1980.jpg
# 192 работаем  с файлом:  ..\avto\train_data3\images\train\img_1983.jpg
# 193 работаем  с файлом:  ..\avto\train_data3\images\train\img_1984.jpg
# 194 работаем  с файлом:  ..\avto\train_data3\images\train\img_1985.jpg
# 195 работаем  с файлом:  ..\avto\train_data3\images\train\img_1991.jpg
# 196 работаем  с файлом:  ..\avto\train_data3\images\train\img_1992.jpg
# 197 работаем  с файлом:  ..\avto\train_data3\images\train\img_1994.jpg
# 198 работаем  с файлом:  ..\avto\train_data3\images\train\img_1996.jpg
# 199 работаем  с файлом:  ..\avto\train_data3\images\train\img_2001.jpg
# 200 работаем  с файлом:  ..\avto\train_data3\images\train\img_2002.jpg
# 201 работаем  с файлом:  ..\avto\train_data3\images\train\img_2003.jpg
# 202 работаем  с файлом:  ..\avto\train_data3\images\train\img_2005.jpg
# 203 работаем  с файлом:  ..\avto\train_data3\images\train\img_2007.jpg
# 204 работаем  с файлом:  ..\avto\train_data3\images\train\img_2008.jpg
# 205 работаем  с файлом:  ..\avto\train_data3\images\train\img_2010.jpg
# 206 работаем  с файлом:  ..\avto\train_data3\images\train\img_2012.jpg
# 207 работаем  с файлом:  ..\avto\train_data3\images\train\img_2014.jpg
# 208 работаем  с файлом:  ..\avto\train_data3\images\train\img_2016.jpg
# 209 работаем  с файлом:  ..\avto\train_data3\images\train\img_2018.jpg
# 210 работаем  с файлом:  ..\avto\train_data3\images\train\img_2021.jpg
# 211 работаем  с файлом:  ..\avto\train_data3\images\train\img_2025.jpg
# 212 работаем  с файлом:  ..\avto\train_data3\images\train\img_2026.jpg
# 213 работаем  с файлом:  ..\avto\train_data3\images\train\img_2027.jpg
# 214 работаем  с файлом:  ..\avto\train_data3\images\train\img_2030.jpg
# 215 работаем  с файлом:  ..\avto\train_data3\images\train\img_2254.jpg
# 216 работаем  с файлом:  ..\avto\train_data3\images\train\img_2255.jpg
# 217 работаем  с файлом:  ..\avto\train_data3\images\train\img_2256.jpg
# 218 работаем  с файлом:  ..\avto\train_data3\images\train\img_2260.jpg
# 219 работаем  с файлом:  ..\avto\train_data3\images\train\img_2261.jpg
# 220 работаем  с файлом:  ..\avto\train_data3\images\train\img_2264.jpg
# 221 работаем  с файлом:  ..\avto\train_data3\images\train\img_2266.jpg
# 222 работаем  с файлом:  ..\avto\train_data3\images\train\img_2268.jpg
# 223 работаем  с файлом:  ..\avto\train_data3\images\train\img_2269.jpg
# 224 работаем  с файлом:  ..\avto\train_data3\images\train\img_2270.jpg
# 225 работаем  с файлом:  ..\avto\train_data3\images\train\img_2271.jpg
# 226 работаем  с файлом:  ..\avto\train_data3\images\train\img_2272.jpg
# 227 работаем  с файлом:  ..\avto\train_data3\images\train\img_2275.jpg
# 228 работаем  с файлом:  ..\avto\train_data3\images\train\img_2277.jpg
# 229 работаем  с файлом:  ..\avto\train_data3\images\train\img_2278.jpg
# 230 работаем  с файлом:  ..\avto\train_data3\images\train\img_2280.jpg
# 231 работаем  с файлом:  ..\avto\train_data3\images\train\img_2282.jpg
# 232 работаем  с файлом:  ..\avto\train_data3\images\train\img_2285.jpg
# 233 работаем  с файлом:  ..\avto\train_data3\images\train\img_2287.jpg
# 234 работаем  с файлом:  ..\avto\train_data3\images\train\img_2289.jpg
# 235 работаем  с файлом:  ..\avto\train_data3\images\train\img_2290.jpg
# 236 работаем  с файлом:  ..\avto\train_data3\images\train\img_2291.jpg
# 237 работаем  с файлом:  ..\avto\train_data3\images\train\img_2294.jpg
# 238 работаем  с файлом:  ..\avto\train_data3\images\train\img_2295.jpg
# 239 работаем  с файлом:  ..\avto\train_data3\images\train\img_2296.jpg
# 240 работаем  с файлом:  ..\avto\train_data3\images\train\img_2297.jpg
# 241 работаем  с файлом:  ..\avto\train_data3\images\train\img_2300.jpg
# 242 работаем  с файлом:  ..\avto\train_data3\images\train\img_2301.jpg
# 243 работаем  с файлом:  ..\avto\train_data3\images\train\img_2302.jpg
# 244 работаем  с файлом:  ..\avto\train_data3\images\train\img_2304.jpg
# 245 работаем  с файлом:  ..\avto\train_data3\images\train\img_2305.jpg
# 246 работаем  с файлом:  ..\avto\train_data3\images\train\img_2306.jpg
# 247 работаем  с файлом:  ..\avto\train_data3\images\train\img_2308.jpg
# 248 работаем  с файлом:  ..\avto\train_data3\images\train\img_2309.jpg
# 249 работаем  с файлом:  ..\avto\train_data3\images\train\img_2310.jpg
# 250 работаем  с файлом:  ..\avto\train_data3\images\train\img_2313.jpg
# 251 работаем  с файлом:  ..\avto\train_data3\images\train\img_2316.jpg
# 252 работаем  с файлом:  ..\avto\train_data3\images\train\img_2319.jpg
# 253 работаем  с файлом:  ..\avto\train_data3\images\train\img_2320.jpg
# 254 работаем  с файлом:  ..\avto\train_data3\images\train\img_2321.jpg
# 255 работаем  с файлом:  ..\avto\train_data3\images\train\img_2322.jpg
# 256 работаем  с файлом:  ..\avto\train_data3\images\train\img_2327.jpg
# 257 работаем  с файлом:  ..\avto\train_data3\images\train\img_2330.jpg
# 258 работаем  с файлом:  ..\avto\train_data3\images\train\img_2331.jpg
# 259 работаем  с файлом:  ..\avto\train_data3\images\train\img_2332.jpg
# 260 работаем  с файлом:  ..\avto\train_data3\images\train\img_2333.jpg
# 261 работаем  с файлом:  ..\avto\train_data3\images\train\img_2336.jpg
# 262 работаем  с файлом:  ..\avto\train_data3\images\train\img_2341.jpg
# 263 работаем  с файлом:  ..\avto\train_data3\images\train\img_2342.jpg
# 264 работаем  с файлом:  ..\avto\train_data3\images\train\img_2344.jpg
# 265 работаем  с файлом:  ..\avto\train_data3\images\train\img_2345.jpg
# 266 работаем  с файлом:  ..\avto\train_data3\images\train\img_2347.jpg
# 267 работаем  с файлом:  ..\avto\train_data3\images\train\img_2350.jpg
# 268 работаем  с файлом:  ..\avto\train_data3\images\train\img_2352.jpg
# 269 работаем  с файлом:  ..\avto\train_data3\images\train\img_2359.jpg
# 270 работаем  с файлом:  ..\avto\train_data3\images\train\img_2361.jpg
# 271 работаем  с файлом:  ..\avto\train_data3\images\train\img_2369.jpg
# 272 работаем  с файлом:  ..\avto\train_data3\images\train\img_2372.jpg
# 273 работаем  с файлом:  ..\avto\train_data3\images\train\img_2373.jpg
# 274 работаем  с файлом:  ..\avto\train_data3\images\train\img_2374.jpg
# 275 работаем  с файлом:  ..\avto\train_data3\images\train\img_2376.jpg
# 276 работаем  с файлом:  ..\avto\train_data3\images\train\img_2378.jpg
# 277 работаем  с файлом:  ..\avto\train_data3\images\train\img_2383.jpg
# 278 работаем  с файлом:  ..\avto\train_data3\images\train\img_2384.jpg
# 279 работаем  с файлом:  ..\avto\train_data3\images\train\img_2385.jpg
# 280 работаем  с файлом:  ..\avto\train_data3\images\train\img_2390.jpg
# 281 работаем  с файлом:  ..\avto\train_data3\images\train\img_2397.jpg
# 282 работаем  с файлом:  ..\avto\train_data3\images\train\img_2398.jpg
# 283 работаем  с файлом:  ..\avto\train_data3\images\train\img_2404.jpg
# 284 работаем  с файлом:  ..\avto\train_data3\images\train\img_2405.jpg
# 285 работаем  с файлом:  ..\avto\train_data3\images\train\img_2406.jpg
# 286 работаем  с файлом:  ..\avto\train_data3\images\train\img_2408.jpg
# 287 работаем  с файлом:  ..\avto\train_data3\images\train\img_2409.jpg
# 288 работаем  с файлом:  ..\avto\train_data3\images\train\img_2410.jpg
# 289 работаем  с файлом:  ..\avto\train_data3\images\train\img_2411.jpg
# 290 работаем  с файлом:  ..\avto\train_data3\images\train\img_2418.jpg
# 291 работаем  с файлом:  ..\avto\train_data3\images\train\img_2420.jpg
# 292 работаем  с файлом:  ..\avto\train_data3\images\train\img_2422.jpg
# 293 работаем  с файлом:  ..\avto\train_data3\images\train\img_2423.jpg
# 294 работаем  с файлом:  ..\avto\train_data3\images\train\img_2426.jpg
# 295 работаем  с файлом:  ..\avto\train_data3\images\train\img_2427.jpg
# 296 работаем  с файлом:  ..\avto\train_data3\images\train\img_2429.jpg
# 297 работаем  с файлом:  ..\avto\train_data3\images\train\img_2430.jpg
# 298 работаем  с файлом:  ..\avto\train_data3\images\train\img_2432.jpg
# 299 работаем  с файлом:  ..\avto\train_data3\images\train\img_2434.jpg
# 300 работаем  с файлом:  ..\avto\train_data3\images\train\img_2436.jpg
# 301 работаем  с файлом:  ..\avto\train_data3\images\train\img_2437.jpg
# 302 работаем  с файлом:  ..\avto\train_data3\images\train\img_2440.jpg
# 303 работаем  с файлом:  ..\avto\train_data3\images\train\img_2442.jpg
# 304 работаем  с файлом:  ..\avto\train_data3\images\train\img_2443.jpg
# 305 работаем  с файлом:  ..\avto\train_data3\images\train\img_2445.jpg
# 306 работаем  с файлом:  ..\avto\train_data3\images\train\img_2449.jpg
# 307 работаем  с файлом:  ..\avto\train_data3\images\train\img_2450.jpg
# 308 работаем  с файлом:  ..\avto\train_data3\images\train\img_2451.jpg
# 309 работаем  с файлом:  ..\avto\train_data3\images\train\img_2452.jpg
# 310 работаем  с файлом:  ..\avto\train_data3\images\train\img_2453.jpg
# 311 работаем  с файлом:  ..\avto\train_data3\images\train\img_2454.jpg
# 312 работаем  с файлом:  ..\avto\train_data3\images\train\img_2455.jpg
# 313 работаем  с файлом:  ..\avto\train_data3\images\train\img_2458.jpg
# 314 работаем  с файлом:  ..\avto\train_data3\images\train\img_2459.jpg
# 315 работаем  с файлом:  ..\avto\train_data3\images\train\img_2460.jpg
# 316 работаем  с файлом:  ..\avto\train_data3\images\train\img_2462.jpg
# 317 работаем  с файлом:  ..\avto\train_data3\images\train\img_2463.jpg
# 318 работаем  с файлом:  ..\avto\train_data3\images\train\img_2468.jpg
# 319 работаем  с файлом:  ..\avto\train_data3\images\train\img_2469.jpg
# 320 работаем  с файлом:  ..\avto\train_data3\images\train\img_2470.jpg
# 321 работаем  с файлом:  ..\avto\train_data3\images\train\img_2474.jpg
# 322 работаем  с файлом:  ..\avto\train_data3\images\train\img_2476.jpg
# 323 работаем  с файлом:  ..\avto\train_data3\images\train\img_2477.jpg
# 324 работаем  с файлом:  ..\avto\train_data3\images\train\img_2480.jpg
# 325 работаем  с файлом:  ..\avto\train_data3\images\train\img_2484.jpg
# 326 работаем  с файлом:  ..\avto\train_data3\images\train\img_2485.jpg
# 327 работаем  с файлом:  ..\avto\train_data3\images\train\img_2487.jpg
# 328 работаем  с файлом:  ..\avto\train_data3\images\train\img_2490.jpg
# 329 работаем  с файлом:  ..\avto\train_data3\images\train\img_2492.jpg
# 330 работаем  с файлом:  ..\avto\train_data3\images\train\img_2494.jpg
# 331 работаем  с файлом:  ..\avto\train_data3\images\train\img_2495.jpg
# 332 работаем  с файлом:  ..\avto\train_data3\images\train\img_2502.jpg
# 333 работаем  с файлом:  ..\avto\train_data3\images\train\img_2503.jpg
# 334 работаем  с файлом:  ..\avto\train_data3\images\train\img_2504.jpg
# 335 работаем  с файлом:  ..\avto\train_data3\images\train\img_2505.jpg
# 336 работаем  с файлом:  ..\avto\train_data3\images\train\img_2507.jpg
# 337 работаем  с файлом:  ..\avto\train_data3\images\train\img_2510.jpg
# 338 работаем  с файлом:  ..\avto\train_data3\images\train\img_2511.jpg
# 339 работаем  с файлом:  ..\avto\train_data3\images\train\img_2512.jpg
# 340 работаем  с файлом:  ..\avto\train_data3\images\train\img_2514.jpg
# 341 работаем  с файлом:  ..\avto\train_data3\images\train\img_2516.jpg
# 342 работаем  с файлом:  ..\avto\train_data3\images\train\img_2519.jpg
# 343 работаем  с файлом:  ..\avto\train_data3\images\train\img_2520.jpg
# 344 работаем  с файлом:  ..\avto\train_data3\images\train\img_2527.jpg
# 345 работаем  с файлом:  ..\avto\train_data3\images\train\img_2528.jpg
# 346 работаем  с файлом:  ..\avto\train_data3\images\train\img_2533.jpg
# 347 работаем  с файлом:  ..\avto\train_data3\images\train\img_2535.jpg
# 348 работаем  с файлом:  ..\avto\train_data3\images\train\img_2536.jpg
# 349 работаем  с файлом:  ..\avto\train_data3\images\train\img_2538.jpg
# 350 работаем  с файлом:  ..\avto\train_data3\images\train\img_2539.jpg
# 351 работаем  с файлом:  ..\avto\train_data3\images\train\img_2544.jpg
# 352 работаем  с файлом:  ..\avto\train_data3\images\train\img_2547.jpg
# 353 работаем  с файлом:  ..\avto\train_data3\images\train\img_2548.jpg
# 354 работаем  с файлом:  ..\avto\train_data3\images\train\img_2549.jpg
# 355 работаем  с файлом:  ..\avto\train_data3\images\train\img_2550.jpg
# 356 работаем  с файлом:  ..\avto\train_data3\images\train\img_2553.jpg
# 357 работаем  с файлом:  ..\avto\train_data3\images\train\img_2554.jpg
# 358 работаем  с файлом:  ..\avto\train_data3\images\train\img_2561.jpg
# 359 работаем  с файлом:  ..\avto\train_data3\images\train\img_2562.jpg
# 360 работаем  с файлом:  ..\avto\train_data3\images\train\img_2563.jpg
# 361 работаем  с файлом:  ..\avto\train_data3\images\train\img_2568.jpg
# 362 работаем  с файлом:  ..\avto\train_data3\images\train\img_2570.jpg
# 363 работаем  с файлом:  ..\avto\train_data3\images\train\img_2574.jpg
# 364 работаем  с файлом:  ..\avto\train_data3\images\train\img_2575.jpg
# 365 работаем  с файлом:  ..\avto\train_data3\images\train\img_2577.jpg
# 366 работаем  с файлом:  ..\avto\train_data3\images\train\img_2578.jpg
# 367 работаем  с файлом:  ..\avto\train_data3\images\train\img_2579.jpg
# 368 работаем  с файлом:  ..\avto\train_data3\images\train\img_2581.jpg
# 369 работаем  с файлом:  ..\avto\train_data3\images\train\img_2583.jpg
# 370 работаем  с файлом:  ..\avto\train_data3\images\train\img_2584.jpg
# 371 работаем  с файлом:  ..\avto\train_data3\images\train\img_2586.jpg
# 372 работаем  с файлом:  ..\avto\train_data3\images\train\img_2588.jpg
# 373 работаем  с файлом:  ..\avto\train_data3\images\train\img_2590.jpg
# 374 работаем  с файлом:  ..\avto\train_data3\images\train\img_2593.jpg
# 375 работаем  с файлом:  ..\avto\train_data3\images\train\img_2597.jpg
# 376 работаем  с файлом:  ..\avto\train_data3\images\train\img_2600.jpg
# 377 работаем  с файлом:  ..\avto\train_data3\images\train\img_2601.jpg
# 378 работаем  с файлом:  ..\avto\train_data3\images\train\img_2604.jpg
# 379 работаем  с файлом:  ..\avto\train_data3\images\train\img_2608.jpg
# 380 работаем  с файлом:  ..\avto\train_data3\images\train\img_2613.jpg
# 381 работаем  с файлом:  ..\avto\train_data3\images\train\img_2614.jpg
# 382 работаем  с файлом:  ..\avto\train_data3\images\train\img_2615.jpg
# 383 работаем  с файлом:  ..\avto\train_data3\images\train\img_2620.jpg
# 384 работаем  с файлом:  ..\avto\train_data3\images\train\img_2621.jpg
# 385 работаем  с файлом:  ..\avto\train_data3\images\train\img_2623.jpg
# 386 работаем  с файлом:  ..\avto\train_data3\images\train\img_2624.jpg
# 387 работаем  с файлом:  ..\avto\train_data3\images\train\img_2625.jpg
# 388 работаем  с файлом:  ..\avto\train_data3\images\train\img_2627.jpg
# 389 работаем  с файлом:  ..\avto\train_data3\images\train\img_2629.jpg
# 390 работаем  с файлом:  ..\avto\train_data3\images\train\img_2630.jpg
# 391 работаем  с файлом:  ..\avto\train_data3\images\train\img_2631.jpg
# 392 работаем  с файлом:  ..\avto\train_data3\images\train\img_2634.jpg
# 393 работаем  с файлом:  ..\avto\train_data3\images\train\img_2635.jpg
# 394 работаем  с файлом:  ..\avto\train_data3\images\train\img_2636.jpg
# 395 работаем  с файлом:  ..\avto\train_data3\images\train\img_2638.jpg
# 396 работаем  с файлом:  ..\avto\train_data3\images\train\img_2639.jpg
# 397 работаем  с файлом:  ..\avto\train_data3\images\train\img_2642.jpg
# 398 работаем  с файлом:  ..\avto\train_data3\images\train\img_2643.jpg
# 399 работаем  с файлом:  ..\avto\train_data3\images\train\img_2645.jpg
# 400 работаем  с файлом:  ..\avto\train_data3\images\train\img_2646.jpg
# 401 работаем  с файлом:  ..\avto\train_data3\images\train\img_2648.jpg
# 402 работаем  с файлом:  ..\avto\train_data3\images\train\img_2650.jpg
# 403 работаем  с файлом:  ..\avto\train_data3\images\train\img_2651.jpg
# 404 работаем  с файлом:  ..\avto\train_data3\images\train\img_2654.jpg
# 405 работаем  с файлом:  ..\avto\train_data3\images\train\img_2656.jpg
# 406 работаем  с файлом:  ..\avto\train_data3\images\train\img_2657.jpg
# 407 работаем  с файлом:  ..\avto\train_data3\images\train\img_2658.jpg
# 408 работаем  с файлом:  ..\avto\train_data3\images\train\img_2659.jpg
# 409 работаем  с файлом:  ..\avto\train_data3\images\train\img_2660.jpg
# 410 работаем  с файлом:  ..\avto\train_data3\images\train\img_2664.jpg
# 411 работаем  с файлом:  ..\avto\train_data3\images\train\img_2665.jpg
# 412 работаем  с файлом:  ..\avto\train_data3\images\train\img_2666.jpg
# 413 работаем  с файлом:  ..\avto\train_data3\images\train\img_2667.jpg
# 414 работаем  с файлом:  ..\avto\train_data3\images\train\img_2669.jpg
# 415 работаем  с файлом:  ..\avto\train_data3\images\train\img_2671.jpg
# 416 работаем  с файлом:  ..\avto\train_data3\images\train\img_2672.jpg
# 417 работаем  с файлом:  ..\avto\train_data3\images\train\img_2672_heic.jpg
# 418 работаем  с файлом:  ..\avto\train_data3\images\train\img_2673.jpg
# 419 работаем  с файлом:  ..\avto\train_data3\images\train\img_2673_heic.jpg
# 420 работаем  с файлом:  ..\avto\train_data3\images\train\img_2674.jpg
# 421 работаем  с файлом:  ..\avto\train_data3\images\train\img_2675_heic.jpg
# 422 работаем  с файлом:  ..\avto\train_data3\images\train\img_2676_heic.jpg
# 423 работаем  с файлом:  ..\avto\train_data3\images\train\img_2678_heic.jpg
# 424 работаем  с файлом:  ..\avto\train_data3\images\train\img_2680_heic.jpg
# 425 работаем  с файлом:  ..\avto\train_data3\images\train\img_2681.jpg
# 426 работаем  с файлом:  ..\avto\train_data3\images\train\img_2681_heic.jpg
# 427 работаем  с файлом:  ..\avto\train_data3\images\train\img_2682.jpg
# 428 работаем  с файлом:  ..\avto\train_data3\images\train\img_2682_heic.jpg
# 429 работаем  с файлом:  ..\avto\train_data3\images\train\img_2683.jpg
# 430 работаем  с файлом:  ..\avto\train_data3\images\train\img_2683_heic.jpg
# 431 работаем  с файлом:  ..\avto\train_data3\images\train\img_2684.jpg
# 432 работаем  с файлом:  ..\avto\train_data3\images\train\img_2685_heic.jpg
# 433 работаем  с файлом:  ..\avto\train_data3\images\train\img_2686.jpg
# 434 работаем  с файлом:  ..\avto\train_data3\images\train\img_2687_heic.jpg
# 435 работаем  с файлом:  ..\avto\train_data3\images\train\img_2688.jpg
# 436 работаем  с файлом:  ..\avto\train_data3\images\train\img_2688_heic.jpg
# 437 работаем  с файлом:  ..\avto\train_data3\images\train\img_2690.jpg
# 438 работаем  с файлом:  ..\avto\train_data3\images\train\img_2690_heic.jpg
# 439 работаем  с файлом:  ..\avto\train_data3\images\train\img_2691.jpg
# 440 работаем  с файлом:  ..\avto\train_data3\images\train\img_2691_heic.jpg
# 441 работаем  с файлом:  ..\avto\train_data3\images\train\img_2694.jpg
# 442 работаем  с файлом:  ..\avto\train_data3\images\train\img_2694_heic.jpg
# 443 работаем  с файлом:  ..\avto\train_data3\images\train\img_2695_heic.jpg
# 444 работаем  с файлом:  ..\avto\train_data3\images\train\img_2696_heic.jpg
# 445 работаем  с файлом:  ..\avto\train_data3\images\train\img_2699_heic.jpg
# 446 работаем  с файлом:  ..\avto\train_data3\images\train\img_2700_heic.jpg
# 447 работаем  с файлом:  ..\avto\train_data3\images\train\img_2701_heic.jpg
# 448 работаем  с файлом:  ..\avto\train_data3\images\train\img_2704.jpg
# 449 работаем  с файлом:  ..\avto\train_data3\images\train\img_2705.jpg
# 450 работаем  с файлом:  ..\avto\train_data3\images\train\img_2705_heic.jpg
# 451 работаем  с файлом:  ..\avto\train_data3\images\train\img_2706.jpg
# 452 работаем  с файлом:  ..\avto\train_data3\images\train\img_2707.jpg
# 453 работаем  с файлом:  ..\avto\train_data3\images\train\img_2708.jpg
# 454 работаем  с файлом:  ..\avto\train_data3\images\train\img_2709.jpg
# 455 работаем  с файлом:  ..\avto\train_data3\images\train\img_2709_heic.jpg
# 456 работаем  с файлом:  ..\avto\train_data3\images\train\img_2710_heic.jpg
# 457 работаем  с файлом:  ..\avto\train_data3\images\train\img_2712.jpg
# 458 работаем  с файлом:  ..\avto\train_data3\images\train\img_2713.jpg
# 459 работаем  с файлом:  ..\avto\train_data3\images\train\img_2714_heic.jpg
# 460 работаем  с файлом:  ..\avto\train_data3\images\train\img_2716.jpg
# 461 работаем  с файлом:  ..\avto\train_data3\images\train\img_2721.jpg
# 462 работаем  с файлом:  ..\avto\train_data3\images\train\img_2721_heic.jpg
# 463 работаем  с файлом:  ..\avto\train_data3\images\train\img_2722_heic.jpg
# 464 работаем  с файлом:  ..\avto\train_data3\images\train\img_2723.jpg
# 465 работаем  с файлом:  ..\avto\train_data3\images\train\img_2723_heic.jpg
# 466 работаем  с файлом:  ..\avto\train_data3\images\train\img_2724_heic.jpg
# 467 работаем  с файлом:  ..\avto\train_data3\images\train\img_2725.jpg
# 468 работаем  с файлом:  ..\avto\train_data3\images\train\img_2726_heic.jpg
# 469 работаем  с файлом:  ..\avto\train_data3\images\train\img_2727_heic.jpg
# 470 работаем  с файлом:  ..\avto\train_data3\images\train\img_2728.jpg
# 471 работаем  с файлом:  ..\avto\train_data3\images\train\img_2729_heic.jpg
# 472 работаем  с файлом:  ..\avto\train_data3\images\train\img_2730.jpg
# 473 работаем  с файлом:  ..\avto\train_data3\images\train\img_2730_heic.jpg
# 474 работаем  с файлом:  ..\avto\train_data3\images\train\img_2732.jpg
# 475 работаем  с файлом:  ..\avto\train_data3\images\train\img_2733_heic.jpg
# 476 работаем  с файлом:  ..\avto\train_data3\images\train\img_2734_heic.jpg
# 477 работаем  с файлом:  ..\avto\train_data3\images\train\img_2735.jpg
# 478 работаем  с файлом:  ..\avto\train_data3\images\train\img_2735_heic.jpg
# 479 работаем  с файлом:  ..\avto\train_data3\images\train\img_2737.jpg
# 480 работаем  с файлом:  ..\avto\train_data3\images\train\img_2737_heic.jpg
# 481 работаем  с файлом:  ..\avto\train_data3\images\train\img_2738_heic.jpg
# 482 работаем  с файлом:  ..\avto\train_data3\images\train\img_2739.jpg
# 483 работаем  с файлом:  ..\avto\train_data3\images\train\img_2740_heic.jpg
# 484 работаем  с файлом:  ..\avto\train_data3\images\train\img_2741.jpg
# 485 работаем  с файлом:  ..\avto\train_data3\images\train\img_2742.jpg
# 486 работаем  с файлом:  ..\avto\train_data3\images\train\img_2743.jpg
# 487 работаем  с файлом:  ..\avto\train_data3\images\train\img_2743_heic.jpg
# 488 работаем  с файлом:  ..\avto\train_data3\images\train\img_2744_heic.jpg
# 489 работаем  с файлом:  ..\avto\train_data3\images\train\img_2745.jpg
# 490 работаем  с файлом:  ..\avto\train_data3\images\train\img_2745_heic.jpg
# 491 работаем  с файлом:  ..\avto\train_data3\images\train\img_2746_heic.jpg
# 492 работаем  с файлом:  ..\avto\train_data3\images\train\img_2747.jpg
# 493 работаем  с файлом:  ..\avto\train_data3\images\train\img_2747_heic.jpg
# 494 работаем  с файлом:  ..\avto\train_data3\images\train\img_2748.jpg
# 495 работаем  с файлом:  ..\avto\train_data3\images\train\img_2748_heic.jpg
# 496 работаем  с файлом:  ..\avto\train_data3\images\train\img_2749_heic.jpg
# 497 работаем  с файлом:  ..\avto\train_data3\images\train\img_2750.jpg
# 498 работаем  с файлом:  ..\avto\train_data3\images\train\img_2751.jpg
# 499 работаем  с файлом:  ..\avto\train_data3\images\train\img_2751_heic.jpg
# 500 работаем  с файлом:  ..\avto\train_data3\images\train\img_2754_heic.jpg
# 501 работаем  с файлом:  ..\avto\train_data3\images\train\img_2755.jpg
# 502 работаем  с файлом:  ..\avto\train_data3\images\train\img_2756_heic.jpg
# 503 работаем  с файлом:  ..\avto\train_data3\images\train\img_2760.jpg
# 504 работаем  с файлом:  ..\avto\train_data3\images\train\img_2763.jpg
# 505 работаем  с файлом:  ..\avto\train_data3\images\train\img_2764.jpg
# 506 работаем  с файлом:  ..\avto\train_data3\images\train\img_2765.jpg
# 507 работаем  с файлом:  ..\avto\train_data3\images\train\img_2766.jpg
# 508 работаем  с файлом:  ..\avto\train_data3\images\train\img_2767.jpg
# 509 работаем  с файлом:  ..\avto\train_data3\images\train\img_2770.jpg
# 510 работаем  с файлом:  ..\avto\train_data3\images\train\img_2774.jpg
# 511 работаем  с файлом:  ..\avto\train_data3\images\train\img_2775.jpg
# 512 работаем  с файлом:  ..\avto\train_data3\images\train\img_2779.jpg
# 513 работаем  с файлом:  ..\avto\train_data3\images\train\img_2780.jpg
# 514 работаем  с файлом:  ..\avto\train_data3\images\train\img_2783.jpg
# 515 работаем  с файлом:  ..\avto\train_data3\images\train\img_2786.jpg
# 516 работаем  с файлом:  ..\avto\train_data3\images\train\img_2787.jpg
# 517 работаем  с файлом:  ..\avto\train_data3\images\train\img_2788.jpg
# 518 работаем  с файлом:  ..\avto\train_data3\images\train\img_2789.jpg
# 519 работаем  с файлом:  ..\avto\train_data3\images\train\img_2791.jpg
# 520 работаем  с файлом:  ..\avto\train_data3\images\train\img_2792.jpg
# 521 работаем  с файлом:  ..\avto\train_data3\images\train\img_2793.jpg
# 522 работаем  с файлом:  ..\avto\train_data3\images\train\img_2794.jpg
# 523 работаем  с файлом:  ..\avto\train_data3\images\train\img_2795.jpg
# 524 работаем  с файлом:  ..\avto\train_data3\images\train\img_2796.jpg
# 525 работаем  с файлом:  ..\avto\train_data3\images\train\img_2797.jpg
# 526 работаем  с файлом:  ..\avto\train_data3\images\train\img_2799.jpg
# 527 работаем  с файлом:  ..\avto\train_data3\images\train\img_2857.jpg
# 528 работаем  с файлом:  ..\avto\train_data3\images\train\img_2858.jpg
# 529 работаем  с файлом:  ..\avto\train_data3\images\train\img_2860.jpg
# 530 работаем  с файлом:  ..\avto\train_data3\images\train\img_2861.jpg
# 531 работаем  с файлом:  ..\avto\train_data3\images\train\img_2862.jpg
# 532 работаем  с файлом:  ..\avto\train_data3\images\train\img_2863.jpg
# 533 работаем  с файлом:  ..\avto\train_data3\images\train\img_2866.jpg
# 534 работаем  с файлом:  ..\avto\train_data3\images\train\img_2867.jpg
# 535 работаем  с файлом:  ..\avto\train_data3\images\train\img_2869.jpg
# 536 работаем  с файлом:  ..\avto\train_data3\images\train\img_2870.jpg
# 537 работаем  с файлом:  ..\avto\train_data3\images\train\img_2872.jpg
# 538 работаем  с файлом:  ..\avto\train_data3\images\train\img_2874.jpg
# 539 работаем  с файлом:  ..\avto\train_data3\images\train\img_2876.jpg
# 540 работаем  с файлом:  ..\avto\train_data3\images\train\img_2879.jpg
# 541 работаем  с файлом:  ..\avto\train_data3\images\train\img_2881.jpg
# 542 работаем  с файлом:  ..\avto\train_data3\images\train\img_2882.jpg
# 543 работаем  с файлом:  ..\avto\train_data3\images\train\img_2883.jpg
# 544 работаем  с файлом:  ..\avto\train_data3\images\train\img_2885.jpg
# 545 работаем  с файлом:  ..\avto\train_data3\images\train\img_2890.jpg
# 546 работаем  с файлом:  ..\avto\train_data3\images\train\img_2891.jpg
# 547 работаем  с файлом:  ..\avto\train_data3\images\train\img_2892.jpg
# 548 работаем  с файлом:  ..\avto\train_data3\images\train\img_2894.jpg
# 549 работаем  с файлом:  ..\avto\train_data3\images\train\img_2895.jpg
# 550 работаем  с файлом:  ..\avto\train_data3\images\train\img_2896.jpg
# 551 работаем  с файлом:  ..\avto\train_data3\images\train\img_2897.jpg
# 552 работаем  с файлом:  ..\avto\train_data3\images\train\img_2899.jpg
# 553 работаем  с файлом:  ..\avto\train_data3\images\train\img_2901.jpg
# 554 работаем  с файлом:  ..\avto\train_data3\images\train\img_2902.jpg
# 555 работаем  с файлом:  ..\avto\train_data3\images\train\img_2903.jpg
# 556 работаем  с файлом:  ..\avto\train_data3\images\train\img_2904.jpg
# 557 работаем  с файлом:  ..\avto\train_data3\images\train\img_2905.jpg
# 558 работаем  с файлом:  ..\avto\train_data3\images\train\img_2908.jpg
# 559 работаем  с файлом:  ..\avto\train_data3\images\train\img_2911.jpg
# 560 работаем  с файлом:  ..\avto\train_data3\images\train\img_2912.jpg
# 561 работаем  с файлом:  ..\avto\train_data3\images\train\img_2913.jpg
# 562 работаем  с файлом:  ..\avto\train_data3\images\train\img_2915.jpg
# 563 работаем  с файлом:  ..\avto\train_data3\images\train\img_2916.jpg
# 564 работаем  с файлом:  ..\avto\train_data3\images\train\img_2918.jpg
# 565 работаем  с файлом:  ..\avto\train_data3\images\train\img_2920.jpg
# 566 работаем  с файлом:  ..\avto\train_data3\images\train\img_2927.jpg
# 567 работаем  с файлом:  ..\avto\train_data3\images\train\img_2928.jpg
# 568 работаем  с файлом:  ..\avto\train_data3\images\train\img_2930.jpg
# 569 работаем  с файлом:  ..\avto\train_data3\images\train\img_2931.jpg
# 570 работаем  с файлом:  ..\avto\train_data3\images\train\img_2932.jpg
# 571 работаем  с файлом:  ..\avto\train_data3\images\train\img_2934.jpg
# 572 работаем  с файлом:  ..\avto\train_data3\images\train\img_2937.jpg
# 573 работаем  с файлом:  ..\avto\train_data3\images\train\img_2939.jpg
# 574 работаем  с файлом:  ..\avto\train_data3\images\train\img_2940.jpg
# 575 работаем  с файлом:  ..\avto\train_data3\images\train\img_2941.jpg
# 576 работаем  с файлом:  ..\avto\train_data3\images\train\img_2944.jpg
# 577 работаем  с файлом:  ..\avto\train_data3\images\train\img_2945.jpg
# ОК

# %%
d = file_recognition('..\\avto\\start_dataset\\test\\img_2717.jpg')
print(d)
# Out:
# 6
# повернули
# сохранили поворот Y:\img_2717.jpg
# ФАЙЛ НЕ РАСПОЗНАН ..\avto\start_dataset\test\img_2717.jpg
# 0.0

# %%
img = Image.open('..\\avto\\start_dataset\\test\\img_2717.jpg')
img = img.rotate(-90, expand=True)
img.save('Y:\\img_2717.jpg')

# %%
from exif import Image as exif

# %%
#не распознанные img_2674.heic img_2715.jpg img_2717.jpg

# %%
get_focus_from_exif("..\\avto\\start_dataset\\test\\img_1602.jpg")
# Out:
# 17

# %%
with open("..\\avto\\start_dataset\\test\\img_1599.jpg", "rb") as palm_1_file:
    palm_1_image = exif(palm_1_file)
with open("..\\avto\\start_dataset\\test\\img_1602.jpg", "rb") as palm_2_file:
    palm_2_image = exif(palm_2_file)
images = [palm_1_image, palm_2_image]

# %%
if palm_1_image.has_exif:
    status = f"contains EXIF (version {palm_1_image.exif_version}) information."
else:
    status = "does not contain any EXIF information."
print(f"Image {status}")
# Out:
# Image contains EXIF (version 0232) information.

# %%
image_members = []

for image in images:
    image_members.append(dir(image))

for index, image_member_list in enumerate(image_members):
    print(f"Image {index} contains {len(image_member_list)} members:")
    print(f"{image_member_list}\n")
# Out:
# Image 0 contains 74 members:
# ['<unknown EXIF tag 316>', '<unknown EXIF tag 42080>', '_exif_ifd_pointer', '_gps_ifd_pointer', '_segments', 'aperture_value', 'brightness_value', 'color_space', 'components_configuration', 'compression', 'datetime', 'datetime_digitized', 'datetime_original', 'delete', 'delete_all', 'digital_zoom_ratio', 'exif_version', 'exposure_bias_value', 'exposure_mode', 'exposure_program', 'exposure_time', 'f_number', 'flash', 'flashpix_version', 'focal_length', 'focal_length_in_35mm_film', 'get', 'get_all', 'get_file', 'get_thumbnail', 'gps_altitude', 'gps_altitude_ref', 'gps_dest_bearing', 'gps_dest_bearing_ref', 'gps_horizontal_positioning_error', 'gps_img_direction', 'gps_img_direction_ref', 'gps_latitude', 'gps_latitude_ref', 'gps_longitude', 'gps_longitude_ref', 'gps_speed', 'gps_speed_ref', 'has_exif', 'jpeg_interchange_format', 'jpeg_interchange_format_length', 'lens_make', 'lens_model', 'lens_specification', 'list_all', 'make', 'maker_note', 'metering_mode', 'model', 'offset_time', 'offset_time_digitized', 'offset_time_original', 'orientation', 'photographic_sensitivity', 'pixel_x_dimension', 'pixel_y_dimension', 'resolution_unit', 'scene_capture_type', 'scene_type', 'sensing_method', 'shutter_speed_value', 'software', 'subject_area', 'subsec_time_digitized', 'subsec_time_original', 'white_balance', 'x_resolution', 'y_and_c_positioning', 'y_resolution']
#
# Image 1 contains 74 members:
# ['<unknown EXIF tag 316>', '<unknown EXIF tag 42080>', '_exif_ifd_pointer', '_gps_ifd_pointer', '_segments', 'aperture_value', 'brightness_value', 'color_space', 'components_configuration', 'compression', 'datetime', 'datetime_digitized', 'datetime_original', 'delete', 'delete_all', 'digital_zoom_ratio', 'exif_version', 'exposure_bias_value', 'exposure_mode', 'exposure_program', 'exposure_time', 'f_number', 'flash', 'flashpix_version', 'focal_length', 'focal_length_in_35mm_film', 'get', 'get_all', 'get_file', 'get_thumbnail', 'gps_altitude', 'gps_altitude_ref', 'gps_dest_bearing', 'gps_dest_bearing_ref', 'gps_horizontal_positioning_error', 'gps_img_direction', 'gps_img_direction_ref', 'gps_latitude', 'gps_latitude_ref', 'gps_longitude', 'gps_longitude_ref', 'gps_speed', 'gps_speed_ref', 'has_exif', 'jpeg_interchange_format', 'jpeg_interchange_format_length', 'lens_make', 'lens_model', 'lens_specification', 'list_all', 'make', 'maker_note', 'metering_mode', 'model', 'offset_time', 'offset_time_digitized', 'offset_time_original', 'orientation', 'photographic_sensitivity', 'pixel_x_dimension', 'pixel_y_dimension', 'resolution_unit', 'scene_capture_type', 'scene_type', 'sensing_method', 'shutter_speed_value', 'software', 'subject_area', 'subsec_time_digitized', 'subsec_time_original', 'white_balance', 'x_resolution', 'y_and_c_positioning', 'y_resolution']

# %%
palm_1_image.get('focal_length_in_35mm_film', 'Unknown')
# Out:
# 17

# %%
for i in image_member_list:
    print(i,palm_1_image.get(i, 'Unknown'))
# Out:
# <unknown EXIF tag 316> Unknown
# <unknown EXIF tag 42080> Unknown
# _exif_ifd_pointer 226
# _gps_ifd_pointer 2192
# _segments Unknown
# aperture_value 2.5260688112781806
# brightness_value 8.91151083143064
# color_space ColorSpace.UNCALIBRATED
# components_configuration Unknown
# compression 6
# datetime 2022:07:07 11:04:56
# datetime_digitized 2022:07:07 11:04:56
# datetime_original 2022:07:07 11:04:56
# delete Unknown
# delete_all Unknown
# digital_zoom_ratio 1.261050875729775
# exif_version 0232
# exposure_bias_value 0.0
# exposure_mode ExposureMode.AUTO_EXPOSURE
# exposure_program ExposureProgram.NORMAL_PROGRAM
# exposure_time 0.0027548209366391185
# f_number 2.4
# flash Flash(flash_fired=False, flash_return=FlashReturn.NO_STROBE_RETURN_DETECTION_FUNCTION, flash_mode=FlashMode.COMPULSORY_FLASH_SUPPRESSION, flash_function_not_present=False, red_eye_reduction_supported=False, reserved=0)
# flashpix_version Unknown
# focal_length 1.54
# focal_length_in_35mm_film 17
# get Unknown
# get_all Unknown
# get_file Unknown
# get_thumbnail Unknown
# gps_altitude 181.68673808644255
# gps_altitude_ref GpsAltitudeRef.ABOVE_SEA_LEVEL
# gps_dest_bearing 178.59268175252768
# gps_dest_bearing_ref T
# gps_horizontal_positioning_error 5.067514380865879
# gps_img_direction 178.59268175252768
# gps_img_direction_ref T
# gps_latitude (54.0, 19.0, 46.04)
# gps_latitude_ref N
# gps_longitude (48.0, 23.0, 43.1)
# gps_longitude_ref E
# gps_speed 0.0
# gps_speed_ref K
# has_exif Unknown
# jpeg_interchange_format 2536
# jpeg_interchange_format_length 9421
# lens_make Apple
# lens_model iPhone 11 back dual wide camera 1.54mm f/2.4
# lens_specification (1.5399999618512084, 4.25, 1.8, 2.4)
# list_all Unknown
# make Apple
# maker_note Unknown
# metering_mode MeteringMode.PATTERN
# model iPhone 11
# offset_time +04:00
# offset_time_digitized +04:00
# offset_time_original +04:00
# orientation Orientation.TOP_LEFT
# photographic_sensitivity 20
# pixel_x_dimension 4032
# pixel_y_dimension 3024
# resolution_unit ResolutionUnit.INCHES
# scene_capture_type SceneCaptureType.STANDARD
# scene_type Unknown
# sensing_method SensingMethod.ONE_CHIP_COLOR_AREA_SENSOR
# shutter_speed_value 8.5053038199767
# software 15.5
# subject_area 0
# subsec_time_digitized 645
# subsec_time_original 645
# white_balance WhiteBalance.AUTO
# x_resolution 72.0
# y_and_c_positioning 1
# y_resolution 72.0

# %%
for index, image in enumerate(images):
    print(f"Lens and OS - Image {index}")
    print("---------------------")
    print(f"focal_length_in_35mm_film: {image.get('focal_length_in_35mm_film', 'Unknown')}")
    print(f"Lens model: {image.get('lens_model', 'Unknown')}")
    print(f"Lens specification: {image.get('lens_specification', 'Unknown')}")
    print(f"OS version: {image.get('software', 'Unknown')}\n")
# Out:
# Lens and OS - Image 0
# ---------------------
# focal_length_in_35mm_film: 17
# Lens model: iPhone 11 back dual wide camera 1.54mm f/2.4
# Lens specification: (1.5399999618512084, 4.25, 1.8, 2.4)
# OS version: 15.5
#
# Lens and OS - Image 1
# ---------------------
# focal_length_in_35mm_film: 17
# Lens model: iPhone 11 back dual wide camera 1.54mm f/2.4
# Lens specification: (1.5399999618512084, 4.25, 1.8, 2.4)
# OS version: 15.5

# %%
for i in image_member_list:
    print(i)
# Out:
# <unknown EXIF tag 316>
# <unknown EXIF tag 42080>
# _exif_ifd_pointer
# _gps_ifd_pointer
# _segments
# aperture_value
# brightness_value
# color_space
# components_configuration
# compression
# datetime
# datetime_digitized
# datetime_original
# delete
# delete_all
# digital_zoom_ratio
# exif_version
# exposure_bias_value
# exposure_mode
# exposure_program
# exposure_time
# f_number
# flash
# flashpix_version
# focal_length
# focal_length_in_35mm_film
# get
# get_all
# get_file
# get_thumbnail
# gps_altitude
# gps_altitude_ref
# gps_dest_bearing
# gps_dest_bearing_ref
# gps_horizontal_positioning_error
# gps_img_direction
# gps_img_direction_ref
# gps_latitude
# gps_latitude_ref
# gps_longitude
# gps_longitude_ref
# gps_speed
# gps_speed_ref
# has_exif
# jpeg_interchange_format
# jpeg_interchange_format_length
# lens_make
# lens_model
# lens_specification
# list_all
# make
# maker_note
# metering_mode
# model
# offset_time
# offset_time_digitized
# offset_time_original
# orientation
# photographic_sensitivity
# pixel_x_dimension
# pixel_y_dimension
# resolution_unit
# scene_capture_type
# scene_type
# sensing_method
# shutter_speed_value
# software
# subject_area
# subsec_time_digitized
# subsec_time_original
# white_balance
# x_resolution
# y_and_c_positioning
# y_resolution

# %%
import exifread
f = open('..\\avto\\start_dataset\\test\\img_2674.heic', 'rb')
#f = open('..\\avto\\start_dataset\\test\\img_1598.jpg', 'rb')

tags = exifread.process_file(f,details=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\anaconda3\envs\torch_gpu\lib\site-packages\exifread\heic.py:171, in HEICExifFinder.get_parser(self, box)
#     170 try:
# --> 171     return defs[box.name]
#     172 except (IndexError, KeyError) as err:
#
# KeyError: 'hdlr'
#
# The above exception was the direct cause of the following exception:
#
# NoParser                                  Traceback (most recent call last)
# Input In [97], in <cell line: 5>()
#       2 f = open('..\\avto\\start_dataset\\test\\img_2674.heic', 'rb')
#       3 #f = open('..\\avto\\start_dataset\\test\\img_1598.jpg', 'rb')
# ----> 5 tags = exifread.process_file(f,details=False)
#
# File C:\anaconda3\envs\torch_gpu\lib\site-packages\exifread\__init__.py:137, in process_file(fh, stop_tag, details, strict, debug, truncate_tags, auto_seek)
#     134     fh.seek(0)
#     136 try:
# --> 137     offset, endian, fake_exif = _determine_type(fh)
#     138 except ExifNotFound as err:
#     139     logger.warning(err)
#
# File C:\anaconda3\envs\torch_gpu\lib\site-packages\exifread\__init__.py:109, in _determine_type(fh)
#     107     fh.seek(0)
#     108     heic = HEICExifFinder(fh)
# --> 109     offset, endian = heic.find_exif()
#     110 elif data[0:4] == b'RIFF' and data[8:12] == b'WEBP':
#     111     offset, endian = _find_webp_exif(fh)
#
# File C:\anaconda3\envs\torch_gpu\lib\site-packages\exifread\heic.py:268, in HEICExifFinder.find_exif(self)
#     266 assert ftyp.major_brand == b'heic'
#     267 assert ftyp.minor_version == 0
# --> 268 meta = self.expect_parse('meta')
#     269 assert meta.subs['iinf'].exif_infe is not None
#     270 item_id = meta.subs['iinf'].exif_infe.item_id
#
# File C:\anaconda3\envs\torch_gpu\lib\site-packages\exifread\heic.py:159, in HEICExifFinder.expect_parse(self, name)
#     157 box = self.next_box()
#     158 if box.name == name:
# --> 159     return self.parse_box(box)
#     160 self.skip(box)
#
# File C:\anaconda3\envs\torch_gpu\lib\site-packages\exifread\heic.py:177, in HEICExifFinder.parse_box(self, box)
#     175 def parse_box(self, box: Box) -> Box:
#     176     probe = self.get_parser(box)
# --> 177     probe(box)
#     178     # in case anything is left unread
#     179     self.file_handle.seek(box.after)
#
# File C:\anaconda3\envs\torch_gpu\lib\site-packages\exifread\heic.py:195, in HEICExifFinder._parse_meta(self, meta)
#     193 while self.file_handle.tell() < meta.after:
#     194     box = self.next_box()
# --> 195     psub = self.get_parser(box)
#     196     if psub is not None:
#     197         psub(box)
#
# File C:\anaconda3\envs\torch_gpu\lib\site-packages\exifread\heic.py:173, in HEICExifFinder.get_parser(self, box)
#     171     return defs[box.name]
#     172 except (IndexError, KeyError) as err:
# --> 173     raise NoParser(box.name) from err
#
# NoParser: hdlr

# %%
tags['EXIF FocalLengthIn35mmFilm']
# Out:
# (0xA405) Short=17 @ 608

# %%
for tag in tags.keys():
    print ("Key: %s, value %s" % (tag, tags[tag]))
# Out:
# Key: Image Make, value Apple
# Key: Image Model, value iPhone 11
# Key: Image Orientation, value Horizontal (normal)
# Key: Image XResolution, value 72
# Key: Image YResolution, value 72
# Key: Image ResolutionUnit, value Pixels/Inch
# Key: Image Software, value 15.5
# Key: Image DateTime, value 2022:07:07 11:04:10
# Key: Image HostComputer, value iPhone 11
# Key: Image YCbCrPositioning, value Centered
# Key: Image ExifOffset, value 226
# Key: GPS GPSLatitudeRef, value N
# Key: GPS GPSLatitude, value [54, 19, 4599/100]
# Key: GPS GPSLongitudeRef, value E
# Key: GPS GPSLongitude, value [48, 23, 861/20]
# Key: GPS GPSAltitudeRef, value 0
# Key: GPS GPSAltitude, value 475297/2619
# Key: GPS GPSSpeedRef, value K
# Key: GPS GPSSpeed, value 0
# Key: GPS GPSImgDirectionRef, value T
# Key: GPS GPSImgDirection, value 390347/2216
# Key: GPS GPSDestBearingRef, value T
# Key: GPS GPSDestBearing, value 390347/2216
# Key: GPS Tag 0x001F, value 54304/11167
# Key: Image GPSInfo, value 2192
# Key: Thumbnail Compression, value JPEG (old-style)
# Key: Thumbnail XResolution, value 72
# Key: Thumbnail YResolution, value 72
# Key: Thumbnail ResolutionUnit, value Pixels/Inch
# Key: Thumbnail JPEGInterchangeFormat, value 2536
# Key: Thumbnail JPEGInterchangeFormatLength, value 9369
# Key: EXIF ExposureTime, value 1/466
# Key: EXIF FNumber, value 12/5
# Key: EXIF ExposureProgram, value Program Normal
# Key: EXIF ISOSpeedRatings, value 20
# Key: EXIF ExifVersion, value 0232
# Key: EXIF DateTimeOriginal, value 2022:07:07 11:04:10
# Key: EXIF DateTimeDigitized, value 2022:07:07 11:04:10
# Key: EXIF OffsetTime, value +04:00
# Key: EXIF OffsetTimeOriginal, value +04:00
# Key: EXIF OffsetTimeDigitized, value +04:00
# Key: EXIF ComponentsConfiguration, value YCbCr
# Key: EXIF ShutterSpeedValue, value 49995/5641
# Key: EXIF ApertureValue, value 126503/50079
# Key: EXIF BrightnessValue, value 125719/13668
# Key: EXIF ExposureBiasValue, value 0
# Key: EXIF MeteringMode, value Pattern
# Key: EXIF Flash, value Flash did not fire, compulsory flash mode
# Key: EXIF FocalLength, value 77/50
# Key: EXIF SubjectArea, value [2015, 1511, 2322, 1394]
# Key: EXIF SubSecTimeOriginal, value 716
# Key: EXIF SubSecTimeDigitized, value 716
# Key: EXIF FlashPixVersion, value 0100
# Key: EXIF ColorSpace, value Uncalibrated
# Key: EXIF ExifImageWidth, value 4032
# Key: EXIF ExifImageLength, value 3024
# Key: EXIF SensingMethod, value One-chip color area
# Key: EXIF SceneType, value Directly Photographed
# Key: EXIF ExposureMode, value Auto Exposure
# Key: EXIF WhiteBalance, value Auto
# Key: EXIF DigitalZoomRatio, value 1512/1199
# Key: EXIF FocalLengthIn35mmFilm, value 17
# Key: EXIF SceneCaptureType, value Standard
# Key: EXIF LensSpecification, value [807365/524263, 17/4, 9/5, 12/5]
# Key: EXIF LensMake, value Apple
# Key: EXIF LensModel, value iPhone 11 back dual wide camera 1.54mm f/2.4
# Key: EXIF Tag 0xA460, value 2

# %%
decodeImage('..\avto\start_dataset\test\img_2674.heic')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [73], in <cell line: 1>()
# ----> 1 decodeImage('..\avto\start_dataset\test\img_2674.heic')
#
# Input In [72], in decodeImage(bytesIo)
#       8 def decodeImage(bytesIo):
#       9 #     fmt = whatimage.identify_image(bytesIo)
#      10 #     if fmt in ['heic', 'avif']:
# ---> 11     i = pyheif.read_heif(bytesIo)
#      12         # Extract metadata etc
#      13     for metadata in i.metadata or []:
#
# NameError: name 'pyheif' is not defined

# %%
heif_file = pillow_heif.open_heif('..\\avto\\start_dataset\\test\\img_2674.heic')
print("image mode:", heif_file.mode)
print("image data length:", len(heif_file.data))
print("image data stride:", heif_file.stride)
heif_file.convert_to("RGB;16")  # convert 10 bit image to RGB 16 bit.
print("image mode:", heif_file.info.keys())
# Out:
# image mode: RGB
# image data length: 36578304
# image data stride: 12096
# image mode: dict_keys(['exif', 'xmp', 'primary', 'metadata', 'icc_profile', 'icc_profile_type'])

# %%
print(heif_file.info['exif'])
# Out:
# b'Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x0b\x01\x0f\x00\x02\x00\x00\x00\x06\x00\x00\x00\x92\x01\x10\x00\x02\x00\x00\x00\n\x00\x00\x00\x98\x01\x12\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00\xa2\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00\xaa\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x011\x00\x02\x00\x00\x00\x07\x00\x00\x00\xb2\x012\x00\x02\x00\x00\x00\x14\x00\x00\x00\xba\x01<\x00\x02\x00\x00\x00\n\x00\x00\x00\xce\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\xd8\x88%\x00\x04\x00\x00\x00\x01\x00\x00\t\x1a\x00\x00\x00\x00Apple\x00iPhone 12\x00\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\x0115.4.1\x00\x002022:07:10 21:12:03\x00iPhone 12\x00\x00$\x82\x9a\x00\x05\x00\x00\x00\x01\x00\x00\x02\x8e\x82\x9d\x00\x05\x00\x00\x00\x01\x00\x00\x02\x96\x88"\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x88\'\x00\x03\x00\x00\x00\x01\x03\xe8\x00\x00\x90\x00\x00\x07\x00\x00\x00\x040232\x90\x03\x00\x02\x00\x00\x00\x14\x00\x00\x02\x9e\x90\x04\x00\x02\x00\x00\x00\x14\x00\x00\x02\xb2\x90\x10\x00\x02\x00\x00\x00\x07\x00\x00\x02\xc6\x90\x11\x00\x02\x00\x00\x00\x07\x00\x00\x02\xce\x90\x12\x00\x02\x00\x00\x00\x07\x00\x00\x02\xd6\x92\x01\x00\n\x00\x00\x00\x01\x00\x00\x02\xde\x92\x02\x00\x05\x00\x00\x00\x01\x00\x00\x02\xe6\x92\x03\x00\n\x00\x00\x00\x01\x00\x00\x02\xee\x92\x04\x00\n\x00\x00\x00\x01\x00\x00\x02\xf6\x92\x07\x00\x03\x00\x00\x00\x01\x00\x05\x00\x00\x92\t\x00\x03\x00\x00\x00\x01\x00\x10\x00\x00\x92\n\x00\x05\x00\x00\x00\x01\x00\x00\x02\xfe\x92\x14\x00\x03\x00\x00\x00\x04\x00\x00\x03\x06\x92|\x00\x07\x00\x00\x05v\x00\x00\x03\x0e\x92\x91\x00\x02\x00\x00\x00\x04713\x00\x92\x92\x00\x02\x00\x00\x00\x047132\x00\x05\x00\x00\x00\x04\x00\x00\x08\x8c\xa43\x00\x02\x00\x00\x00\x06\x00\x00\x08\xac\xa44\x00\x02\x00\x00\x00-\x00\x00\x08\xb2\xa4`\x00\x03\x00\x00\x00\x01\x00\x03\x00\x00\xa4a\x00\x03\x00\x00\x00\x02\x00\n\x00\x00\xa4b\x00\x07\x00\x00\x00:\x00\x00\x08\xe0\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\r\x00\x00\x00\x0c\x00\x00\x00\x052022:07:10 21:12:03\x002022:07:10 21:12:03\x00+04:00\x00\x00+04:00\x00\x00+04:00\x00\x00\x00\x00\xb9\x16\x00\x002\xcb\x00\x02\x01\x14\x00\x00\xcb\x1d\xff\xfekG\x00\x00\xb3\xe2\xff\xff\xff\xf9\x00\x00\x00\x80\x00\x00\x00\x1f\x00\x00\x00\x14\x07\xe1\x05\xe7\t\x15\x05rApple iOS\x00\x00\x01MM\x00&\x00\x01\x00\t\x00\x00\x00\x01\x00\x00\x00\x0e\x00\x02\x00\x07\x00\x00\x02.\x00\x00\x01\xdc\x00\x03\x00\x07\x00\x00\x00h\x00\x00\x04\n\x00\x04\x00\t\x00\x00\x00\x01\x00\x00\x00\x01\x00\x05\x00\t\x00\x00\x00\x01\x00\x00\x00l\x00\x06\x00\t\x00\x00\x00\x01\x00\x00\x00g\x00\x07\x00\t\x00\x00\x00\x01\x00\x00\x00\x01\x00\x08\x00\n\x00\x00\x00\x03\x00\x00\x04r\x00\x0e\x00\t\x00\x00\x00\x01\x00\x00\x00\x00\x00\x14\x00\t\x00\x00\x00\x01\x00\x00\x00\x0b\x00\x17\x00\t\x00\x00\x00\x01\xc6\x00\x80\x00\x00\x19\x00\t\x00\x00\x00\x01\x00\x00\x00\x00\x00\x1a\x00\x02\x00\x00\x00\x06\x00\x00\x04\x8a\x00\x1f\x00\t\x00\x00\x00\x01\x00\x00\x00\x00\x00 \x00\x02\x00\x00\x00%\x00\x00\x04\x90\x00!\x00\n\x00\x00\x00\x01\x00\x00\x04\xb6\x00%\x00\t\x00\x00\x00\x01\x00\x00\x16\x8c\x00&\x00\t\x00\x00\x00\x01\x00\x00\x00\x02\x00\'\x00\n\x00\x00\x00\x01\x00\x00\x04\xbe\x00(\x00\t\x00\x00\x00\x01\x00\x00\x00\x01\x00+\x00\x02\x00\x00\x00%\x00\x00\x04\xc6\x00-\x00\t\x00\x00\x00\x01\x00\x00\x1b/\x00.\x00\t\x00\x00\x00\x01\x00\x00\x00\x00\x00/\x00\t\x00\x00\x00\x01\x00\x00\x00\x00\x000\x00\n\x00\x00\x00\x01\x00\x00\x04\xec\x001\x00\x07\x00\x00\x00X\x00\x00\x04\xf4\x002\x00\t\x00\x00\x00\x01\x02\xc1(\x00\x003\x00\t\x00\x00\x00\x01\x00\x00 \x00\x004\x00\t\x00\x00\x00\x01\x00\x00\x00\n\x005\x00\t\ ...

# %%
 heif_file = pillow_heif.read_heif(file)
    image = Image.frombytes(
        heif_file.mode,
        heif_file.size,
        heif_file.data,

# %%
https://pillow-heif.readthedocs.io/en/latest/reference/API.html
